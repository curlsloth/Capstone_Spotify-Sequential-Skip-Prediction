# %% [markdown]
# # **Will you skip this music track or not?**
#
#
# The public part of the dataset consists of roughly 130 million listening sessions with associated user interactions on the Spotify service.
#
# The task is to predict whether individual tracks encountered in a listening session will be skipped by a particular user. In order to do this, complete information about the first half of a user’s listening session is provided, while the prediction is to be carried out on the second half. Participants have access to metadata, as well as acoustic descriptors, for all the tracks encountered in listening sessions.
#
# https://www.aicrowd.com/challenges/spotify-sequential-skip-prediction-challenge
#
# Brost, B., Mehrotra, R., & Jehan, T. (2019, May). The music streaming sessions dataset. In The World Wide Web Conference (pp. 2594-2600).

# %% [markdown]
# As the entire dataset is too big to experiment data manipulation, Spotify provided a mini dataset for this purpose.
#
# In this script, we will do data wrangling to inspect the quality of the data, and do data engineering to generate features for machine learning modeling.

# %% [markdown]
# # Mount Google drive to Colab

# %%
# # For Colab only
#from google.colab import drive
#drive.mount('/content/drive')
#%cd /content/drive/MyDrive/Capstone_SpotifyStreaming/notebooks

#!pip install featuretools==0.4.0
#!pip install -U featuretools
#!pip install featuretools

# # check the installed packages
# pip list -v

# %%
import numpy as np
import pandas as pd
import featuretools as ft
import time
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load the data and perform some data cleaning/re-coding as described in 2_mini_EDA

# %%
# load the track information (mini version)

tf_df = pd.read_csv('../data/raw/data/track_features/tf_mini.csv')
log_df = pd.read_csv('../data/raw/data/training_set/log_mini.csv')

# %%
# perform some data cleaning/re-coding as described in 2_mini_EDA

tf_df_dummy = pd.get_dummies(tf_df, columns=['key','time_signature','mode'])
log_df_dummy = pd.get_dummies(log_df.drop(columns = ['session_length',  'hist_user_behavior_reason_end', 'hist_user_behavior_n_seekfwd','hist_user_behavior_n_seekback']), columns=['hist_user_behavior_reason_start', 'context_type'])

# %%
tf_df_dummy.head().T
# Out:
#                                                              0  \
# track_id                t_a540e552-16d4-42f8-a185-232bd650ea7d
# duration                                            109.706673
# release_year                                              1950
# us_popularity_estimate                               99.975414
# acousticness                                           0.45804
# beat_strength                                         0.519497
# bounciness                                            0.504949
# danceability                                          0.399767
# dyn_range_mean                                         7.51188
# energy                                                0.817709
# flatness                                              0.903753
# instrumentalness                                      0.000003
# liveness                                              0.132124
# loudness                                               -11.238
# mechanism                                               0.3861
# organism                                              0.541606
# speechiness                                           0.079985
# tempo                                               166.287003
# valence                                               0.935512
# acoustic_vector_0                                    -0.033284
# acoustic_vector_1                                    -0.411896
# acoustic_vector_2                                     -0.02858
# acoustic_vector_3                                     0.349438
# acoustic_vector_4                                     0.832467
# acoustic_vector_5                                    -0.213871
# acoustic_vector_6                                    -0.299464
# acoustic_vector_7                                    -0.675907
# key_0                                                        1
# key_1                                                        0
# key_2                                                        0
# key_3                                                        0
# key_4                                                        0
# key_5                                                        0
# key_6                                                        0
# key_7                                                        0
# key_8                                                        0
# key_9                                                        0
# key_10                                                       0
# key_11                                                       0
# time_signature_0                                             0
# time_signature_1                                             0
# time_signature_3                                             0
# time_signature_4                                             1
# time_signature_5                                             0
# mode_major                                                   1
# mode_minor                                                   0
#
#                                                              1  \
# track_id                t_67965da0-132b-4b1e-8a69-0ef99b32287c
# duration                                            187.693329
# release_year                                              1950
# us_popularity_estimate                                99.96943
# acousticness                                          0.916272
# beat_strength                                         0.419223
# bounciness                                             0.54553
# danceability                                          0.491235
# dyn_range_mean                                        9.098376
# energy                                                0.154258
# flatness                                              1.037952
# instrumentalness                                           0.0
# liveness                                              0.163281
# loudness                                               -13.706
# mechanism                                                0.125
# organism                                              0.895874
# speechiness                                           0.083877
# tempo                                                95.261002
# valence                                               0.359675
# acoustic_vector_0                                     0.145703
# acoustic_vector_1                                    -0.850372
# acoustic_vector_2                                      0.12386
# acoustic_vector_3                                     0.746904
# acoustic_vector_4                                     0.371803
# acoustic_vector_5                                    -0.420558
# acoustic_vector_6                                     -0.21312
# acoustic_vector_7                                    -0.525795
# key_0                                                        1
# key_1                                                        0
# key_2                                                        0
# key_3                                                        0
# key_4                                                        0
# key_5                                                        0
# key_6                                                        0
# key_7                                                        0
# key_8                                                        0
# key_9                                                        0
# key_10                                                       0
# key_11                                                       0
# time_signature_0                                             0
# time_signature_1                                             0
# time_signature_3                                             1
# time_signature_4                                             0
# time_signature_5                                             0
# mode_major                                                   1
# mode_minor                                                   0
#
#                                                              2  \
# track_id                t_0614ecd3-a7d5-40a1-816e-156d5872a467
# duration                                            160.839996
# release_year                                              1951
# us_popularity_estimate                               99.602549
# acousticness                                          0.812884
# beat_strength                                          0.42589
# bounciness                                             0.50828
# danceability                                          0.491625
# dyn_range_mean                                         8.36867
# energy                                                0.358813
# flatness                                              1.004268
# instrumentalness                                           0.0
# liveness                                              0.090115
# loudness                                               -10.522
# mechanism                                             0.200669
# organism                                              0.806136
# speechiness                                           0.038777
# tempo                                               105.185997
# valence                                               0.726769
# acoustic_vector_0                                      0.02172
# acoustic_vector_1                                    -0.743634
# acoustic_vector_2                                     0.333247
# acoustic_vector_3                                     0.568447
# acoustic_vector_4                                     0.411094
# acoustic_vector_5                                    -0.187749
# acoustic_vector_6                                    -0.387599
# acoustic_vector_7                                    -0.433496
# key_0                                                        1
# key_1                                                        0
# key_2                                                        0
# key_3                                                        0
# key_4                                                        0
# key_5                                                        0
# key_6                                                        0
# key_7                                                        0
# key_8                                                        0
# key_9                                                        0
# key_10                                                       0
# key_11                                                       0
# time_signature_0                                             0
# time_signature_1                                             0
# time_signature_3                                             0
# time_signature_4                                             1
# time_signature_5                                             0
# mode_major                                                   0
# mode_minor                                                   1
#
#                                                              3  \
# track_id                t_070a63a0-744a-434e-9913-a97b02926a29
# duration                                            175.399994
# release_year                                              1951
# us_popularity_estimate                               99.665018
# acousticness                                          0.396854
# beat_strength                                         0.400934
# bounciness                                             0.35999
# danceability                                          0.552227
# dyn_range_mean                                        5.967346
# energy                                                0.514585
# flatness                                              0.975138
# instrumentalness                                           0.0
# liveness                                              0.360924
# loudness                                               -11.032
# mechanism                                             0.427152
# organism                                              0.492772
# speechiness                                           0.038337
# tempo                                               119.441002
# valence                                               0.859075
# acoustic_vector_0                                     0.039143
# acoustic_vector_1                                    -0.267555
# acoustic_vector_2                                    -0.051825
# acoustic_vector_3                                     0.106173
# acoustic_vector_4                                     0.614825
# acoustic_vector_5                                    -0.111419
# acoustic_vector_6                                    -0.265953
# acoustic_vector_7                                    -0.542753
# key_0                                                        1
# key_1                                                        0
# key_2                                                        0
# key_3                                                        0
# key_4                                                        0
# key_5                                                        0
# key_6                                                        0
# key_7                                                        0
# key_8                                                        0
# key_9                                                        0
# key_10                                                       0
# key_11                                                       0
# time_signature_0                                             0
# time_signature_1                                             0
# time_signature_3                                             0
# time_signature_4                                             1
# time_signature_5                                             0
# mode_major                                                   1
# mode_minor                                                   0
#
#                                                              4
# track_id                t_d6990e17-9c31-4b01-8559-47d9ce476df1
# duration                                            369.600006
# release_year                                              1951
# us_popularity_estimate                               99.991764
# acousticness                                          0.728831
# beat_strength                                         0.371328
# bounciness                                            0.335115
# danceability                                          0.483044
# dyn_range_mean                                        5.802681
# energy                                                0.721442
# flatness                                              0.976866
# instrumentalness                                           0.0
# liveness                                              0.189162
# loudness                                                -6.836
# mechanism                                              0.28125
# organism                                              0.723808
# speechiness                                           0.032043
# tempo                                                95.261002
# valence                                               0.562343
# acoustic_vector_0                                     0.131931
# acoustic_vector_1                                    -0.292523
# acoustic_vector_2                                    -0.174819
# acoustic_vector_3                                    -0.034422
# acoustic_vector_4                                     0.717229
# acoustic_vector_5                                    -0.016239
# acoustic_vector_6                                    -0.392694
# acoustic_vector_7                                    -0.455496
# key_0                                                        1
# key_1                                                        0
# key_2                                                        0
# key_3                                                        0
# key_4                                                        0
# key_5                                                        0
# key_6                                                        0
# key_7                                                        0
# key_8                                                        0
# key_9                                                        0
# key_10                                                       0
# key_11                                                       0
# time_signature_0                                             0
# time_signature_1                                             0
# time_signature_3                                             0
# time_signature_4                                             1
# time_signature_5                                             0
# mode_major                                                   1
# mode_minor                                                   0

# %%
log_df_dummy.head().T
# Out:
#                                                                                  0  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 1
# track_id_clean                              t_0479f24c-27d2-46d6-a00c-7ec928f2b539
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             0
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
#
#                                                                                  1  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 2
# track_id_clean                              t_9099cd7b-c238-47b7-9381-f23f2c1d1043
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
#
#                                                                                  2  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 3
# track_id_clean                              t_fc5df5ba-5396-49a7-8b29-35d0d28249e0
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
#
#                                                                                  3  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 4
# track_id_clean                              t_23cff8d6-d874-4b20-83dc-94e450e8aa20
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
#
#                                                                                  4
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 5
# track_id_clean                              t_64f3743c-f624-46bb-a579-0f3f9a07a123
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0

# %% [markdown]
# # **Calculate acoustic distance of each song from previous song(s)**
#
# The track information dataframe contains acoustic analysis and scores of each track on 8 acoustic features (see: https://benanne.github.io/2014/08/05/spotify-cnns.html). Therefore, within each session, I would like to calculate the ***distance*** of each track to the other tracks.
#
# The distance can be calculated in many ways, but here I would like to focus on *Euclidean* and *Mahalanobis* distances.
#
# Euclidean distance is simply the root-sum-square between two vectors. The Mahalanobis distance can be conceptualized as the Euclidean distance being normized to the multidimensional statistical variance.
#
# Both metrices were applied to calculate the distance of the current track to (1) the previous track and (2) the mean of all tracks in the session.

# %%
# extract the 8 acoustic feature of each track
df = log_df_dummy.merge(tf_df_dummy[['track_id','acoustic_vector_0', 'acoustic_vector_1', 'acoustic_vector_2', 'acoustic_vector_3','acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6','acoustic_vector_7']], left_on = 'track_id_clean', right_on = 'track_id')
df.sort_values(by = ['session_id', 'session_position'],inplace = True)
df.head().T
# Out:
#                                                                                0    \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 1
# track_id_clean                              t_0479f24c-27d2-46d6-a00c-7ec928f2b539
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             0
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# track_id                                    t_0479f24c-27d2-46d6-a00c-7ec928f2b539
# acoustic_vector_0                                                        -0.815775
# acoustic_vector_1                                                         0.386409
# acoustic_vector_2                                                          0.23016
# acoustic_vector_3                                                         0.028028
# acoustic_vector_4                                                        -0.333373
# acoustic_vector_5                                                         0.015452
# acoustic_vector_6                                                         -0.35359
# acoustic_vector_7                                                         0.205826
#
#                                                                                45   \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 2
# track_id_clean                              t_9099cd7b-c238-47b7-9381-f23f2c1d1043
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# track_id                                    t_9099cd7b-c238-47b7-9381-f23f2c1d1043
# acoustic_vector_0                                                        -0.713646
# acoustic_vector_1                                                         0.363718
# acoustic_vector_2                                                         0.310315
# acoustic_vector_3                                                        -0.042222
# acoustic_vector_4                                                        -0.383164
# acoustic_vector_5                                                         0.066357
# acoustic_vector_6                                                        -0.365308
# acoustic_vector_7                                                          0.15792
#
#                                                                                50   \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 3
# track_id_clean                              t_fc5df5ba-5396-49a7-8b29-35d0d28249e0
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# track_id                                    t_fc5df5ba-5396-49a7-8b29-35d0d28249e0
# acoustic_vector_0                                                        -0.742541
# acoustic_vector_1                                                         0.375599
# acoustic_vector_2                                                          0.25266
# acoustic_vector_3                                                        -0.049007
# acoustic_vector_4                                                        -0.299745
# acoustic_vector_5                                                         0.063341
# acoustic_vector_6                                                        -0.486689
# acoustic_vector_7                                                         0.181604
#
#                                                                                327  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 4
# track_id_clean                              t_23cff8d6-d874-4b20-83dc-94e450e8aa20
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# track_id                                    t_23cff8d6-d874-4b20-83dc-94e450e8aa20
# acoustic_vector_0                                                        -0.705116
# acoustic_vector_1                                                         0.317562
# acoustic_vector_2                                                         0.289141
# acoustic_vector_3                                                         -0.03892
# acoustic_vector_4                                                        -0.393358
# acoustic_vector_5                                                         0.092719
# acoustic_vector_6                                                        -0.364418
# acoustic_vector_7                                                         0.285603
#
#                                                                                353
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 5
# track_id_clean                              t_64f3743c-f624-46bb-a579-0f3f9a07a123
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# track_id                                    t_64f3743c-f624-46bb-a579-0f3f9a07a123
# acoustic_vector_0                                                        -0.868489
# acoustic_vector_1                                                          0.33128
# acoustic_vector_2                                                         0.210478
# acoustic_vector_3                                                          0.08474
# acoustic_vector_4                                                        -0.333287
# acoustic_vector_5                                                        -0.025706
# acoustic_vector_6                                                         -0.51035
# acoustic_vector_7                                                         0.182315

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 167880 entries, 0 to 134498
# Data columns (total 39 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   session_id                                  167880 non-null  object
#  1   session_position                            167880 non-null  int64
#  2   track_id_clean                              167880 non-null  object
#  3   skip_1                                      167880 non-null  bool
#  4   skip_2                                      167880 non-null  bool
#  5   skip_3                                      167880 non-null  bool
#  6   not_skipped                                 167880 non-null  bool
#  7   context_switch                              167880 non-null  int64
#  8   no_pause_before_play                        167880 non-null  int64
#  9   short_pause_before_play                     167880 non-null  int64
#  10  long_pause_before_play                      167880 non-null  int64
#  11  hist_user_behavior_is_shuffle               167880 non-null  bool
#  12  hour_of_day                                 167880 non-null  int64
#  13  date                                        167880 non-null  object
#  14  premium                                     167880 non-null  bool
#  15  hist_user_behavior_reason_start_appload     167880 non-null  uint8
#  16  hist_user_behavior_reason_start_backbtn     167880 non-null  uint8
#  17  hist_user_behavior_reason_start_clickrow    167880 non-null  uint8
#  18  hist_user_behavior_reason_start_endplay     167880 non-null  uint8
#  19  hist_user_behavior_reason_start_fwdbtn      167880 non-null  uint8
#  20  hist_user_behavior_reason_start_playbtn     167880 non-null  uint8
#  21  hist_user_behavior_reason_start_remote      167880 non-null  uint8
#  22  hist_user_behavior_reason_start_trackdone   167880 non-null  uint8
#  23  hist_user_behavior_reason_start_trackerror  167880 non-null  uint8
#  24  context_type_catalog                        167880 non-null  uint8
#  25  context_type_charts                         167880 non-null  uint8
#  26  context_type_editorial_playlist             167880 non-null  uint8
#  27  context_type_personalized_playlist          167880 non-null  uint8
#  28  context_type_radio                          167880 non-null  uint8
#  29  context_type_user_collection                167880 non-null  uint8
#  30  track_id                                    167880 non-null  object
#  31  acoustic_vector_0                           167880 non-null  float64
#  32  acoustic_vector_1                           167880 non-null  float64
#  33  acoustic_vector_2                           167880 non-null  float64
#  34  acoustic_vector_3                           167880 non-null  float64
#  35  acoustic_vector_4                           167880 non-null  float64
#  36  acoustic_vector_5                           167880 non-null  float64
#  37  acoustic_vector_6                           167880 non-null  float64
#  38  acoustic_vector_7                           167880 non-null  float64
# dtypes: bool(6), float64(8), int64(6), object(4), uint8(15)
# memory usage: 27.7+ MB

# %%
df.columns
# Out:
# Index(['session_id', 'session_position', 'track_id_clean', 'skip_1', 'skip_2',
#        'skip_3', 'not_skipped', 'context_switch', 'no_pause_before_play',
#        'short_pause_before_play', 'long_pause_before_play',
#        'hist_user_behavior_is_shuffle', 'hour_of_day', 'date', 'premium',
#        'hist_user_behavior_reason_start_appload',
#        'hist_user_behavior_reason_start_backbtn',
#        'hist_user_behavior_reason_start_clickrow',
#        'hist_user_behavior_reason_start_endplay',
#        'hist_user_behavior_reason_start_fwdbtn',
#        'hist_user_behavior_reason_start_playbtn',
#        'hist_user_behavior_reason_start_remote',
#        'hist_user_behavior_reason_start_trackdone',
#        'hist_user_behavior_reason_start_trackerror', 'context_type_catalog',
#        'context_type_charts', 'context_type_editorial_playlist',
#        'context_type_personalized_playlist', 'context_type_radio',
#        'context_type_user_collection', 'track_id', 'acoustic_vector_0',
#        'acoustic_vector_1', 'acoustic_vector_2', 'acoustic_vector_3',
#        'acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6',
#        'acoustic_vector_7'],
#       dtype='object')

# %%
session_id = pd.unique(df['session_id'])
print('number of sessions in this mini dataset:',len(session_id))
# Out:
# number of sessions in this mini dataset: 10000

# %%
# All the tracks within each session should be categorized as skipped or not
#df['session_id_not_skip_1'] = df['session_id'] * (df['skip_1']==False)
#df['session_id_not_skip_2'] = df['session_id'] * (df['skip_2']==False)
#df['session_id_not_skip_3'] = df['session_id'] * (df['skip_3']==False)
df['session_id_not_skipped'] = df['session_id'] * df['not_skipped']
df.head(10).T
# Out:
#                                                                                0    \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 1
# track_id_clean                              t_0479f24c-27d2-46d6-a00c-7ec928f2b539
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             0
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# track_id                                    t_0479f24c-27d2-46d6-a00c-7ec928f2b539
# acoustic_vector_0                                                        -0.815775
# acoustic_vector_1                                                         0.386409
# acoustic_vector_2                                                          0.23016
# acoustic_vector_3                                                         0.028028
# acoustic_vector_4                                                        -0.333373
# acoustic_vector_5                                                         0.015452
# acoustic_vector_6                                                         -0.35359
# acoustic_vector_7                                                         0.205826
# session_id_not_skipped                      0_00006f66-33e5-4de7-a324-2d18e439fc1e
#
#                                                                                45   \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 2
# track_id_clean                              t_9099cd7b-c238-47b7-9381-f23f2c1d1043
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# track_id                                    t_9099cd7b-c238-47b7-9381-f23f2c1d1043
# acoustic_vector_0                                                        -0.713646
# acoustic_vector_1                                                         0.363718
# acoustic_vector_2                                                         0.310315
# acoustic_vector_3                                                        -0.042222
# acoustic_vector_4                                                        -0.383164
# acoustic_vector_5                                                         0.066357
# acoustic_vector_6                                                        -0.365308
# acoustic_vector_7                                                          0.15792
# session_id_not_skipped                      0_00006f66-33e5-4de7-a324-2d18e439fc1e
#
#                                                                                50   \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 3
# track_id_clean                              t_fc5df5ba-5396-49a7-8b29-35d0d28249e0
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# track_id                                    t_fc5df5ba-5396-49a7-8b29-35d0d28249e0
# acoustic_vector_0                                                        -0.742541
# acoustic_vector_1                                                         0.375599
# acoustic_vector_2                                                          0.25266
# acoustic_vector_3                                                        -0.049007
# acoustic_vector_4                                                        -0.299745
# acoustic_vector_5                                                         0.063341
# acoustic_vector_6                                                        -0.486689
# acoustic_vector_7                                                         0.181604
# session_id_not_skipped                      0_00006f66-33e5-4de7-a324-2d18e439fc1e
#
#                                                                                327  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 4
# track_id_clean                              t_23cff8d6-d874-4b20-83dc-94e450e8aa20
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# track_id                                    t_23cff8d6-d874-4b20-83dc-94e450e8aa20
# acoustic_vector_0                                                        -0.705116
# acoustic_vector_1                                                         0.317562
# acoustic_vector_2                                                         0.289141
# acoustic_vector_3                                                         -0.03892
# acoustic_vector_4                                                        -0.393358
# acoustic_vector_5                                                         0.092719
# acoustic_vector_6                                                        -0.364418
# acoustic_vector_7                                                         0.285603
# session_id_not_skipped                      0_00006f66-33e5-4de7-a324-2d18e439fc1e
#
#                                                                                353  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 5
# track_id_clean                              t_64f3743c-f624-46bb-a579-0f3f9a07a123
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# track_id                                    t_64f3743c-f624-46bb-a579-0f3f9a07a123
# acoustic_vector_0                                                        -0.868489
# acoustic_vector_1                                                          0.33128
# acoustic_vector_2                                                         0.210478
# acoustic_vector_3                                                          0.08474
# acoustic_vector_4                                                        -0.333287
# acoustic_vector_5                                                        -0.025706
# acoustic_vector_6                                                         -0.51035
# acoustic_vector_7                                                         0.182315
# session_id_not_skipped                      0_00006f66-33e5-4de7-a324-2d18e439fc1e
#
#                                                                                475  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 6
# track_id_clean                              t_c815228b-3212-4f9e-9d4f-9cb19b248184
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                        True
# not_skipped                                                                  False
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# track_id                                    t_c815228b-3212-4f9e-9d4f-9cb19b248184
# acoustic_vector_0                                                        -0.817504
# acoustic_vector_1                                                         0.283297
# acoustic_vector_2                                                         0.387589
# acoustic_vector_3                                                         0.279636
# acoustic_vector_4                                                        -0.280334
# acoustic_vector_5                                                         0.117993
# acoustic_vector_6                                                         0.106159
# acoustic_vector_7                                                         0.311233
# session_id_not_skipped
#
#                                                                                537  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 7
# track_id_clean                              t_e23c19f5-4c32-4557-aa44-81372c2e3705
# skip_1                                                                        True
# skip_2                                                                        True
# skip_3                                                                        True
# not_skipped                                                                  False
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           1
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        0
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# track_id                                    t_e23c19f5-4c32-4557-aa44-81372c2e3705
# acoustic_vector_0                                                        -0.748412
# acoustic_vector_1                                                         0.321976
# acoustic_vector_2                                                         0.237488
# acoustic_vector_3                                                          0.00348
# acoustic_vector_4                                                        -0.315287
# acoustic_vector_5                                                         0.032431
# acoustic_vector_6                                                        -0.464694
# acoustic_vector_7                                                         0.200836
# session_id_not_skipped
#
#                                                                                540  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 8
# track_id_clean                              t_0be6eced-f56f-48bd-8086-f2e0b760fdee
# skip_1                                                                        True
# skip_2                                                                        True
# skip_3                                                                        True
# not_skipped                                                                  False
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           1
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        0
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# track_id                                    t_0be6eced-f56f-48bd-8086-f2e0b760fdee
# acoustic_vector_0                                                        -0.921928
# acoustic_vector_1                                                          0.35974
# acoustic_vector_2                                                         0.293674
# acoustic_vector_3                                                         0.115302
# acoustic_vector_4                                                        -0.274987
# acoustic_vector_5                                                         0.043193
# acoustic_vector_6                                                        -0.444351
# acoustic_vector_7                                                         0.211909
# session_id_not_skipped
#
#                                                                                541  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 9
# track_id_clean                              t_f3ecbd3b-9e8e-4557-b8e0-39cfcd7e65dd
# skip_1                                                                       False
# skip_2                                                                        True
# skip_3                                                                        True
# not_skipped                                                                  False
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           1
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        0
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# track_id                                    t_f3ecbd3b-9e8e-4557-b8e0-39cfcd7e65dd
# acoustic_vector_0                                                        -0.744412
# acoustic_vector_1                                                           0.3087
# acoustic_vector_2                                                         0.230126
# acoustic_vector_3                                                         0.066493
# acoustic_vector_4                                                        -0.242549
# acoustic_vector_5                                                          0.02537
# acoustic_vector_6                                                         -0.40321
# acoustic_vector_7                                                          0.15935
# session_id_not_skipped
#
#                                                                                601
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                10
# track_id_clean                              t_2af4dfa0-7df3-4b7e-b7ab-353ba48237f9
# skip_1                                                                        True
# skip_2                                                                        True
# skip_3                                                                        True
# not_skipped                                                                  False
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           1
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        0
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# track_id                                    t_2af4dfa0-7df3-4b7e-b7ab-353ba48237f9
# acoustic_vector_0                                                        -0.647221
# acoustic_vector_1                                                         0.316101
# acoustic_vector_2                                                         0.251329
# acoustic_vector_3                                                        -0.041532
# acoustic_vector_4                                                        -0.252359
# acoustic_vector_5                                                         0.059971
# acoustic_vector_6                                                        -0.313696
# acoustic_vector_7                                                         0.126421
# session_id_not_skipped

# %%
# # calculate the mahalanobis distance and the rmse of each track's acoustic factor to the mean of each session
# from scipy.spatial import distance
# singular_s_id = []

# for s_id in session_id:
#   temp_data = df.loc[df['session_id'] == s_id,['acoustic_vector_0', 'acoustic_vector_1', 'acoustic_vector_2', 'acoustic_vector_3','acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6','acoustic_vector_7']]
#   temp_data_noskip = df.loc[(df['session_id'] == s_id) & (df['not_skipped'] == True),['acoustic_vector_0', 'acoustic_vector_1', 'acoustic_vector_2', 'acoustic_vector_3','acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6','acoustic_vector_7']]
  

#   acou_center = temp_data.mean(axis = 0) # the multidimensional mean of the acoustic factors
#   acou_center_noskip = temp_data_noskip.mean(axis = 0) # the multidimensional mean of the acoustic factors among the non-skipped tracks
  
#   df.loc[temp_data.index, 'acous_rmse_to_mean'] = np.sqrt(np.square(temp_data - acou_center).sum(axis = 1))
#   df.loc[temp_data_noskip.index, 'acous_rmse_to_mean_noskip'] = np.sqrt(np.square(temp_data_noskip - acou_center_noskip).sum(axis = 1))
#   df.loc[temp_data.index, 'acous_rmse_to_previous'] = np.sqrt(np.square(temp_data.diff()).sum(axis = 1))
#   iv = []
#   try:
#     iv = np.linalg.inv(np.array(np.cov(temp_data, rowvar = False))) # compute the covariance matrix, and then take its inverse
#   except: # The inverse of the covariance matrix was singular for some sessions due to whatever reason. In those cases, adding a small Gaussian noise can resolve the issue.
#     iv = np.linalg.inv(np.array(np.cov(temp_data + np.random.normal(0,1e-5,temp_data.shape), rowvar = False)))
#     singular_s_id.append(s_id)

#   for n in range(len(temp_data)):
#       df.loc[temp_data.index[n], 'acous_mah_dist_to_mean'] = distance.mahalanobis(temp_data.iloc[n,:], acou_center, iv)
#       if n > 0:
#         df.loc[temp_data.index[n], 'acous_mah_dist_to_previous'] = distance.mahalanobis(temp_data.iloc[n,:], temp_data.iloc[n-1,:], iv)

# %%
# df.head(10)

# %%
# # It appears that the singular sessions have small number of tracks, which mathematically makes sense.
# for s_id in singular_s_id:
#   temp_data = df.loc[df['session_id'] == s_id,['acoustic_vector_0', 'acoustic_vector_1', 'acoustic_vector_2', 'acoustic_vector_3','acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6','acoustic_vector_7']]
#   print(len(temp_data))

# %%
# # print out a singular session's data for visual inspection

# temp_singular_data = df.loc[df['session_id'] == singular_s_id[0],['acoustic_vector_0', 'acoustic_vector_1', 'acoustic_vector_2', 'acoustic_vector_3','acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6','acoustic_vector_7']]

# import seaborn as sns
# import matplotlib.pylab as plt
# %matplotlib inline
  
# ax = sns.heatmap( temp_singular_data , linewidth = 0.5 , cmap = 'coolwarm' )
  
# plt.title( singular_s_id[0] )
# plt.show()

# %%
# take out the acoustic feature columns for now, as it will be combined back later.
log_df_dummy2 = df.drop(columns = ['acoustic_vector_0', 'acoustic_vector_1', 'acoustic_vector_2', 'acoustic_vector_3','acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6','acoustic_vector_7'])

# %%
df.columns
# Out:
# Index(['session_id', 'session_position', 'track_id_clean', 'skip_1', 'skip_2',
#        'skip_3', 'not_skipped', 'context_switch', 'no_pause_before_play',
#        'short_pause_before_play', 'long_pause_before_play',
#        'hist_user_behavior_is_shuffle', 'hour_of_day', 'date', 'premium',
#        'hist_user_behavior_reason_start_appload',
#        'hist_user_behavior_reason_start_backbtn',
#        'hist_user_behavior_reason_start_clickrow',
#        'hist_user_behavior_reason_start_endplay',
#        'hist_user_behavior_reason_start_fwdbtn',
#        'hist_user_behavior_reason_start_playbtn',
#        'hist_user_behavior_reason_start_remote',
#        'hist_user_behavior_reason_start_trackdone',
#        'hist_user_behavior_reason_start_trackerror', 'context_type_catalog',
#        'context_type_charts', 'context_type_editorial_playlist',
#        'context_type_personalized_playlist', 'context_type_radio',
#        'context_type_user_collection', 'track_id', 'acoustic_vector_0',
#        'acoustic_vector_1', 'acoustic_vector_2', 'acoustic_vector_3',
#        'acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6',
#        'acoustic_vector_7', 'session_id_not_skipped'],
#       dtype='object')

# %% [markdown]
# # **Use featuretool to do automatic feature engineering**

# %%
#First, initializing an EntitySet with a name
es = ft.EntitySet(id="spotify_data")

# %%
from woodwork.logical_types import Categorical, PostalCode

es = es.add_dataframe(
    dataframe_name="tf",
    dataframe=tf_df_dummy,
    index="track_id",
)

es
# Out:
# Entityset: spotify_data
#   DataFrames:
#     tf [Rows: 50704, Columns: 46]
#   Relationships:
#     No relationships

# %%
es['tf'].ww.schema
# Out:
#                        Logical Type Semantic Tag(s)
# Column
# track_id                    Unknown       ['index']
# duration                     Double     ['numeric']
# release_year                Integer     ['numeric']
# us_popularity_estimate       Double     ['numeric']
# acousticness                 Double     ['numeric']
# beat_strength                Double     ['numeric']
# bounciness                   Double     ['numeric']
# danceability                 Double     ['numeric']
# dyn_range_mean               Double     ['numeric']
# energy                       Double     ['numeric']
# flatness                     Double     ['numeric']
# instrumentalness             Double     ['numeric']
# liveness                     Double     ['numeric']
# loudness                     Double     ['numeric']
# mechanism                    Double     ['numeric']
# organism                     Double     ['numeric']
# speechiness                  Double     ['numeric']
# tempo                        Double     ['numeric']
# valence                      Double     ['numeric']
# acoustic_vector_0            Double     ['numeric']
# acoustic_vector_1            Double     ['numeric']
# acoustic_vector_2            Double     ['numeric']
# acoustic_vector_3            Double     ['numeric']
# acoustic_vector_4            Double     ['numeric']
# acoustic_vector_5            Double     ['numeric']
# acoustic_vector_6            Double     ['numeric']
# acoustic_vector_7            Double     ['numeric']
# key_0                       Integer     ['numeric']
# key_1                       Integer     ['numeric']
# key_2                       Integer     ['numeric']
# key_3                       Integer     ['numeric']
# key_4                       Integer     ['numeric']
# key_5                       Integer     ['numeric']
# key_6                       Integer     ['numeric']
# key_7                       Integer     ['numeric']
# key_8                       Integer     ['numeric']
# key_9                       Integer     ['numeric']
# key_10                      Integer     ['numeric']
# key_11                      Integer     ['numeric']
# time_signature_0            Integer     ['numeric']
# time_signature_1            Integer     ['numeric']
# time_signature_3            Integer     ['numeric']
# time_signature_4            Integer     ['numeric']
# time_signature_5            Integer     ['numeric']
# mode_major                  Integer     ['numeric']
# mode_minor                  Integer     ['numeric']

# %%
# add dataframe
# the 'session_position' contains order information within each session

es = es.add_dataframe(
    dataframe_name="log", dataframe=log_df_dummy2, make_index = True, index="event_id", time_index="session_position",
)

es
# Out:
# Entityset: spotify_data
#   DataFrames:
#     tf [Rows: 50704, Columns: 46]
#     log [Rows: 167880, Columns: 33]
#   Relationships:
#     No relationships

# %%
es['log'].ww.schema
# Out:
#                                            Logical Type  \
# Column
# event_id                                        Integer
# session_id                                  Categorical
# session_position                                Integer
# track_id_clean                                  Unknown
# skip_1                                          Boolean
# skip_2                                          Boolean
# skip_3                                          Boolean
# not_skipped                                     Boolean
# context_switch                                  Integer
# no_pause_before_play                            Integer
# short_pause_before_play                         Integer
# long_pause_before_play                          Integer
# hist_user_behavior_is_shuffle                   Boolean
# hour_of_day                                     Integer
# date                                           Datetime
# premium                                         Boolean
# hist_user_behavior_reason_start_appload         Integer
# hist_user_behavior_reason_start_backbtn         Integer
# hist_user_behavior_reason_start_clickrow        Integer
# hist_user_behavior_reason_start_endplay         Integer
# hist_user_behavior_reason_start_fwdbtn          Integer
# hist_user_behavior_reason_start_playbtn         Integer
# hist_user_behavior_reason_start_remote          Integer
# hist_user_behavior_reason_start_trackdone       Integer
# hist_user_behavior_reason_start_trackerror      Integer
# context_type_catalog                            Integer
# context_type_charts                             Integer
# context_type_editorial_playlist                 Integer
# context_type_personalized_playlist              Integer
# context_type_radio                              Integer
# context_type_user_collection                    Integer
# track_id                                        Unknown
# session_id_not_skipped                      Categorical
#
#                                                       Semantic Tag(s)
# Column
# event_id                                                    ['index']
# session_id                                               ['category']
# session_position                            ['time_index', 'numeric']
# track_id_clean                                                     []
# skip_1                                                             []
# skip_2                                                             []
# skip_3                                                             []
# not_skipped                                                        []
# context_switch                                            ['numeric']
# no_pause_before_play                                      ['numeric']
# short_pause_before_play                                   ['numeric']
# long_pause_before_play                                    ['numeric']
# hist_user_behavior_is_shuffle                                      []
# hour_of_day                                               ['numeric']
# date                                                               []
# premium                                                            []
# hist_user_behavior_reason_start_appload                   ['numeric']
# hist_user_behavior_reason_start_backbtn                   ['numeric']
# hist_user_behavior_reason_start_clickrow                  ['numeric']
# hist_user_behavior_reason_start_endplay                   ['numeric']
# hist_user_behavior_reason_start_fwdbtn                    ['numeric']
# hist_user_behavior_reason_start_playbtn                   ['numeric']
# hist_user_behavior_reason_start_remote                    ['numeric']
# hist_user_behavior_reason_start_trackdone                 ['numeric']
# hist_user_behavior_reason_start_trackerror                ['numeric']
# context_type_catalog                                      ['numeric']
# context_type_charts                                       ['numeric']
# context_type_editorial_playlist                           ['numeric']
# context_type_personalized_playlist                        ['numeric']
# context_type_radio                                        ['numeric']
# context_type_user_collection                              ['numeric']
# track_id                                                           []
# session_id_not_skipped                                   ['category']

# %%
# When two DataFrames have a one-to-many relationship, we call the “one” DataFrame, the “parent DataFrame”. A relationship between a parent and child is defined like this:
# (parent_dataframe, parent_column, child_dataframe, child_column)
es = es.add_relationship("tf", "track_id", "log", "track_id_clean")
es
# Out:
# Entityset: spotify_data
#   DataFrames:
#     tf [Rows: 50704, Columns: 46]
#     log [Rows: 167880, Columns: 33]
#   Relationships:
#     log.track_id_clean -> tf.track_id

# %%
# turn on "features_only = True" to experiment with the function without computing the feature_matrix
feature_defs_test = ft.dfs(entityset=es,
                        target_dataframe_name="log",
                        groupby_trans_primitives=["Diff","CumSum", "CumCount", "CumMean", "CumMin", "CumMax"],
                        agg_primitives=[],
                        trans_primitives=[],
                        primitive_options={"diff": {"include_groupby_columns": {"log": ["session_id","session_id_not_skipped"]},"ignore_groupby_dataframes": ["tf"]},
                                        "cum_sum": {"include_groupby_columns": {"log": ["session_id","session_id_not_skipped"]},"ignore_groupby_dataframes": ["tf"]},
                                        "cum_count": {"include_groupby_columns": {"log": ["session_id","session_id_not_skipped"]},"ignore_groupby_dataframes": ["tf"]},
                                        "cum_mean": {"include_groupby_columns": {"log": ["session_id","session_id_not_skipped"]},"ignore_groupby_dataframes": ["tf"]},
                                        "cum_min": {"include_groupby_columns": {"log": ["session_id","session_id_not_skipped"]},"ignore_groupby_dataframes": ["tf"]},
                                        "cum_max": {"include_groupby_columns": {"log": ["session_id","session_id_not_skipped"]},"ignore_groupby_dataframes": ["tf"]}},
                        features_only = True,
                        n_jobs=-1)

feature_defs_test
# Out:
# [<Feature: session_id>,
#  <Feature: session_position>,
#  <Feature: skip_1>,
#  <Feature: skip_2>,
#  <Feature: skip_3>,
#  <Feature: not_skipped>,
#  <Feature: context_switch>,
#  <Feature: no_pause_before_play>,
#  <Feature: short_pause_before_play>,
#  <Feature: long_pause_before_play>,
#  <Feature: hist_user_behavior_is_shuffle>,
#  <Feature: hour_of_day>,
#  <Feature: premium>,
#  <Feature: hist_user_behavior_reason_start_appload>,
#  <Feature: hist_user_behavior_reason_start_backbtn>,
#  <Feature: hist_user_behavior_reason_start_clickrow>,
#  <Feature: hist_user_behavior_reason_start_endplay>,
#  <Feature: hist_user_behavior_reason_start_fwdbtn>,
#  <Feature: hist_user_behavior_reason_start_playbtn>,
#  <Feature: hist_user_behavior_reason_start_remote>,
#  <Feature: hist_user_behavior_reason_start_trackdone>,
#  <Feature: hist_user_behavior_reason_start_trackerror>,
#  <Feature: context_type_catalog>,
#  <Feature: context_type_charts>,
#  <Feature: context_type_editorial_playlist>,
#  <Feature: context_type_personalized_playlist>,
#  <Feature: context_type_radio>,
#  <Feature: context_type_user_collection>,
#  <Feature: session_id_not_skipped>,
#  <Feature: CUM_COUNT(session_id) by session_id>,
#  <Feature: CUM_COUNT(session_id) by session_id_not_skipped>,
#  <Feature: CUM_COUNT(session_id_not_skipped) by session_id>,
#  <Feature: CUM_COUNT(session_id_not_skipped) by session_id_not_skipped>,
#  <Feature: CUM_COUNT(track_id_clean) by session_id>,
#  <Feature: CUM_COUNT(track_id_clean) by session_id_not_skipped>,
#  <Feature: CUM_MAX(context_switch) by session_id>,
#  <Feature: CUM_MAX(context_switch) by session_id_not_skipped>,
#  <Feature: CUM_MAX(context_type_catalog) by session_id>,
#  <Feature: CUM_MAX(context_type_catalog) by session_id_not_skipped>,
#  <Feature: CUM_MAX(context_type_charts) by session_id>,
#  <Feature: CUM_MAX(context_type_charts) by session_id_not_skipped>,
#  <Feature: CUM_MAX(context_type_editorial_playlist) by session_id>,
#  <Feature: CUM_MAX(context_type_editorial_playlist) by session_id_not_skipped>,
#  <Feature: CUM_MAX(context_type_personalized_playlist) by session_id>,
#  <Feature: CUM_MAX(context_type_personalized_playlist) by session_id_not_skipped>,
#  <Feature: CUM_MAX(context_type_radio) by session_id>,
#  <Feature: CUM_MAX(context_type_radio) by session_id_not_skipped>,
#  <Feature: CUM_MAX(context_type_user_collection) by session_id>,
#  <Feature: CUM_MAX(context_type_user_collection) by session_id_not_skipped>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_appload) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_appload) by session_id_not_skipped>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_backbtn) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_backbtn) by session_id_not_skipped>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_clickrow) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_clickrow) by session_id_not_skipped>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_endplay) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_endplay) by session_id_not_skipped>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_fwdbtn) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_fwdbtn) by session_id_not_skipped>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_playbtn) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_playbtn) by session_id_not_skipped>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_remote) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_remote) by session_id_not_skipped>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_trackdone) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_trackdone) by session_id_not_skipped>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_trackerror) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_trackerror) by session_id_not_skipped>,
#  <Feature: CUM_MAX(hour_of_day) by session_id>,
#  <Feature: CUM_MAX(hour_of_day) by session_id_not_skipped>,
#  <Feature: CUM_MAX(long_pause_before_play) by session_id>,
#  <Feature: CUM_MAX(long_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_MAX(no_pause_before_play) by session_id>,
#  <Feature: CUM_MAX(no_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_MAX(session_position) by session_id>,
#  <Feature: CUM_MAX(session_position) by session_id_not_skipped>,
#  <Feature: CUM_MAX(short_pause_before_play) by session_id>,
#  <Feature: CUM_MAX(short_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(context_switch) by session_id>,
#  <Feature: CUM_MEAN(context_switch) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(context_type_catalog) by session_id>,
#  <Feature: CUM_MEAN(context_type_catalog) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(context_type_charts) by session_id>,
#  <Feature: CUM_MEAN(context_type_charts) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(context_type_editorial_playlist) by session_id>,
#  <Feature: CUM_MEAN(context_type_editorial_playlist) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(context_type_personalized_playlist) by session_id>,
#  <Feature: CUM_MEAN(context_type_personalized_playlist) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(context_type_radio) by session_id>,
#  <Feature: CUM_MEAN(context_type_radio) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(context_type_user_collection) by session_id>,
#  <Feature: CUM_MEAN(context_type_user_collection) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_appload) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_appload) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_backbtn) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_backbtn) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_clickrow) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_clickrow) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_endplay) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_endplay) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_fwdbtn) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_fwdbtn) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_playbtn) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_playbtn) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_remote) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_remote) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_trackdone) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_trackdone) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_trackerror) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_trackerror) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(hour_of_day) by session_id>,
#  <Feature: CUM_MEAN(hour_of_day) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(long_pause_before_play) by session_id>,
#  <Feature: CUM_MEAN(long_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(no_pause_before_play) by session_id>,
#  <Feature: CUM_MEAN(no_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(session_position) by session_id>,
#  <Feature: CUM_MEAN(session_position) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(short_pause_before_play) by session_id>,
#  <Feature: CUM_MEAN(short_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_MIN(context_switch) by session_id>,
#  <Feature: CUM_MIN(context_switch) by session_id_not_skipped>,
#  <Feature: CUM_MIN(context_type_catalog) by session_id>,
#  <Feature: CUM_MIN(context_type_catalog) by session_id_not_skipped>,
#  <Feature: CUM_MIN(context_type_charts) by session_id>,
#  <Feature: CUM_MIN(context_type_charts) by session_id_not_skipped>,
#  <Feature: CUM_MIN(context_type_editorial_playlist) by session_id>,
#  <Feature: CUM_MIN(context_type_editorial_playlist) by session_id_not_skipped>,
#  <Feature: CUM_MIN(context_type_personalized_playlist) by session_id>,
#  <Feature: CUM_MIN(context_type_personalized_playlist) by session_id_not_skipped>,
#  <Feature: CUM_MIN(context_type_radio) by session_id>,
#  <Feature: CUM_MIN(context_type_radio) by session_id_not_skipped>,
#  <Feature: CUM_MIN(context_type_user_collection) by session_id>,
#  <Feature: CUM_MIN(context_type_user_collection) by session_id_not_skipped>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_appload) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_appload) by session_id_not_skipped>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_backbtn) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_backbtn) by session_id_not_skipped>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_clickrow) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_clickrow) by session_id_not_skipped>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_endplay) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_endplay) by session_id_not_skipped>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_fwdbtn) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_fwdbtn) by session_id_not_skipped>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_playbtn) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_playbtn) by session_id_not_skipped>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_remote) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_remote) by session_id_not_skipped>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_trackdone) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_trackdone) by session_id_not_skipped>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_trackerror) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_trackerror) by session_id_not_skipped>,
#  <Feature: CUM_MIN(hour_of_day) by session_id>,
#  <Feature: CUM_MIN(hour_of_day) by session_id_not_skipped>,
#  <Feature: CUM_MIN(long_pause_before_play) by session_id>,
#  <Feature: CUM_MIN(long_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_MIN(no_pause_before_play) by session_id>,
#  <Feature: CUM_MIN(no_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_MIN(session_position) by session_id>,
#  <Feature: CUM_MIN(session_position) by session_id_not_skipped>,
#  <Feature: CUM_MIN(short_pause_before_play) by session_id>,
#  <Feature: CUM_MIN(short_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_SUM(context_switch) by session_id>,
#  <Feature: CUM_SUM(context_switch) by session_id_not_skipped>,
#  <Feature: CUM_SUM(context_type_catalog) by session_id>,
#  <Feature: CUM_SUM(context_type_catalog) by session_id_not_skipped>,
#  <Feature: CUM_SUM(context_type_charts) by session_id>,
#  <Feature: CUM_SUM(context_type_charts) by session_id_not_skipped>,
#  <Feature: CUM_SUM(context_type_editorial_playlist) by session_id>,
#  <Feature: CUM_SUM(context_type_editorial_playlist) by session_id_not_skipped>,
#  <Feature: CUM_SUM(context_type_personalized_playlist) by session_id>,
#  <Feature: CUM_SUM(context_type_personalized_playlist) by session_id_not_skipped>,
#  <Feature: CUM_SUM(context_type_radio) by session_id>,
#  <Feature: CUM_SUM(context_type_radio) by session_id_not_skipped>,
#  <Feature: CUM_SUM(context_type_user_collection) by session_id>,
#  <Feature: CUM_SUM(context_type_user_collection) by session_id_not_skipped>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_appload) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_appload) by session_id_not_skipped>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_backbtn) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_backbtn) by session_id_not_skipped>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_clickrow) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_clickrow) by session_id_not_skipped>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_endplay) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_endplay) by session_id_not_skipped>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_fwdbtn) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_fwdbtn) by session_id_not_skipped>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_playbtn) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_playbtn) by session_id_not_skipped>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_remote) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_remote) by session_id_not_skipped>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_trackdone) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_trackdone) by session_id_not_skipped>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_trackerror) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_trackerror) by session_id_not_skipped>,
#  <Feature: CUM_SUM(hour_of_day) by session_id>,
#  <Feature: CUM_SUM(hour_of_day) by session_id_not_skipped>,
#  <Feature: CUM_SUM(long_pause_before_play) by session_id>,
#  <Feature: CUM_SUM(long_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_SUM(no_pause_before_play) by session_id>,
#  <Feature: CUM_SUM(no_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_SUM(session_position) by session_id>,
#  <Feature: CUM_SUM(session_position) by session_id_not_skipped>,
#  <Feature: CUM_SUM(short_pause_before_play) by session_id>,
#  <Feature: CUM_SUM(short_pause_before_play) by session_id_not_skipped>,
#  <Feature: DIFF(context_switch) by session_id>,
#  <Feature: DIFF(context_switch) by session_id_not_skipped>,
#  <Feature: DIFF(context_type_catalog) by session_id>,
#  <Feature: DIFF(context_type_catalog) by session_id_not_skipped>,
#  <Feature: DIFF(context_type_charts) by session_id>,
#  <Feature: DIFF(context_type_charts) by session_id_not_skipped>,
#  <Feature: DIFF(context_type_editorial_playlist) by session_id>,
#  <Feature: DIFF(context_type_editorial_playlist) by session_id_not_skipped>,
#  <Feature: DIFF(context_type_personalized_playlist) by session_id>,
#  <Feature: DIFF(context_type_personalized_playlist) by session_id_not_skipped>,
#  <Feature: DIFF(context_type_radio) by session_id>,
#  <Feature: DIFF(context_type_radio) by session_id_not_skipped>,
#  <Feature: DIFF(context_type_user_collection) by session_id>,
#  <Feature: DIFF(context_type_user_collection) by session_id_not_skipped>,
#  <Feature: DIFF(hist_user_behavior_reason_start_appload) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_appload) by session_id_not_skipped>,
#  <Feature: DIFF(hist_user_behavior_reason_start_backbtn) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_backbtn) by session_id_not_skipped>,
#  <Feature: DIFF(hist_user_behavior_reason_start_clickrow) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_clickrow) by session_id_not_skipped>,
#  <Feature: DIFF(hist_user_behavior_reason_start_endplay) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_endplay) by session_id_not_skipped>,
#  <Feature: DIFF(hist_user_behavior_reason_start_fwdbtn) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_fwdbtn) by session_id_not_skipped>,
#  <Feature: DIFF(hist_user_behavior_reason_start_playbtn) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_playbtn) by session_id_not_skipped>,
#  <Feature: DIFF(hist_user_behavior_reason_start_remote) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_remote) by session_id_not_skipped>,
#  <Feature: DIFF(hist_user_behavior_reason_start_trackdone) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_trackdone) by session_id_not_skipped>,
#  <Feature: DIFF(hist_user_behavior_reason_start_trackerror) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_trackerror) by session_id_not_skipped>,
#  <Feature: DIFF(hour_of_day) by session_id>,
#  <Feature: DIFF(hour_of_day) by session_id_not_skipped>,
#  <Feature: DIFF(long_pause_before_play) by session_id>,
#  <Feature: DIFF(long_pause_before_play) by session_id_not_skipped>,
#  <Feature: DIFF(no_pause_before_play) by session_id>,
#  <Feature: DIFF(no_pause_before_play) by session_id_not_skipped>,
#  <Feature: DIFF(session_position) by session_id>,
#  <Feature: DIFF(session_position) by session_id_not_skipped>,
#  <Feature: DIFF(short_pause_before_play) by session_id>,
#  <Feature: DIFF(short_pause_before_play) by session_id_not_skipped>,
#  <Feature: tf.duration>,
#  <Feature: tf.release_year>,
#  <Feature: tf.us_popularity_estimate>,
#  <Feature: tf.acousticness>,
#  <Feature: tf.beat_strength>,
#  <Feature: tf.bounciness>,
#  <Feature: tf.danceability>,
#  <Feature: tf.dyn_range_mean>,
#  <Feature: tf.energy>,
#  <Feature: tf.flatness>,
#  <Feature: tf.instrumentalness>,
#  <Feature: tf.liveness>,
#  <Feature: tf.loudness>,
#  <Feature: tf.mechanism>,
#  <Feature: tf.organism>,
#  <Feature: tf.speechiness>,
#  <Feature: tf.tempo>,
#  <Feature: tf.valence>,
#  <Feature: tf.acoustic_vector_0>,
#  <Feature: tf.acoustic_vector_1>,
#  <Feature: tf.acoustic_vector_2>,
#  <Feature: tf.acoustic_vector_3>,
#  <Feature: tf.acoustic_vector_4>,
#  <Feature: tf.acoustic_vector_5>,
#  <Feature: tf.acoustic_vector_6>,
#  <Feature: tf.acoustic_vector_7>,
#  <Feature: tf.key_0>,
#  <Feature: tf.key_1>,
#  <Feature: tf.key_2>,
#  <Feature: tf.key_3>,
#  <Feature: tf.key_4>,
#  <Feature: tf.key_5>,
#  <Feature: tf.key_6>,
#  <Feature: tf.key_7>,
#  <Feature: tf.key_8>,
#  <Feature: tf.key_9>,
#  <Feature: tf.key_10>,
#  <Feature: tf.key_11>,
#  <Feature: tf.time_signature_0>,
#  <Feature: tf.time_signature_1>,
#  <Feature: tf.time_signature_3>,
#  <Feature: tf.time_signature_4>,
#  <Feature: tf.time_signature_5>,
#  <Feature: tf.mode_major>,
#  <Feature: tf.mode_minor>,
#  <Feature: CUM_MAX(tf.acoustic_vector_0) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_0) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.acoustic_vector_1) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_1) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.acoustic_vector_2) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_2) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.acoustic_vector_3) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_3) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.acoustic_vector_4) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_4) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.acoustic_vector_5) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_5) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.acoustic_vector_6) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_6) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.acoustic_vector_7) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_7) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.acousticness) by session_id>,
#  <Feature: CUM_MAX(tf.acousticness) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.beat_strength) by session_id>,
#  <Feature: CUM_MAX(tf.beat_strength) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.bounciness) by session_id>,
#  <Feature: CUM_MAX(tf.bounciness) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.danceability) by session_id>,
#  <Feature: CUM_MAX(tf.danceability) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.duration) by session_id>,
#  <Feature: CUM_MAX(tf.duration) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.dyn_range_mean) by session_id>,
#  <Feature: CUM_MAX(tf.dyn_range_mean) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.energy) by session_id>,
#  <Feature: CUM_MAX(tf.energy) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.flatness) by session_id>,
#  <Feature: CUM_MAX(tf.flatness) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.instrumentalness) by session_id>,
#  <Feature: CUM_MAX(tf.instrumentalness) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_0) by session_id>,
#  <Feature: CUM_MAX(tf.key_0) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_1) by session_id>,
#  <Feature: CUM_MAX(tf.key_1) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_10) by session_id>,
#  <Feature: CUM_MAX(tf.key_10) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_11) by session_id>,
#  <Feature: CUM_MAX(tf.key_11) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_2) by session_id>,
#  <Feature: CUM_MAX(tf.key_2) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_3) by session_id>,
#  <Feature: CUM_MAX(tf.key_3) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_4) by session_id>,
#  <Feature: CUM_MAX(tf.key_4) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_5) by session_id>,
#  <Feature: CUM_MAX(tf.key_5) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_6) by session_id>,
#  <Feature: CUM_MAX(tf.key_6) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_7) by session_id>,
#  <Feature: CUM_MAX(tf.key_7) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_8) by session_id>,
#  <Feature: CUM_MAX(tf.key_8) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_9) by session_id>,
#  <Feature: CUM_MAX(tf.key_9) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.liveness) by session_id>,
#  <Feature: CUM_MAX(tf.liveness) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.loudness) by session_id>,
#  <Feature: CUM_MAX(tf.loudness) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.mechanism) by session_id>,
#  <Feature: CUM_MAX(tf.mechanism) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.mode_major) by session_id>,
#  <Feature: CUM_MAX(tf.mode_major) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.mode_minor) by session_id>,
#  <Feature: CUM_MAX(tf.mode_minor) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.organism) by session_id>,
#  <Feature: CUM_MAX(tf.organism) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.release_year) by session_id>,
#  <Feature: CUM_MAX(tf.release_year) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.speechiness) by session_id>,
#  <Feature: CUM_MAX(tf.speechiness) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.tempo) by session_id>,
#  <Feature: CUM_MAX(tf.tempo) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.time_signature_0) by session_id>,
#  <Feature: CUM_MAX(tf.time_signature_0) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.time_signature_1) by session_id>,
#  <Feature: CUM_MAX(tf.time_signature_1) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.time_signature_3) by session_id>,
#  <Feature: CUM_MAX(tf.time_signature_3) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.time_signature_4) by session_id>,
#  <Feature: CUM_MAX(tf.time_signature_4) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.time_signature_5) by session_id>,
#  <Feature: CUM_MAX(tf.time_signature_5) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.us_popularity_estimate) by session_id>,
#  <Feature: CUM_MAX(tf.us_popularity_estimate) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.valence) by session_id>,
#  <Feature: CUM_MAX(tf.valence) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_0) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_0) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_1) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_1) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_2) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_2) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_3) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_3) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_4) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_4) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_5) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_5) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_6) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_6) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_7) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_7) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.acousticness) by session_id>,
#  <Feature: CUM_MEAN(tf.acousticness) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.beat_strength) by session_id>,
#  <Feature: CUM_MEAN(tf.beat_strength) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.bounciness) by session_id>,
#  <Feature: CUM_MEAN(tf.bounciness) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.danceability) by session_id>,
#  <Feature: CUM_MEAN(tf.danceability) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.duration) by session_id>,
#  <Feature: CUM_MEAN(tf.duration) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.dyn_range_mean) by session_id>,
#  <Feature: CUM_MEAN(tf.dyn_range_mean) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.energy) by session_id>,
#  <Feature: CUM_MEAN(tf.energy) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.flatness) by session_id>,
#  <Feature: CUM_MEAN(tf.flatness) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.instrumentalness) by session_id>,
#  <Feature: CUM_MEAN(tf.instrumentalness) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_0) by session_id>,
#  <Feature: CUM_MEAN(tf.key_0) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_1) by session_id>,
#  <Feature: CUM_MEAN(tf.key_1) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_10) by session_id>,
#  <Feature: CUM_MEAN(tf.key_10) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_11) by session_id>,
#  <Feature: CUM_MEAN(tf.key_11) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_2) by session_id>,
#  <Feature: CUM_MEAN(tf.key_2) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_3) by session_id>,
#  <Feature: CUM_MEAN(tf.key_3) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_4) by session_id>,
#  <Feature: CUM_MEAN(tf.key_4) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_5) by session_id>,
#  <Feature: CUM_MEAN(tf.key_5) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_6) by session_id>,
#  <Feature: CUM_MEAN(tf.key_6) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_7) by session_id>,
#  <Feature: CUM_MEAN(tf.key_7) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_8) by session_id>,
#  <Feature: CUM_MEAN(tf.key_8) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_9) by session_id>,
#  <Feature: CUM_MEAN(tf.key_9) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.liveness) by session_id>,
#  <Feature: CUM_MEAN(tf.liveness) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.loudness) by session_id>,
#  <Feature: CUM_MEAN(tf.loudness) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.mechanism) by session_id>,
#  <Feature: CUM_MEAN(tf.mechanism) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.mode_major) by session_id>,
#  <Feature: CUM_MEAN(tf.mode_major) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.mode_minor) by session_id>,
#  <Feature: CUM_MEAN(tf.mode_minor) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.organism) by session_id>,
#  <Feature: CUM_MEAN(tf.organism) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.release_year) by session_id>,
#  <Feature: CUM_MEAN(tf.release_year) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.speechiness) by session_id>,
#  <Feature: CUM_MEAN(tf.speechiness) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.tempo) by session_id>,
#  <Feature: CUM_MEAN(tf.tempo) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.time_signature_0) by session_id>,
#  <Feature: CUM_MEAN(tf.time_signature_0) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.time_signature_1) by session_id>,
#  <Feature: CUM_MEAN(tf.time_signature_1) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.time_signature_3) by session_id>,
#  <Feature: CUM_MEAN(tf.time_signature_3) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.time_signature_4) by session_id>,
#  <Feature: CUM_MEAN(tf.time_signature_4) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.time_signature_5) by session_id>,
#  <Feature: CUM_MEAN(tf.time_signature_5) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.us_popularity_estimate) by session_id>,
#  <Feature: CUM_MEAN(tf.us_popularity_estimate) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.valence) by session_id>,
#  <Feature: CUM_MEAN(tf.valence) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.acoustic_vector_0) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_0) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.acoustic_vector_1) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_1) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.acoustic_vector_2) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_2) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.acoustic_vector_3) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_3) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.acoustic_vector_4) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_4) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.acoustic_vector_5) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_5) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.acoustic_vector_6) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_6) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.acoustic_vector_7) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_7) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.acousticness) by session_id>,
#  <Feature: CUM_MIN(tf.acousticness) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.beat_strength) by session_id>,
#  <Feature: CUM_MIN(tf.beat_strength) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.bounciness) by session_id>,
#  <Feature: CUM_MIN(tf.bounciness) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.danceability) by session_id>,
#  <Feature: CUM_MIN(tf.danceability) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.duration) by session_id>,
#  <Feature: CUM_MIN(tf.duration) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.dyn_range_mean) by session_id>,
#  <Feature: CUM_MIN(tf.dyn_range_mean) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.energy) by session_id>,
#  <Feature: CUM_MIN(tf.energy) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.flatness) by session_id>,
#  <Feature: CUM_MIN(tf.flatness) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.instrumentalness) by session_id>,
#  <Feature: CUM_MIN(tf.instrumentalness) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_0) by session_id>,
#  <Feature: CUM_MIN(tf.key_0) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_1) by session_id>,
#  <Feature: CUM_MIN(tf.key_1) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_10) by session_id>,
#  <Feature: CUM_MIN(tf.key_10) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_11) by session_id>,
#  <Feature: CUM_MIN(tf.key_11) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_2) by session_id>,
#  <Feature: CUM_MIN(tf.key_2) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_3) by session_id>,
#  <Feature: CUM_MIN(tf.key_3) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_4) by session_id>,
#  <Feature: CUM_MIN(tf.key_4) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_5) by session_id>,
#  <Feature: CUM_MIN(tf.key_5) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_6) by session_id>,
#  <Feature: CUM_MIN(tf.key_6) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_7) by session_id>,
#  <Feature: CUM_MIN(tf.key_7) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_8) by session_id>,
#  <Feature: CUM_MIN(tf.key_8) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_9) by session_id>,
#  <Feature: CUM_MIN(tf.key_9) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.liveness) by session_id>,
#  <Feature: CUM_MIN(tf.liveness) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.loudness) by session_id>,
#  <Feature: CUM_MIN(tf.loudness) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.mechanism) by session_id>,
#  <Feature: CUM_MIN(tf.mechanism) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.mode_major) by session_id>,
#  <Feature: CUM_MIN(tf.mode_major) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.mode_minor) by session_id>,
#  <Feature: CUM_MIN(tf.mode_minor) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.organism) by session_id>,
#  <Feature: CUM_MIN(tf.organism) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.release_year) by session_id>,
#  <Feature: CUM_MIN(tf.release_year) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.speechiness) by session_id>,
#  <Feature: CUM_MIN(tf.speechiness) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.tempo) by session_id>,
#  <Feature: CUM_MIN(tf.tempo) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.time_signature_0) by session_id>,
#  <Feature: CUM_MIN(tf.time_signature_0) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.time_signature_1) by session_id>,
#  <Feature: CUM_MIN(tf.time_signature_1) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.time_signature_3) by session_id>,
#  <Feature: CUM_MIN(tf.time_signature_3) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.time_signature_4) by session_id>,
#  <Feature: CUM_MIN(tf.time_signature_4) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.time_signature_5) by session_id>,
#  <Feature: CUM_MIN(tf.time_signature_5) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.us_popularity_estimate) by session_id>,
#  <Feature: CUM_MIN(tf.us_popularity_estimate) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.valence) by session_id>,
#  <Feature: CUM_MIN(tf.valence) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.acoustic_vector_0) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_0) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.acoustic_vector_1) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_1) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.acoustic_vector_2) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_2) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.acoustic_vector_3) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_3) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.acoustic_vector_4) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_4) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.acoustic_vector_5) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_5) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.acoustic_vector_6) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_6) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.acoustic_vector_7) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_7) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.acousticness) by session_id>,
#  <Feature: CUM_SUM(tf.acousticness) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.beat_strength) by session_id>,
#  <Feature: CUM_SUM(tf.beat_strength) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.bounciness) by session_id>,
#  <Feature: CUM_SUM(tf.bounciness) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.danceability) by session_id>,
#  <Feature: CUM_SUM(tf.danceability) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.duration) by session_id>,
#  <Feature: CUM_SUM(tf.duration) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.dyn_range_mean) by session_id>,
#  <Feature: CUM_SUM(tf.dyn_range_mean) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.energy) by session_id>,
#  <Feature: CUM_SUM(tf.energy) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.flatness) by session_id>,
#  <Feature: CUM_SUM(tf.flatness) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.instrumentalness) by session_id>,
#  <Feature: CUM_SUM(tf.instrumentalness) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_0) by session_id>,
#  <Feature: CUM_SUM(tf.key_0) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_1) by session_id>,
#  <Feature: CUM_SUM(tf.key_1) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_10) by session_id>,
#  <Feature: CUM_SUM(tf.key_10) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_11) by session_id>,
#  <Feature: CUM_SUM(tf.key_11) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_2) by session_id>,
#  <Feature: CUM_SUM(tf.key_2) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_3) by session_id>,
#  <Feature: CUM_SUM(tf.key_3) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_4) by session_id>,
#  <Feature: CUM_SUM(tf.key_4) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_5) by session_id>,
#  <Feature: CUM_SUM(tf.key_5) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_6) by session_id>,
#  <Feature: CUM_SUM(tf.key_6) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_7) by session_id>,
#  <Feature: CUM_SUM(tf.key_7) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_8) by session_id>,
#  <Feature: CUM_SUM(tf.key_8) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_9) by session_id>,
#  <Feature: CUM_SUM(tf.key_9) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.liveness) by session_id>,
#  <Feature: CUM_SUM(tf.liveness) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.loudness) by session_id>,
#  <Feature: CUM_SUM(tf.loudness) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.mechanism) by session_id>,
#  <Feature: CUM_SUM(tf.mechanism) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.mode_major) by session_id>,
#  <Feature: CUM_SUM(tf.mode_major) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.mode_minor) by session_id>,
#  <Feature: CUM_SUM(tf.mode_minor) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.organism) by session_id>,
#  <Feature: CUM_SUM(tf.organism) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.release_year) by session_id>,
#  <Feature: CUM_SUM(tf.release_year) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.speechiness) by session_id>,
#  <Feature: CUM_SUM(tf.speechiness) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.tempo) by session_id>,
#  <Feature: CUM_SUM(tf.tempo) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.time_signature_0) by session_id>,
#  <Feature: CUM_SUM(tf.time_signature_0) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.time_signature_1) by session_id>,
#  <Feature: CUM_SUM(tf.time_signature_1) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.time_signature_3) by session_id>,
#  <Feature: CUM_SUM(tf.time_signature_3) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.time_signature_4) by session_id>,
#  <Feature: CUM_SUM(tf.time_signature_4) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.time_signature_5) by session_id>,
#  <Feature: CUM_SUM(tf.time_signature_5) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.us_popularity_estimate) by session_id>,
#  <Feature: CUM_SUM(tf.us_popularity_estimate) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.valence) by session_id>,
#  <Feature: CUM_SUM(tf.valence) by session_id_not_skipped>,
#  <Feature: DIFF(tf.acoustic_vector_0) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_0) by session_id_not_skipped>,
#  <Feature: DIFF(tf.acoustic_vector_1) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_1) by session_id_not_skipped>,
#  <Feature: DIFF(tf.acoustic_vector_2) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_2) by session_id_not_skipped>,
#  <Feature: DIFF(tf.acoustic_vector_3) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_3) by session_id_not_skipped>,
#  <Feature: DIFF(tf.acoustic_vector_4) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_4) by session_id_not_skipped>,
#  <Feature: DIFF(tf.acoustic_vector_5) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_5) by session_id_not_skipped>,
#  <Feature: DIFF(tf.acoustic_vector_6) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_6) by session_id_not_skipped>,
#  <Feature: DIFF(tf.acoustic_vector_7) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_7) by session_id_not_skipped>,
#  <Feature: DIFF(tf.acousticness) by session_id>,
#  <Feature: DIFF(tf.acousticness) by session_id_not_skipped>,
#  <Feature: DIFF(tf.beat_strength) by session_id>,
#  <Feature: DIFF(tf.beat_strength) by session_id_not_skipped>,
#  <Feature: DIFF(tf.bounciness) by session_id>,
#  <Feature: DIFF(tf.bounciness) by session_id_not_skipped>,
#  <Feature: DIFF(tf.danceability) by session_id>,
#  <Feature: DIFF(tf.danceability) by session_id_not_skipped>,
#  <Feature: DIFF(tf.duration) by session_id>,
#  <Feature: DIFF(tf.duration) by session_id_not_skipped>,
#  <Feature: DIFF(tf.dyn_range_mean) by session_id>,
#  <Feature: DIFF(tf.dyn_range_mean) by session_id_not_skipped>,
#  <Feature: DIFF(tf.energy) by session_id>,
#  <Feature: DIFF(tf.energy) by session_id_not_skipped>,
#  <Feature: DIFF(tf.flatness) by session_id>,
#  <Feature: DIFF(tf.flatness) by session_id_not_skipped>,
#  <Feature: DIFF(tf.instrumentalness) by session_id>,
#  <Feature: DIFF(tf.instrumentalness) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_0) by session_id>,
#  <Feature: DIFF(tf.key_0) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_1) by session_id>,
#  <Feature: DIFF(tf.key_1) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_10) by session_id>,
#  <Feature: DIFF(tf.key_10) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_11) by session_id>,
#  <Feature: DIFF(tf.key_11) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_2) by session_id>,
#  <Feature: DIFF(tf.key_2) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_3) by session_id>,
#  <Feature: DIFF(tf.key_3) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_4) by session_id>,
#  <Feature: DIFF(tf.key_4) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_5) by session_id>,
#  <Feature: DIFF(tf.key_5) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_6) by session_id>,
#  <Feature: DIFF(tf.key_6) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_7) by session_id>,
#  <Feature: DIFF(tf.key_7) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_8) by session_id>,
#  <Feature: DIFF(tf.key_8) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_9) by session_id>,
#  <Feature: DIFF(tf.key_9) by session_id_not_skipped>,
#  <Feature: DIFF(tf.liveness) by session_id>,
#  <Feature: DIFF(tf.liveness) by session_id_not_skipped>,
#  <Feature: DIFF(tf.loudness) by session_id>,
#  <Feature: DIFF(tf.loudness) by session_id_not_skipped>,
#  <Feature: DIFF(tf.mechanism) by session_id>,
#  <Feature: DIFF(tf.mechanism) by session_id_not_skipped>,
#  <Feature: DIFF(tf.mode_major) by session_id>,
#  <Feature: DIFF(tf.mode_major) by session_id_not_skipped>,
#  <Feature: DIFF(tf.mode_minor) by session_id>,
#  <Feature: DIFF(tf.mode_minor) by session_id_not_skipped>,
#  <Feature: DIFF(tf.organism) by session_id>,
#  <Feature: DIFF(tf.organism) by session_id_not_skipped>,
#  <Feature: DIFF(tf.release_year) by session_id>,
#  <Feature: DIFF(tf.release_year) by session_id_not_skipped>,
#  <Feature: DIFF(tf.speechiness) by session_id>,
#  <Feature: DIFF(tf.speechiness) by session_id_not_skipped>,
#  <Feature: DIFF(tf.tempo) by session_id>,
#  <Feature: DIFF(tf.tempo) by session_id_not_skipped>,
#  <Feature: DIFF(tf.time_signature_0) by session_id>,
#  <Feature: DIFF(tf.time_signature_0) by session_id_not_skipped>,
#  <Feature: DIFF(tf.time_signature_1) by session_id>,
#  <Feature: DIFF(tf.time_signature_1) by session_id_not_skipped>,
#  <Feature: DIFF(tf.time_signature_3) by session_id>,
#  <Feature: DIFF(tf.time_signature_3) by session_id_not_skipped>,
#  <Feature: DIFF(tf.time_signature_4) by session_id>,
#  <Feature: DIFF(tf.time_signature_4) by session_id_not_skipped>,
#  <Feature: DIFF(tf.time_signature_5) by session_id>,
#  <Feature: DIFF(tf.time_signature_5) by session_id_not_skipped>,
#  <Feature: DIFF(tf.us_popularity_estimate) by session_id>,
#  <Feature: DIFF(tf.us_popularity_estimate) by session_id_not_skipped>,
#  <Feature: DIFF(tf.valence) by session_id>,
#  <Feature: DIFF(tf.valence) by session_id_not_skipped>]

# %%
len(feature_defs_test)
# Out:
# 740

# %%
import warnings
def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
#warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# %%
# check this for specifying groupby: https://featuretools.alteryx.com/en/stable/guides/specifying_primitive_options.html
# The 'session_id' was specified as GroupBy option as we care what happend in each session.
# The tf (track inforamtion) dataframe does not contain any order or session information, so it does not be be specified as GroupBy option.

#warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
# warnings.simplefilter("ignore")


start_time = time.time()

feature_matrix, feature_defs = ft.dfs(entityset=es,
                        target_dataframe_name="log",
                        groupby_trans_primitives=["Diff","CumSum", "CumCount", "CumMean", "CumMin", "CumMax"],
                        agg_primitives=[],
                        trans_primitives=[],
                        primitive_options={"diff": {"include_groupby_columns": {"log": ["session_id","session_id_not_skipped"]},"ignore_groupby_dataframes": ["tf"]},
                                        "cum_sum": {"include_groupby_columns": {"log": ["session_id","session_id_not_skipped"]},"ignore_groupby_dataframes": ["tf"]},
                                        "cum_count": {"include_groupby_columns": {"log": ["session_id","session_id_not_skipped"]},"ignore_groupby_dataframes": ["tf"]},
                                        "cum_mean": {"include_groupby_columns": {"log": ["session_id","session_id_not_skipped"]},"ignore_groupby_dataframes": ["tf"]},
                                        "cum_min": {"include_groupby_columns": {"log": ["session_id","session_id_not_skipped"]},"ignore_groupby_dataframes": ["tf"]},
                                        "cum_max": {"include_groupby_columns": {"log": ["session_id","session_id_not_skipped"]},"ignore_groupby_dataframes": ["tf"]}},
                        features_only = False,
                        n_jobs=-1)

print('***It takes ',(time.time() - start_time)/60, ' minutes.***')
# Out:
# EntitySet scattered to 8 workers in 6 seconds
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# ...
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# distributed.nanny - WARNING - Worker process still alive after 3.9999990463256836 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3.999998474121094 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3.999999237060547 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# ***It takes  54.85303083260854  minutes.***

# %%
feature_matrix
# Out:
#                                       session_id  session_position  skip_1  \
# event_id
# 0         0_00006f66-33e5-4de7-a324-2d18e439fc1e                 1   False
# 20        0_0000a72b-09ac-412f-b452-9b9e79bded8f                 1   False
# 40        0_00010fc5-b79e-4cdf-bc4c-f140d0f99a3a                 1   False
# 60        0_00016a3d-9076-4f67-918f-f29e3ce160dc                 1    True
# 80        0_00018b58-deb8-4f98-ac5e-d7e01b346130                 1   False
# ...                                          ...               ...     ...
# 167773    0_0eab7430-d291-4d57-9c92-ac7cb682f2c6                20   False
# 167807    0_0eac164c-f209-4590-8608-a56e67658952                20   False
# 167827    0_0eacbee7-9868-48a0-9ab0-f86069329f50                20    True
# 167847    0_0ead11fc-f32c-4eb4-8fc1-15b51432a404                20    True
# 167879    0_0eaeef5d-25e9-4429-bd55-af15d3604c9f                20   False
#
#           skip_2  skip_3  not_skipped  context_switch  no_pause_before_play  \
# event_id
# 0          False   False         True               0                     0
# 20          True    True        False               0                     0
# 40         False    True        False               0                     0
# 60          True    True        False               0                     0
# 80         False    True        False               0                     0
# ...          ...     ...          ...             ...                   ...
# 167773     False   False         True               0                     1
# 167807     False    True        False               0                     1
# 167827      True    True        False               0                     1
# 167847      True    True        False               0                     0
# 167879     False   False         True               0                     1
#
#           short_pause_before_play  long_pause_before_play  ...  \
# event_id                                                   ...
# 0                               0                       0  ...
# 20                              0                       0  ...
# 40                              0                       0  ...
# 60                              0                       0  ...
# 80                              0                       0  ...
# ...                           ...                     ...  ...
# 167773                          0                       0  ...
# 167807                          0                       0  ...
# 167827                          0                       0  ...
# 167847                          1                       1  ...
# 167879                          0                       0  ...
#
#           DIFF(tf.time_signature_3) by session_id  \
# event_id
# 0                                             NaN
# 20                                            NaN
# 40                                            NaN
# 60                                            NaN
# 80                                            NaN
# ...                                           ...
# 167773                                        0.0
# 167807                                        0.0
# 167827                                        0.0
# 167847                                        0.0
# 167879                                        0.0
#
#           DIFF(tf.time_signature_3) by session_id_not_skipped  \
# event_id
# 0                                                       NaN
# 20                                                      NaN
# 40                                                      0.0
# 60                                                      0.0
# 80                                                      0.0
# ...                                                     ...
# 167773                                                  0.0
# 167807                                                  0.0
# 167827                                                  0.0
# 167847                                                  0.0
# 167879                                                  0.0
#
#           DIFF(tf.time_signature_4) by session_id  \
# event_id
# 0                                             NaN
# 20                                            NaN
# 40                                            NaN
# 60                                            NaN
# 80                                            NaN
# ...                                           ...
# 167773                                        0.0
# 167807                                        0.0
# 167827                                        0.0
# 167847                                        0.0
# 167879                                        0.0
#
#           DIFF(tf.time_signature_4) by session_id_not_skipped  \
# event_id
# 0                                                       NaN
# 20                                                      NaN
# 40                                                      0.0
# 60                                                      0.0
# 80                                                      0.0
# ...                                                     ...
# 167773                                                  0.0
# 167807                                                  0.0
# 167827                                                  0.0
# 167847                                                  0.0
# 167879                                                  0.0
#
#           DIFF(tf.time_signature_5) by session_id  \
# event_id
# 0                                             NaN
# 20                                            NaN
# 40                                            NaN
# 60                                            NaN
# 80                                            NaN
# ...                                           ...
# 167773                                        0.0
# 167807                                        0.0
# 167827                                        0.0
# 167847                                        0.0
# 167879                                        0.0
#
#           DIFF(tf.time_signature_5) by session_id_not_skipped  \
# event_id
# 0                                                       NaN
# 20                                                      NaN
# 40                                                      0.0
# 60                                                      0.0
# 80                                                      0.0
# ...                                                     ...
# 167773                                                  0.0
# 167807                                                  0.0
# 167827                                                  0.0
# 167847                                                  0.0
# 167879                                                  0.0
#
#           DIFF(tf.us_popularity_estimate) by session_id  \
# event_id
# 0                                                   NaN
# 20                                                  NaN
# 40                                                  NaN
# 60                                                  NaN
# 80                                                  NaN
# ...                                                 ...
# 167773                                        -0.017276
# 167807                                        -0.191419
# 167827                                         0.117369
# 167847                                        -0.205259
# 167879                                        -0.004188
#
#           DIFF(tf.us_popularity_estimate) by session_id_not_skipped  \
# event_id
# 0                                                       NaN
# 20                                                      NaN
# 40                                                 1.191625
# 60                                                -0.068586
# 80                                                -0.358257
# ...                                                     ...
# 167773                                            -0.017276
# 167807                                            -0.141646
# 167827                                             0.189083
# 167847                                            -0.202169
# 167879                                            -0.004188
#
#           DIFF(tf.valence) by session_id  \
# event_id
# 0                                    NaN
# 20                                   NaN
# 40                                   NaN
# 60                                   NaN
# 80                                   NaN
# ...                                  ...
# 167773                         -0.149514
# 167807                         -0.126923
# 167827                          0.339712
# 167847                          0.402161
# 167879                         -0.038645
#
#           DIFF(tf.valence) by session_id_not_skipped
# event_id
# 0                                                NaN
# 20                                               NaN
# 40                                          0.324816
# 60                                          0.087566
# 80                                         -0.420744
# ...                                              ...
# 167773                                     -0.149514
# 167807                                      0.176687
# 167827                                      0.119504
# 167847                                      0.171030
# 167879                                     -0.038645
#
# [167880 rows x 740 columns]

# %%
feature_defs
# Out:
# [<Feature: session_id>,
#  <Feature: session_position>,
#  <Feature: skip_1>,
#  <Feature: skip_2>,
#  <Feature: skip_3>,
#  <Feature: not_skipped>,
#  <Feature: context_switch>,
#  <Feature: no_pause_before_play>,
#  <Feature: short_pause_before_play>,
#  <Feature: long_pause_before_play>,
#  <Feature: hist_user_behavior_is_shuffle>,
#  <Feature: hour_of_day>,
#  <Feature: premium>,
#  <Feature: hist_user_behavior_reason_start_appload>,
#  <Feature: hist_user_behavior_reason_start_backbtn>,
#  <Feature: hist_user_behavior_reason_start_clickrow>,
#  <Feature: hist_user_behavior_reason_start_endplay>,
#  <Feature: hist_user_behavior_reason_start_fwdbtn>,
#  <Feature: hist_user_behavior_reason_start_playbtn>,
#  <Feature: hist_user_behavior_reason_start_remote>,
#  <Feature: hist_user_behavior_reason_start_trackdone>,
#  <Feature: hist_user_behavior_reason_start_trackerror>,
#  <Feature: context_type_catalog>,
#  <Feature: context_type_charts>,
#  <Feature: context_type_editorial_playlist>,
#  <Feature: context_type_personalized_playlist>,
#  <Feature: context_type_radio>,
#  <Feature: context_type_user_collection>,
#  <Feature: session_id_not_skipped>,
#  <Feature: CUM_COUNT(session_id) by session_id>,
#  <Feature: CUM_COUNT(session_id) by session_id_not_skipped>,
#  <Feature: CUM_COUNT(session_id_not_skipped) by session_id>,
#  <Feature: CUM_COUNT(session_id_not_skipped) by session_id_not_skipped>,
#  <Feature: CUM_COUNT(track_id_clean) by session_id>,
#  <Feature: CUM_COUNT(track_id_clean) by session_id_not_skipped>,
#  <Feature: CUM_MAX(context_switch) by session_id>,
#  <Feature: CUM_MAX(context_switch) by session_id_not_skipped>,
#  <Feature: CUM_MAX(context_type_catalog) by session_id>,
#  <Feature: CUM_MAX(context_type_catalog) by session_id_not_skipped>,
#  <Feature: CUM_MAX(context_type_charts) by session_id>,
#  <Feature: CUM_MAX(context_type_charts) by session_id_not_skipped>,
#  <Feature: CUM_MAX(context_type_editorial_playlist) by session_id>,
#  <Feature: CUM_MAX(context_type_editorial_playlist) by session_id_not_skipped>,
#  <Feature: CUM_MAX(context_type_personalized_playlist) by session_id>,
#  <Feature: CUM_MAX(context_type_personalized_playlist) by session_id_not_skipped>,
#  <Feature: CUM_MAX(context_type_radio) by session_id>,
#  <Feature: CUM_MAX(context_type_radio) by session_id_not_skipped>,
#  <Feature: CUM_MAX(context_type_user_collection) by session_id>,
#  <Feature: CUM_MAX(context_type_user_collection) by session_id_not_skipped>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_appload) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_appload) by session_id_not_skipped>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_backbtn) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_backbtn) by session_id_not_skipped>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_clickrow) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_clickrow) by session_id_not_skipped>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_endplay) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_endplay) by session_id_not_skipped>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_fwdbtn) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_fwdbtn) by session_id_not_skipped>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_playbtn) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_playbtn) by session_id_not_skipped>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_remote) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_remote) by session_id_not_skipped>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_trackdone) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_trackdone) by session_id_not_skipped>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_trackerror) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_trackerror) by session_id_not_skipped>,
#  <Feature: CUM_MAX(hour_of_day) by session_id>,
#  <Feature: CUM_MAX(hour_of_day) by session_id_not_skipped>,
#  <Feature: CUM_MAX(long_pause_before_play) by session_id>,
#  <Feature: CUM_MAX(long_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_MAX(no_pause_before_play) by session_id>,
#  <Feature: CUM_MAX(no_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_MAX(session_position) by session_id>,
#  <Feature: CUM_MAX(session_position) by session_id_not_skipped>,
#  <Feature: CUM_MAX(short_pause_before_play) by session_id>,
#  <Feature: CUM_MAX(short_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(context_switch) by session_id>,
#  <Feature: CUM_MEAN(context_switch) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(context_type_catalog) by session_id>,
#  <Feature: CUM_MEAN(context_type_catalog) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(context_type_charts) by session_id>,
#  <Feature: CUM_MEAN(context_type_charts) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(context_type_editorial_playlist) by session_id>,
#  <Feature: CUM_MEAN(context_type_editorial_playlist) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(context_type_personalized_playlist) by session_id>,
#  <Feature: CUM_MEAN(context_type_personalized_playlist) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(context_type_radio) by session_id>,
#  <Feature: CUM_MEAN(context_type_radio) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(context_type_user_collection) by session_id>,
#  <Feature: CUM_MEAN(context_type_user_collection) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_appload) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_appload) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_backbtn) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_backbtn) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_clickrow) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_clickrow) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_endplay) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_endplay) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_fwdbtn) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_fwdbtn) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_playbtn) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_playbtn) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_remote) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_remote) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_trackdone) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_trackdone) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_trackerror) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_trackerror) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(hour_of_day) by session_id>,
#  <Feature: CUM_MEAN(hour_of_day) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(long_pause_before_play) by session_id>,
#  <Feature: CUM_MEAN(long_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(no_pause_before_play) by session_id>,
#  <Feature: CUM_MEAN(no_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(session_position) by session_id>,
#  <Feature: CUM_MEAN(session_position) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(short_pause_before_play) by session_id>,
#  <Feature: CUM_MEAN(short_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_MIN(context_switch) by session_id>,
#  <Feature: CUM_MIN(context_switch) by session_id_not_skipped>,
#  <Feature: CUM_MIN(context_type_catalog) by session_id>,
#  <Feature: CUM_MIN(context_type_catalog) by session_id_not_skipped>,
#  <Feature: CUM_MIN(context_type_charts) by session_id>,
#  <Feature: CUM_MIN(context_type_charts) by session_id_not_skipped>,
#  <Feature: CUM_MIN(context_type_editorial_playlist) by session_id>,
#  <Feature: CUM_MIN(context_type_editorial_playlist) by session_id_not_skipped>,
#  <Feature: CUM_MIN(context_type_personalized_playlist) by session_id>,
#  <Feature: CUM_MIN(context_type_personalized_playlist) by session_id_not_skipped>,
#  <Feature: CUM_MIN(context_type_radio) by session_id>,
#  <Feature: CUM_MIN(context_type_radio) by session_id_not_skipped>,
#  <Feature: CUM_MIN(context_type_user_collection) by session_id>,
#  <Feature: CUM_MIN(context_type_user_collection) by session_id_not_skipped>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_appload) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_appload) by session_id_not_skipped>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_backbtn) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_backbtn) by session_id_not_skipped>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_clickrow) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_clickrow) by session_id_not_skipped>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_endplay) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_endplay) by session_id_not_skipped>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_fwdbtn) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_fwdbtn) by session_id_not_skipped>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_playbtn) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_playbtn) by session_id_not_skipped>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_remote) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_remote) by session_id_not_skipped>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_trackdone) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_trackdone) by session_id_not_skipped>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_trackerror) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_trackerror) by session_id_not_skipped>,
#  <Feature: CUM_MIN(hour_of_day) by session_id>,
#  <Feature: CUM_MIN(hour_of_day) by session_id_not_skipped>,
#  <Feature: CUM_MIN(long_pause_before_play) by session_id>,
#  <Feature: CUM_MIN(long_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_MIN(no_pause_before_play) by session_id>,
#  <Feature: CUM_MIN(no_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_MIN(session_position) by session_id>,
#  <Feature: CUM_MIN(session_position) by session_id_not_skipped>,
#  <Feature: CUM_MIN(short_pause_before_play) by session_id>,
#  <Feature: CUM_MIN(short_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_SUM(context_switch) by session_id>,
#  <Feature: CUM_SUM(context_switch) by session_id_not_skipped>,
#  <Feature: CUM_SUM(context_type_catalog) by session_id>,
#  <Feature: CUM_SUM(context_type_catalog) by session_id_not_skipped>,
#  <Feature: CUM_SUM(context_type_charts) by session_id>,
#  <Feature: CUM_SUM(context_type_charts) by session_id_not_skipped>,
#  <Feature: CUM_SUM(context_type_editorial_playlist) by session_id>,
#  <Feature: CUM_SUM(context_type_editorial_playlist) by session_id_not_skipped>,
#  <Feature: CUM_SUM(context_type_personalized_playlist) by session_id>,
#  <Feature: CUM_SUM(context_type_personalized_playlist) by session_id_not_skipped>,
#  <Feature: CUM_SUM(context_type_radio) by session_id>,
#  <Feature: CUM_SUM(context_type_radio) by session_id_not_skipped>,
#  <Feature: CUM_SUM(context_type_user_collection) by session_id>,
#  <Feature: CUM_SUM(context_type_user_collection) by session_id_not_skipped>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_appload) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_appload) by session_id_not_skipped>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_backbtn) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_backbtn) by session_id_not_skipped>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_clickrow) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_clickrow) by session_id_not_skipped>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_endplay) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_endplay) by session_id_not_skipped>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_fwdbtn) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_fwdbtn) by session_id_not_skipped>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_playbtn) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_playbtn) by session_id_not_skipped>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_remote) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_remote) by session_id_not_skipped>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_trackdone) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_trackdone) by session_id_not_skipped>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_trackerror) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_trackerror) by session_id_not_skipped>,
#  <Feature: CUM_SUM(hour_of_day) by session_id>,
#  <Feature: CUM_SUM(hour_of_day) by session_id_not_skipped>,
#  <Feature: CUM_SUM(long_pause_before_play) by session_id>,
#  <Feature: CUM_SUM(long_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_SUM(no_pause_before_play) by session_id>,
#  <Feature: CUM_SUM(no_pause_before_play) by session_id_not_skipped>,
#  <Feature: CUM_SUM(session_position) by session_id>,
#  <Feature: CUM_SUM(session_position) by session_id_not_skipped>,
#  <Feature: CUM_SUM(short_pause_before_play) by session_id>,
#  <Feature: CUM_SUM(short_pause_before_play) by session_id_not_skipped>,
#  <Feature: DIFF(context_switch) by session_id>,
#  <Feature: DIFF(context_switch) by session_id_not_skipped>,
#  <Feature: DIFF(context_type_catalog) by session_id>,
#  <Feature: DIFF(context_type_catalog) by session_id_not_skipped>,
#  <Feature: DIFF(context_type_charts) by session_id>,
#  <Feature: DIFF(context_type_charts) by session_id_not_skipped>,
#  <Feature: DIFF(context_type_editorial_playlist) by session_id>,
#  <Feature: DIFF(context_type_editorial_playlist) by session_id_not_skipped>,
#  <Feature: DIFF(context_type_personalized_playlist) by session_id>,
#  <Feature: DIFF(context_type_personalized_playlist) by session_id_not_skipped>,
#  <Feature: DIFF(context_type_radio) by session_id>,
#  <Feature: DIFF(context_type_radio) by session_id_not_skipped>,
#  <Feature: DIFF(context_type_user_collection) by session_id>,
#  <Feature: DIFF(context_type_user_collection) by session_id_not_skipped>,
#  <Feature: DIFF(hist_user_behavior_reason_start_appload) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_appload) by session_id_not_skipped>,
#  <Feature: DIFF(hist_user_behavior_reason_start_backbtn) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_backbtn) by session_id_not_skipped>,
#  <Feature: DIFF(hist_user_behavior_reason_start_clickrow) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_clickrow) by session_id_not_skipped>,
#  <Feature: DIFF(hist_user_behavior_reason_start_endplay) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_endplay) by session_id_not_skipped>,
#  <Feature: DIFF(hist_user_behavior_reason_start_fwdbtn) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_fwdbtn) by session_id_not_skipped>,
#  <Feature: DIFF(hist_user_behavior_reason_start_playbtn) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_playbtn) by session_id_not_skipped>,
#  <Feature: DIFF(hist_user_behavior_reason_start_remote) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_remote) by session_id_not_skipped>,
#  <Feature: DIFF(hist_user_behavior_reason_start_trackdone) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_trackdone) by session_id_not_skipped>,
#  <Feature: DIFF(hist_user_behavior_reason_start_trackerror) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_trackerror) by session_id_not_skipped>,
#  <Feature: DIFF(hour_of_day) by session_id>,
#  <Feature: DIFF(hour_of_day) by session_id_not_skipped>,
#  <Feature: DIFF(long_pause_before_play) by session_id>,
#  <Feature: DIFF(long_pause_before_play) by session_id_not_skipped>,
#  <Feature: DIFF(no_pause_before_play) by session_id>,
#  <Feature: DIFF(no_pause_before_play) by session_id_not_skipped>,
#  <Feature: DIFF(session_position) by session_id>,
#  <Feature: DIFF(session_position) by session_id_not_skipped>,
#  <Feature: DIFF(short_pause_before_play) by session_id>,
#  <Feature: DIFF(short_pause_before_play) by session_id_not_skipped>,
#  <Feature: tf.duration>,
#  <Feature: tf.release_year>,
#  <Feature: tf.us_popularity_estimate>,
#  <Feature: tf.acousticness>,
#  <Feature: tf.beat_strength>,
#  <Feature: tf.bounciness>,
#  <Feature: tf.danceability>,
#  <Feature: tf.dyn_range_mean>,
#  <Feature: tf.energy>,
#  <Feature: tf.flatness>,
#  <Feature: tf.instrumentalness>,
#  <Feature: tf.liveness>,
#  <Feature: tf.loudness>,
#  <Feature: tf.mechanism>,
#  <Feature: tf.organism>,
#  <Feature: tf.speechiness>,
#  <Feature: tf.tempo>,
#  <Feature: tf.valence>,
#  <Feature: tf.acoustic_vector_0>,
#  <Feature: tf.acoustic_vector_1>,
#  <Feature: tf.acoustic_vector_2>,
#  <Feature: tf.acoustic_vector_3>,
#  <Feature: tf.acoustic_vector_4>,
#  <Feature: tf.acoustic_vector_5>,
#  <Feature: tf.acoustic_vector_6>,
#  <Feature: tf.acoustic_vector_7>,
#  <Feature: tf.key_0>,
#  <Feature: tf.key_1>,
#  <Feature: tf.key_2>,
#  <Feature: tf.key_3>,
#  <Feature: tf.key_4>,
#  <Feature: tf.key_5>,
#  <Feature: tf.key_6>,
#  <Feature: tf.key_7>,
#  <Feature: tf.key_8>,
#  <Feature: tf.key_9>,
#  <Feature: tf.key_10>,
#  <Feature: tf.key_11>,
#  <Feature: tf.time_signature_0>,
#  <Feature: tf.time_signature_1>,
#  <Feature: tf.time_signature_3>,
#  <Feature: tf.time_signature_4>,
#  <Feature: tf.time_signature_5>,
#  <Feature: tf.mode_major>,
#  <Feature: tf.mode_minor>,
#  <Feature: CUM_MAX(tf.acoustic_vector_0) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_0) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.acoustic_vector_1) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_1) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.acoustic_vector_2) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_2) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.acoustic_vector_3) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_3) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.acoustic_vector_4) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_4) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.acoustic_vector_5) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_5) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.acoustic_vector_6) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_6) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.acoustic_vector_7) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_7) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.acousticness) by session_id>,
#  <Feature: CUM_MAX(tf.acousticness) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.beat_strength) by session_id>,
#  <Feature: CUM_MAX(tf.beat_strength) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.bounciness) by session_id>,
#  <Feature: CUM_MAX(tf.bounciness) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.danceability) by session_id>,
#  <Feature: CUM_MAX(tf.danceability) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.duration) by session_id>,
#  <Feature: CUM_MAX(tf.duration) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.dyn_range_mean) by session_id>,
#  <Feature: CUM_MAX(tf.dyn_range_mean) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.energy) by session_id>,
#  <Feature: CUM_MAX(tf.energy) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.flatness) by session_id>,
#  <Feature: CUM_MAX(tf.flatness) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.instrumentalness) by session_id>,
#  <Feature: CUM_MAX(tf.instrumentalness) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_0) by session_id>,
#  <Feature: CUM_MAX(tf.key_0) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_1) by session_id>,
#  <Feature: CUM_MAX(tf.key_1) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_10) by session_id>,
#  <Feature: CUM_MAX(tf.key_10) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_11) by session_id>,
#  <Feature: CUM_MAX(tf.key_11) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_2) by session_id>,
#  <Feature: CUM_MAX(tf.key_2) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_3) by session_id>,
#  <Feature: CUM_MAX(tf.key_3) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_4) by session_id>,
#  <Feature: CUM_MAX(tf.key_4) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_5) by session_id>,
#  <Feature: CUM_MAX(tf.key_5) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_6) by session_id>,
#  <Feature: CUM_MAX(tf.key_6) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_7) by session_id>,
#  <Feature: CUM_MAX(tf.key_7) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_8) by session_id>,
#  <Feature: CUM_MAX(tf.key_8) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.key_9) by session_id>,
#  <Feature: CUM_MAX(tf.key_9) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.liveness) by session_id>,
#  <Feature: CUM_MAX(tf.liveness) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.loudness) by session_id>,
#  <Feature: CUM_MAX(tf.loudness) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.mechanism) by session_id>,
#  <Feature: CUM_MAX(tf.mechanism) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.mode_major) by session_id>,
#  <Feature: CUM_MAX(tf.mode_major) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.mode_minor) by session_id>,
#  <Feature: CUM_MAX(tf.mode_minor) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.organism) by session_id>,
#  <Feature: CUM_MAX(tf.organism) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.release_year) by session_id>,
#  <Feature: CUM_MAX(tf.release_year) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.speechiness) by session_id>,
#  <Feature: CUM_MAX(tf.speechiness) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.tempo) by session_id>,
#  <Feature: CUM_MAX(tf.tempo) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.time_signature_0) by session_id>,
#  <Feature: CUM_MAX(tf.time_signature_0) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.time_signature_1) by session_id>,
#  <Feature: CUM_MAX(tf.time_signature_1) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.time_signature_3) by session_id>,
#  <Feature: CUM_MAX(tf.time_signature_3) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.time_signature_4) by session_id>,
#  <Feature: CUM_MAX(tf.time_signature_4) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.time_signature_5) by session_id>,
#  <Feature: CUM_MAX(tf.time_signature_5) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.us_popularity_estimate) by session_id>,
#  <Feature: CUM_MAX(tf.us_popularity_estimate) by session_id_not_skipped>,
#  <Feature: CUM_MAX(tf.valence) by session_id>,
#  <Feature: CUM_MAX(tf.valence) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_0) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_0) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_1) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_1) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_2) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_2) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_3) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_3) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_4) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_4) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_5) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_5) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_6) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_6) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_7) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_7) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.acousticness) by session_id>,
#  <Feature: CUM_MEAN(tf.acousticness) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.beat_strength) by session_id>,
#  <Feature: CUM_MEAN(tf.beat_strength) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.bounciness) by session_id>,
#  <Feature: CUM_MEAN(tf.bounciness) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.danceability) by session_id>,
#  <Feature: CUM_MEAN(tf.danceability) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.duration) by session_id>,
#  <Feature: CUM_MEAN(tf.duration) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.dyn_range_mean) by session_id>,
#  <Feature: CUM_MEAN(tf.dyn_range_mean) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.energy) by session_id>,
#  <Feature: CUM_MEAN(tf.energy) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.flatness) by session_id>,
#  <Feature: CUM_MEAN(tf.flatness) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.instrumentalness) by session_id>,
#  <Feature: CUM_MEAN(tf.instrumentalness) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_0) by session_id>,
#  <Feature: CUM_MEAN(tf.key_0) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_1) by session_id>,
#  <Feature: CUM_MEAN(tf.key_1) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_10) by session_id>,
#  <Feature: CUM_MEAN(tf.key_10) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_11) by session_id>,
#  <Feature: CUM_MEAN(tf.key_11) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_2) by session_id>,
#  <Feature: CUM_MEAN(tf.key_2) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_3) by session_id>,
#  <Feature: CUM_MEAN(tf.key_3) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_4) by session_id>,
#  <Feature: CUM_MEAN(tf.key_4) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_5) by session_id>,
#  <Feature: CUM_MEAN(tf.key_5) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_6) by session_id>,
#  <Feature: CUM_MEAN(tf.key_6) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_7) by session_id>,
#  <Feature: CUM_MEAN(tf.key_7) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_8) by session_id>,
#  <Feature: CUM_MEAN(tf.key_8) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.key_9) by session_id>,
#  <Feature: CUM_MEAN(tf.key_9) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.liveness) by session_id>,
#  <Feature: CUM_MEAN(tf.liveness) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.loudness) by session_id>,
#  <Feature: CUM_MEAN(tf.loudness) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.mechanism) by session_id>,
#  <Feature: CUM_MEAN(tf.mechanism) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.mode_major) by session_id>,
#  <Feature: CUM_MEAN(tf.mode_major) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.mode_minor) by session_id>,
#  <Feature: CUM_MEAN(tf.mode_minor) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.organism) by session_id>,
#  <Feature: CUM_MEAN(tf.organism) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.release_year) by session_id>,
#  <Feature: CUM_MEAN(tf.release_year) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.speechiness) by session_id>,
#  <Feature: CUM_MEAN(tf.speechiness) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.tempo) by session_id>,
#  <Feature: CUM_MEAN(tf.tempo) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.time_signature_0) by session_id>,
#  <Feature: CUM_MEAN(tf.time_signature_0) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.time_signature_1) by session_id>,
#  <Feature: CUM_MEAN(tf.time_signature_1) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.time_signature_3) by session_id>,
#  <Feature: CUM_MEAN(tf.time_signature_3) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.time_signature_4) by session_id>,
#  <Feature: CUM_MEAN(tf.time_signature_4) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.time_signature_5) by session_id>,
#  <Feature: CUM_MEAN(tf.time_signature_5) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.us_popularity_estimate) by session_id>,
#  <Feature: CUM_MEAN(tf.us_popularity_estimate) by session_id_not_skipped>,
#  <Feature: CUM_MEAN(tf.valence) by session_id>,
#  <Feature: CUM_MEAN(tf.valence) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.acoustic_vector_0) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_0) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.acoustic_vector_1) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_1) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.acoustic_vector_2) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_2) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.acoustic_vector_3) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_3) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.acoustic_vector_4) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_4) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.acoustic_vector_5) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_5) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.acoustic_vector_6) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_6) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.acoustic_vector_7) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_7) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.acousticness) by session_id>,
#  <Feature: CUM_MIN(tf.acousticness) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.beat_strength) by session_id>,
#  <Feature: CUM_MIN(tf.beat_strength) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.bounciness) by session_id>,
#  <Feature: CUM_MIN(tf.bounciness) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.danceability) by session_id>,
#  <Feature: CUM_MIN(tf.danceability) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.duration) by session_id>,
#  <Feature: CUM_MIN(tf.duration) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.dyn_range_mean) by session_id>,
#  <Feature: CUM_MIN(tf.dyn_range_mean) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.energy) by session_id>,
#  <Feature: CUM_MIN(tf.energy) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.flatness) by session_id>,
#  <Feature: CUM_MIN(tf.flatness) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.instrumentalness) by session_id>,
#  <Feature: CUM_MIN(tf.instrumentalness) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_0) by session_id>,
#  <Feature: CUM_MIN(tf.key_0) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_1) by session_id>,
#  <Feature: CUM_MIN(tf.key_1) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_10) by session_id>,
#  <Feature: CUM_MIN(tf.key_10) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_11) by session_id>,
#  <Feature: CUM_MIN(tf.key_11) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_2) by session_id>,
#  <Feature: CUM_MIN(tf.key_2) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_3) by session_id>,
#  <Feature: CUM_MIN(tf.key_3) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_4) by session_id>,
#  <Feature: CUM_MIN(tf.key_4) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_5) by session_id>,
#  <Feature: CUM_MIN(tf.key_5) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_6) by session_id>,
#  <Feature: CUM_MIN(tf.key_6) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_7) by session_id>,
#  <Feature: CUM_MIN(tf.key_7) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_8) by session_id>,
#  <Feature: CUM_MIN(tf.key_8) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.key_9) by session_id>,
#  <Feature: CUM_MIN(tf.key_9) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.liveness) by session_id>,
#  <Feature: CUM_MIN(tf.liveness) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.loudness) by session_id>,
#  <Feature: CUM_MIN(tf.loudness) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.mechanism) by session_id>,
#  <Feature: CUM_MIN(tf.mechanism) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.mode_major) by session_id>,
#  <Feature: CUM_MIN(tf.mode_major) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.mode_minor) by session_id>,
#  <Feature: CUM_MIN(tf.mode_minor) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.organism) by session_id>,
#  <Feature: CUM_MIN(tf.organism) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.release_year) by session_id>,
#  <Feature: CUM_MIN(tf.release_year) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.speechiness) by session_id>,
#  <Feature: CUM_MIN(tf.speechiness) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.tempo) by session_id>,
#  <Feature: CUM_MIN(tf.tempo) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.time_signature_0) by session_id>,
#  <Feature: CUM_MIN(tf.time_signature_0) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.time_signature_1) by session_id>,
#  <Feature: CUM_MIN(tf.time_signature_1) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.time_signature_3) by session_id>,
#  <Feature: CUM_MIN(tf.time_signature_3) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.time_signature_4) by session_id>,
#  <Feature: CUM_MIN(tf.time_signature_4) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.time_signature_5) by session_id>,
#  <Feature: CUM_MIN(tf.time_signature_5) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.us_popularity_estimate) by session_id>,
#  <Feature: CUM_MIN(tf.us_popularity_estimate) by session_id_not_skipped>,
#  <Feature: CUM_MIN(tf.valence) by session_id>,
#  <Feature: CUM_MIN(tf.valence) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.acoustic_vector_0) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_0) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.acoustic_vector_1) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_1) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.acoustic_vector_2) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_2) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.acoustic_vector_3) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_3) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.acoustic_vector_4) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_4) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.acoustic_vector_5) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_5) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.acoustic_vector_6) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_6) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.acoustic_vector_7) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_7) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.acousticness) by session_id>,
#  <Feature: CUM_SUM(tf.acousticness) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.beat_strength) by session_id>,
#  <Feature: CUM_SUM(tf.beat_strength) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.bounciness) by session_id>,
#  <Feature: CUM_SUM(tf.bounciness) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.danceability) by session_id>,
#  <Feature: CUM_SUM(tf.danceability) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.duration) by session_id>,
#  <Feature: CUM_SUM(tf.duration) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.dyn_range_mean) by session_id>,
#  <Feature: CUM_SUM(tf.dyn_range_mean) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.energy) by session_id>,
#  <Feature: CUM_SUM(tf.energy) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.flatness) by session_id>,
#  <Feature: CUM_SUM(tf.flatness) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.instrumentalness) by session_id>,
#  <Feature: CUM_SUM(tf.instrumentalness) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_0) by session_id>,
#  <Feature: CUM_SUM(tf.key_0) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_1) by session_id>,
#  <Feature: CUM_SUM(tf.key_1) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_10) by session_id>,
#  <Feature: CUM_SUM(tf.key_10) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_11) by session_id>,
#  <Feature: CUM_SUM(tf.key_11) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_2) by session_id>,
#  <Feature: CUM_SUM(tf.key_2) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_3) by session_id>,
#  <Feature: CUM_SUM(tf.key_3) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_4) by session_id>,
#  <Feature: CUM_SUM(tf.key_4) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_5) by session_id>,
#  <Feature: CUM_SUM(tf.key_5) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_6) by session_id>,
#  <Feature: CUM_SUM(tf.key_6) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_7) by session_id>,
#  <Feature: CUM_SUM(tf.key_7) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_8) by session_id>,
#  <Feature: CUM_SUM(tf.key_8) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.key_9) by session_id>,
#  <Feature: CUM_SUM(tf.key_9) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.liveness) by session_id>,
#  <Feature: CUM_SUM(tf.liveness) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.loudness) by session_id>,
#  <Feature: CUM_SUM(tf.loudness) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.mechanism) by session_id>,
#  <Feature: CUM_SUM(tf.mechanism) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.mode_major) by session_id>,
#  <Feature: CUM_SUM(tf.mode_major) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.mode_minor) by session_id>,
#  <Feature: CUM_SUM(tf.mode_minor) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.organism) by session_id>,
#  <Feature: CUM_SUM(tf.organism) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.release_year) by session_id>,
#  <Feature: CUM_SUM(tf.release_year) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.speechiness) by session_id>,
#  <Feature: CUM_SUM(tf.speechiness) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.tempo) by session_id>,
#  <Feature: CUM_SUM(tf.tempo) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.time_signature_0) by session_id>,
#  <Feature: CUM_SUM(tf.time_signature_0) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.time_signature_1) by session_id>,
#  <Feature: CUM_SUM(tf.time_signature_1) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.time_signature_3) by session_id>,
#  <Feature: CUM_SUM(tf.time_signature_3) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.time_signature_4) by session_id>,
#  <Feature: CUM_SUM(tf.time_signature_4) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.time_signature_5) by session_id>,
#  <Feature: CUM_SUM(tf.time_signature_5) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.us_popularity_estimate) by session_id>,
#  <Feature: CUM_SUM(tf.us_popularity_estimate) by session_id_not_skipped>,
#  <Feature: CUM_SUM(tf.valence) by session_id>,
#  <Feature: CUM_SUM(tf.valence) by session_id_not_skipped>,
#  <Feature: DIFF(tf.acoustic_vector_0) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_0) by session_id_not_skipped>,
#  <Feature: DIFF(tf.acoustic_vector_1) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_1) by session_id_not_skipped>,
#  <Feature: DIFF(tf.acoustic_vector_2) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_2) by session_id_not_skipped>,
#  <Feature: DIFF(tf.acoustic_vector_3) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_3) by session_id_not_skipped>,
#  <Feature: DIFF(tf.acoustic_vector_4) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_4) by session_id_not_skipped>,
#  <Feature: DIFF(tf.acoustic_vector_5) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_5) by session_id_not_skipped>,
#  <Feature: DIFF(tf.acoustic_vector_6) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_6) by session_id_not_skipped>,
#  <Feature: DIFF(tf.acoustic_vector_7) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_7) by session_id_not_skipped>,
#  <Feature: DIFF(tf.acousticness) by session_id>,
#  <Feature: DIFF(tf.acousticness) by session_id_not_skipped>,
#  <Feature: DIFF(tf.beat_strength) by session_id>,
#  <Feature: DIFF(tf.beat_strength) by session_id_not_skipped>,
#  <Feature: DIFF(tf.bounciness) by session_id>,
#  <Feature: DIFF(tf.bounciness) by session_id_not_skipped>,
#  <Feature: DIFF(tf.danceability) by session_id>,
#  <Feature: DIFF(tf.danceability) by session_id_not_skipped>,
#  <Feature: DIFF(tf.duration) by session_id>,
#  <Feature: DIFF(tf.duration) by session_id_not_skipped>,
#  <Feature: DIFF(tf.dyn_range_mean) by session_id>,
#  <Feature: DIFF(tf.dyn_range_mean) by session_id_not_skipped>,
#  <Feature: DIFF(tf.energy) by session_id>,
#  <Feature: DIFF(tf.energy) by session_id_not_skipped>,
#  <Feature: DIFF(tf.flatness) by session_id>,
#  <Feature: DIFF(tf.flatness) by session_id_not_skipped>,
#  <Feature: DIFF(tf.instrumentalness) by session_id>,
#  <Feature: DIFF(tf.instrumentalness) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_0) by session_id>,
#  <Feature: DIFF(tf.key_0) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_1) by session_id>,
#  <Feature: DIFF(tf.key_1) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_10) by session_id>,
#  <Feature: DIFF(tf.key_10) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_11) by session_id>,
#  <Feature: DIFF(tf.key_11) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_2) by session_id>,
#  <Feature: DIFF(tf.key_2) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_3) by session_id>,
#  <Feature: DIFF(tf.key_3) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_4) by session_id>,
#  <Feature: DIFF(tf.key_4) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_5) by session_id>,
#  <Feature: DIFF(tf.key_5) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_6) by session_id>,
#  <Feature: DIFF(tf.key_6) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_7) by session_id>,
#  <Feature: DIFF(tf.key_7) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_8) by session_id>,
#  <Feature: DIFF(tf.key_8) by session_id_not_skipped>,
#  <Feature: DIFF(tf.key_9) by session_id>,
#  <Feature: DIFF(tf.key_9) by session_id_not_skipped>,
#  <Feature: DIFF(tf.liveness) by session_id>,
#  <Feature: DIFF(tf.liveness) by session_id_not_skipped>,
#  <Feature: DIFF(tf.loudness) by session_id>,
#  <Feature: DIFF(tf.loudness) by session_id_not_skipped>,
#  <Feature: DIFF(tf.mechanism) by session_id>,
#  <Feature: DIFF(tf.mechanism) by session_id_not_skipped>,
#  <Feature: DIFF(tf.mode_major) by session_id>,
#  <Feature: DIFF(tf.mode_major) by session_id_not_skipped>,
#  <Feature: DIFF(tf.mode_minor) by session_id>,
#  <Feature: DIFF(tf.mode_minor) by session_id_not_skipped>,
#  <Feature: DIFF(tf.organism) by session_id>,
#  <Feature: DIFF(tf.organism) by session_id_not_skipped>,
#  <Feature: DIFF(tf.release_year) by session_id>,
#  <Feature: DIFF(tf.release_year) by session_id_not_skipped>,
#  <Feature: DIFF(tf.speechiness) by session_id>,
#  <Feature: DIFF(tf.speechiness) by session_id_not_skipped>,
#  <Feature: DIFF(tf.tempo) by session_id>,
#  <Feature: DIFF(tf.tempo) by session_id_not_skipped>,
#  <Feature: DIFF(tf.time_signature_0) by session_id>,
#  <Feature: DIFF(tf.time_signature_0) by session_id_not_skipped>,
#  <Feature: DIFF(tf.time_signature_1) by session_id>,
#  <Feature: DIFF(tf.time_signature_1) by session_id_not_skipped>,
#  <Feature: DIFF(tf.time_signature_3) by session_id>,
#  <Feature: DIFF(tf.time_signature_3) by session_id_not_skipped>,
#  <Feature: DIFF(tf.time_signature_4) by session_id>,
#  <Feature: DIFF(tf.time_signature_4) by session_id_not_skipped>,
#  <Feature: DIFF(tf.time_signature_5) by session_id>,
#  <Feature: DIFF(tf.time_signature_5) by session_id_not_skipped>,
#  <Feature: DIFF(tf.us_popularity_estimate) by session_id>,
#  <Feature: DIFF(tf.us_popularity_estimate) by session_id_not_skipped>,
#  <Feature: DIFF(tf.valence) by session_id>,
#  <Feature: DIFF(tf.valence) by session_id_not_skipped>]

# %%
print(feature_defs[350])
ft.describe_feature(feature_defs[350])
# Out:
# <Feature: CUM_MAX(tf.loudness) by session_id>
# 'The cumulative maximum of the "loudness" for the instance of "tf" associated with this instance of "log" for each "session_id".'

# %%
# save feature matrix

feature_matrix.to_csv('../data/processed/feature_matrix_skip.csv')

# %%
feature_matrix.ww.schema
# Out:
#                                                    Logical Type  \
# Column
# session_id                                          Categorical
# session_position                                        Integer
# skip_1                                                  Boolean
# skip_2                                                  Boolean
# skip_3                                                  Boolean
# ...                                                         ...
# DIFF(tf.time_signature_5) by session_id_not_ski...       Double
# DIFF(tf.us_popularity_estimate) by session_id            Double
# DIFF(tf.us_popularity_estimate) by session_id_n...       Double
# DIFF(tf.valence) by session_id                           Double
# DIFF(tf.valence) by session_id_not_skipped               Double
#
#                                                    Semantic Tag(s)
# Column
# session_id                                            ['category']
# session_position                                       ['numeric']
# skip_1                                                          []
# skip_2                                                          []
# skip_3                                                          []
# ...                                                            ...
# DIFF(tf.time_signature_5) by session_id_not_ski...     ['numeric']
# DIFF(tf.us_popularity_estimate) by session_id          ['numeric']
# DIFF(tf.us_popularity_estimate) by session_id_n...     ['numeric']
# DIFF(tf.valence) by session_id                         ['numeric']
# DIFF(tf.valence) by session_id_not_skipped             ['numeric']
#
# [740 rows x 2 columns]

# %% [markdown]
# # Check the results of Featuretools

# %%
# load the feature matrix to check whether it was properly saved.

feature_matrix2 = pd.read_csv('../data/processed/feature_matrix_skip.csv')
feature_matrix2.head().T
# Out:
#                                                                                          0  \
# event_id                                                                                 0
# session_id                                          0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                         1
# skip_1                                                                               False
# skip_2                                                                               False
# ...                                                                                    ...
# DIFF(tf.time_signature_5) by session_id_not_ski...                                     NaN
# DIFF(tf.us_popularity_estimate) by session_id                                          NaN
# DIFF(tf.us_popularity_estimate) by session_id_n...                                     NaN
# DIFF(tf.valence) by session_id                                                         NaN
# DIFF(tf.valence) by session_id_not_skipped                                             NaN
#
#                                                                                          1  \
# event_id                                                                                20
# session_id                                          0_0000a72b-09ac-412f-b452-9b9e79bded8f
# session_position                                                                         1
# skip_1                                                                               False
# skip_2                                                                                True
# ...                                                                                    ...
# DIFF(tf.time_signature_5) by session_id_not_ski...                                     NaN
# DIFF(tf.us_popularity_estimate) by session_id                                          NaN
# DIFF(tf.us_popularity_estimate) by session_id_n...                                     NaN
# DIFF(tf.valence) by session_id                                                         NaN
# DIFF(tf.valence) by session_id_not_skipped                                             NaN
#
#                                                                                          2  \
# event_id                                                                                40
# session_id                                          0_00010fc5-b79e-4cdf-bc4c-f140d0f99a3a
# session_position                                                                         1
# skip_1                                                                               False
# skip_2                                                                               False
# ...                                                                                    ...
# DIFF(tf.time_signature_5) by session_id_not_ski...                                     0.0
# DIFF(tf.us_popularity_estimate) by session_id                                          NaN
# DIFF(tf.us_popularity_estimate) by session_id_n...                                1.191625
# DIFF(tf.valence) by session_id                                                         NaN
# DIFF(tf.valence) by session_id_not_skipped                                        0.324816
#
#                                                                                          3  \
# event_id                                                                                60
# session_id                                          0_00016a3d-9076-4f67-918f-f29e3ce160dc
# session_position                                                                         1
# skip_1                                                                                True
# skip_2                                                                                True
# ...                                                                                    ...
# DIFF(tf.time_signature_5) by session_id_not_ski...                                     0.0
# DIFF(tf.us_popularity_estimate) by session_id                                          NaN
# DIFF(tf.us_popularity_estimate) by session_id_n...                               -0.068586
# DIFF(tf.valence) by session_id                                                         NaN
# DIFF(tf.valence) by session_id_not_skipped                                        0.087566
#
#                                                                                          4
# event_id                                                                                80
# session_id                                          0_00018b58-deb8-4f98-ac5e-d7e01b346130
# session_position                                                                         1
# skip_1                                                                               False
# skip_2                                                                               False
# ...                                                                                    ...
# DIFF(tf.time_signature_5) by session_id_not_ski...                                     0.0
# DIFF(tf.us_popularity_estimate) by session_id                                          NaN
# DIFF(tf.us_popularity_estimate) by session_id_n...                               -0.358257
# DIFF(tf.valence) by session_id                                                         NaN
# DIFF(tf.valence) by session_id_not_skipped                                       -0.420744
#
# [741 rows x 5 columns]

# %%
# inspect the data of a session

a = feature_matrix2[feature_matrix2['session_id'] == '0_00006f66-33e5-4de7-a324-2d18e439fc1e']

a
# Out:
#         event_id                              session_id  session_position  \
# 0              0  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 1
# 10000          1  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 2
# 20000          2  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 3
# 30000          3  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 4
# 40000          4  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 5
# 50000          5  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 6
# 60000          6  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 7
# 70000          7  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 8
# 80000          8  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 9
# 90000          9  0_00006f66-33e5-4de7-a324-2d18e439fc1e                10
# 100000        10  0_00006f66-33e5-4de7-a324-2d18e439fc1e                11
# 109181        11  0_00006f66-33e5-4de7-a324-2d18e439fc1e                12
# 117610        12  0_00006f66-33e5-4de7-a324-2d18e439fc1e                13
# 125393        13  0_00006f66-33e5-4de7-a324-2d18e439fc1e                14
# 132629        14  0_00006f66-33e5-4de7-a324-2d18e439fc1e                15
# 139406        15  0_00006f66-33e5-4de7-a324-2d18e439fc1e                16
# 145748        16  0_00006f66-33e5-4de7-a324-2d18e439fc1e                17
# 151751        17  0_00006f66-33e5-4de7-a324-2d18e439fc1e                18
# 157434        18  0_00006f66-33e5-4de7-a324-2d18e439fc1e                19
# 162814        19  0_00006f66-33e5-4de7-a324-2d18e439fc1e                20
#
#         skip_1  skip_2  skip_3  not_skipped  context_switch  \
# 0        False   False   False         True               0
# 10000    False   False   False         True               0
# 20000    False   False   False         True               0
# 30000    False   False   False         True               0
# 40000    False   False   False         True               0
# 50000    False   False    True        False               0
# 60000     True    True    True        False               0
# 70000     True    True    True        False               0
# 80000    False    True    True        False               0
# 90000     True    True    True        False               0
# 100000    True    True    True        False               0
# 109181    True    True    True        False               0
# 117610    True    True    True        False               0
# 125393   False   False   False         True               0
# 132629   False    True    True        False               0
# 139406   False    True    True        False               0
# 145748   False    True    True        False               0
# 151751   False    True    True        False               0
# 157434    True    True    True        False               0
# 162814    True    True    True        False               0
#
#         no_pause_before_play  short_pause_before_play  ...  \
# 0                          0                        0  ...
# 10000                      1                        0  ...
# 20000                      1                        0  ...
# 30000                      1                        0  ...
# 40000                      1                        0  ...
# 50000                      1                        0  ...
# 60000                      1                        0  ...
# 70000                      1                        0  ...
# 80000                      1                        0  ...
# 90000                      1                        0  ...
# 100000                     1                        0  ...
# 109181                     1                        0  ...
# 117610                     1                        0  ...
# 125393                     1                        0  ...
# 132629                     1                        0  ...
# 139406                     0                        1  ...
# 145748                     1                        0  ...
# 151751                     1                        0  ...
# 157434                     1                        0  ...
# 162814                     1                        0  ...
#
#         DIFF(tf.time_signature_3) by session_id  \
# 0                                           NaN
# 10000                                       0.0
# 20000                                       0.0
# 30000                                       0.0
# 40000                                       0.0
# 50000                                       0.0
# 60000                                       0.0
# 70000                                       0.0
# 80000                                       0.0
# 90000                                       0.0
# 100000                                      0.0
# 109181                                      0.0
# 117610                                      0.0
# 125393                                      0.0
# 132629                                      0.0
# 139406                                      0.0
# 145748                                      0.0
# 151751                                      0.0
# 157434                                      0.0
# 162814                                      0.0
#
#         DIFF(tf.time_signature_3) by session_id_not_skipped  \
# 0                                                     NaN
# 10000                                                 0.0
# 20000                                                 0.0
# 30000                                                 0.0
# 40000                                                 0.0
# 50000                                                -1.0
# 60000                                                 0.0
# 70000                                                -1.0
# 80000                                                 0.0
# 90000                                                 0.0
# 100000                                                0.0
# 109181                                                0.0
# 117610                                               -1.0
# 125393                                                0.0
# 132629                                                0.0
# 139406                                                0.0
# 145748                                                0.0
# 151751                                                0.0
# 157434                                                0.0
# 162814                                                0.0
#
#         DIFF(tf.time_signature_4) by session_id  \
# 0                                           NaN
# 10000                                       0.0
# 20000                                       0.0
# 30000                                       0.0
# 40000                                       0.0
# 50000                                      -1.0
# 60000                                       1.0
# 70000                                       0.0
# 80000                                       0.0
# 90000                                       0.0
# 100000                                      0.0
# 109181                                     -1.0
# 117610                                      1.0
# 125393                                      0.0
# 132629                                      0.0
# 139406                                      0.0
# 145748                                      0.0
# 151751                                      0.0
# 157434                                      0.0
# 162814                                      0.0
#
#         DIFF(tf.time_signature_4) by session_id_not_skipped  \
# 0                                                     NaN
# 10000                                                 0.0
# 20000                                                 0.0
# 30000                                                 0.0
# 40000                                                 0.0
# 50000                                                 0.0
# 60000                                                 0.0
# 70000                                                 1.0
# 80000                                                 0.0
# 90000                                                 0.0
# 100000                                                0.0
# 109181                                               -1.0
# 117610                                                1.0
# 125393                                                0.0
# 132629                                                0.0
# 139406                                                0.0
# 145748                                                0.0
# 151751                                                0.0
# 157434                                                0.0
# 162814                                                0.0
#
#         DIFF(tf.time_signature_5) by session_id  \
# 0                                           NaN
# 10000                                       0.0
# 20000                                       0.0
# 30000                                       0.0
# 40000                                       0.0
# 50000                                       1.0
# 60000                                      -1.0
# 70000                                       0.0
# 80000                                       0.0
# 90000                                       0.0
# 100000                                      0.0
# 109181                                      1.0
# 117610                                     -1.0
# 125393                                      0.0
# 132629                                      0.0
# 139406                                      0.0
# 145748                                      0.0
# 151751                                      0.0
# 157434                                      0.0
# 162814                                      0.0
#
#         DIFF(tf.time_signature_5) by session_id_not_skipped  \
# 0                                                     NaN
# 10000                                                 0.0
# 20000                                                 0.0
# 30000                                                 0.0
# 40000                                                 0.0
# 50000                                                 1.0
# 60000                                                 0.0
# 70000                                                 0.0
# 80000                                                 0.0
# 90000                                                 0.0
# 100000                                                0.0
# 109181                                                1.0
# 117610                                                0.0
# 125393                                                0.0
# 132629                                                0.0
# 139406                                                0.0
# 145748                                                0.0
# 151751                                                0.0
# 157434                                                0.0
# 162814                                                0.0
#
#         DIFF(tf.us_popularity_estimate) by session_id  \
# 0                                                 NaN
# 10000                                       -0.071405
# 20000                                        0.103248
# 30000                                       -0.004938
# 40000                                        0.003460
# 50000                                       -0.000896
# 60000                                       -0.136035
# 70000                                       -2.617748
# 80000                                        2.754632
# 90000                                       -0.041017
# 100000                                       0.036032
# 109181                                      -0.120213
# 117610                                       0.122471
# 125393                                       0.003223
# 132629                                      -0.027534
# 139406                                       0.019326
# 145748                                      -0.128631
# 151751                                       0.116079
# 157434                                       0.019730
# 162814                                      -0.046112
#
#         DIFF(tf.us_popularity_estimate) by session_id_not_skipped  \
# 0                                                     NaN
# 10000                                           -0.071405
# 20000                                            0.103248
# 30000                                           -0.004938
# 40000                                            0.003460
# 50000                                            0.022073
# 60000                                           -0.133144
# 70000                                           -2.752594
# 80000                                           -0.000881
# 90000                                           -0.040328
# 100000                                           0.000951
# 109181                                          -0.120195
# 117610                                           0.015151
# 125393                                           0.000450
# 132629                                           0.040748
# 139406                                           0.034249
# 145748                                          -0.118111
# 151751                                           0.341319
# 157434                                           0.002770
# 162814                                          -0.047663
#
#         DIFF(tf.valence) by session_id  \
# 0                                  NaN
# 10000                         0.184898
# 20000                         0.036710
# 30000                         0.275558
# 40000                         0.003501
# 50000                         0.008161
# 60000                        -0.551661
# 70000                         0.280493
# 80000                        -0.051592
# 90000                        -0.080649
# 100000                       -0.219674
# 109181                        0.612355
# 117610                       -0.343810
# 125393                        0.231844
# 132629                       -0.125149
# 139406                       -0.262849
# 145748                        0.133304
# 151751                        0.282154
# 157434                       -0.196375
# 162814                        0.405967
#
#         DIFF(tf.valence) by session_id_not_skipped
# 0                                              NaN
# 10000                                     0.184898
# 20000                                     0.036710
# 30000                                     0.275558
# 40000                                     0.003501
# 50000                                     0.249168
# 60000                                    -0.648615
# 70000                                     0.212967
# 80000                                    -0.173766
# 90000                                    -0.347373
# 100000                                   -0.228300
# 109181                                    0.059952
# 117610                                   -0.085936
# 125393                                   -0.114533
# 132629                                   -0.069863
# 139406                                   -0.445556
# 145748                                   -0.291789
# 151751                                    0.149251
# 157434                                   -0.386486
# 162814                                    0.594560
#
# [20 rows x 741 columns]

# %%
# inspect whether the featuretools generated features considered the session and the order information. The answer appears yes.

a[['tf.speechiness','CUM_SUM(tf.speechiness) by session_id','session_id','CUM_SUM(tf.speechiness) by session_id_not_skipped','session_id_not_skipped','session_position']]
# Out:
#         tf.speechiness  CUM_SUM(tf.speechiness) by session_id  \
# 0             0.069717                               0.069717
# 10000         0.061158                               0.130874
# 20000         0.045354                               0.176229
# 30000         0.229936                               0.406164
# 40000         0.240980                               0.647144
# 50000         0.133586                               0.780730
# 60000         0.409848                               1.190578
# 70000         0.103687                               1.294266
# 80000         0.049853                               1.344119
# 90000         0.154609                               1.498729
# 100000        0.027932                               1.526660
# 109181        0.414651                               1.941311
# 117610        0.364139                               2.305451
# 125393        0.256456                               2.561906
# 132629        0.125605                               2.687512
# 139406        0.424763                               3.112275
# 145748        0.067412                               3.179687
# 151751        0.140268                               3.319955
# 157434        0.104258                               3.424213
# 162814        0.419025                               3.843238
#
#                                     session_id  \
# 0       0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 10000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 20000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 30000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 40000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 50000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 60000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 70000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 80000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 90000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 100000  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 109181  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 117610  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 125393  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 132629  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 139406  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 145748  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 151751  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 157434  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 162814  0_00006f66-33e5-4de7-a324-2d18e439fc1e
#
#         CUM_SUM(tf.speechiness) by session_id_not_skipped  \
# 0                                                0.069717
# 10000                                            0.130874
# 20000                                            0.176229
# 30000                                            0.406164
# 40000                                            0.647144
# 50000                                         4759.094724
# 60000                                         5784.135332
# 70000                                         6768.998141
# 80000                                         7727.900896
# 90000                                         8695.171707
# 100000                                        9634.508659
# 109181                                       10501.944815
# 117610                                       11305.278321
# 125393                                           0.903600
# 132629                                       12771.353272
# 139406                                       13407.368467
# 145748                                       14001.304933
# 151751                                       14567.028417
# 157434                                       15124.489732
# 162814                                       15646.707891
#
#                         session_id_not_skipped  session_position
# 0       0_00006f66-33e5-4de7-a324-2d18e439fc1e                 1
# 10000   0_00006f66-33e5-4de7-a324-2d18e439fc1e                 2
# 20000   0_00006f66-33e5-4de7-a324-2d18e439fc1e                 3
# 30000   0_00006f66-33e5-4de7-a324-2d18e439fc1e                 4
# 40000   0_00006f66-33e5-4de7-a324-2d18e439fc1e                 5
# 50000                                      NaN                 6
# 60000                                      NaN                 7
# 70000                                      NaN                 8
# 80000                                      NaN                 9
# 90000                                      NaN                10
# 100000                                     NaN                11
# 109181                                     NaN                12
# 117610                                     NaN                13
# 125393  0_00006f66-33e5-4de7-a324-2d18e439fc1e                14
# 132629                                     NaN                15
# 139406                                     NaN                16
# 145748                                     NaN                17
# 151751                                     NaN                18
# 157434                                     NaN                19
# 162814                                     NaN                20

# %%
sel_cols = [col for col in feature_matrix2.columns if 'by session_id_not_skipped' in col]
sel_cols
# Out:
# ['CUM_COUNT(session_id) by session_id_not_skipped',
#  'CUM_COUNT(session_id_not_skipped) by session_id_not_skipped',
#  'CUM_COUNT(track_id_clean) by session_id_not_skipped',
#  'CUM_MAX(context_switch) by session_id_not_skipped',
#  'CUM_MAX(context_type_catalog) by session_id_not_skipped',
#  'CUM_MAX(context_type_charts) by session_id_not_skipped',
#  'CUM_MAX(context_type_editorial_playlist) by session_id_not_skipped',
#  'CUM_MAX(context_type_personalized_playlist) by session_id_not_skipped',
#  'CUM_MAX(context_type_radio) by session_id_not_skipped',
#  'CUM_MAX(context_type_user_collection) by session_id_not_skipped',
#  'CUM_MAX(hist_user_behavior_reason_start_appload) by session_id_not_skipped',
#  'CUM_MAX(hist_user_behavior_reason_start_backbtn) by session_id_not_skipped',
#  'CUM_MAX(hist_user_behavior_reason_start_clickrow) by session_id_not_skipped',
#  'CUM_MAX(hist_user_behavior_reason_start_endplay) by session_id_not_skipped',
#  'CUM_MAX(hist_user_behavior_reason_start_fwdbtn) by session_id_not_skipped',
#  'CUM_MAX(hist_user_behavior_reason_start_playbtn) by session_id_not_skipped',
#  'CUM_MAX(hist_user_behavior_reason_start_remote) by session_id_not_skipped',
#  'CUM_MAX(hist_user_behavior_reason_start_trackdone) by session_id_not_skipped',
#  'CUM_MAX(hist_user_behavior_reason_start_trackerror) by session_id_not_skipped',
#  'CUM_MAX(hour_of_day) by session_id_not_skipped',
#  'CUM_MAX(long_pause_before_play) by session_id_not_skipped',
#  'CUM_MAX(no_pause_before_play) by session_id_not_skipped',
#  'CUM_MAX(session_position) by session_id_not_skipped',
#  'CUM_MAX(short_pause_before_play) by session_id_not_skipped',
#  'CUM_MEAN(context_switch) by session_id_not_skipped',
#  'CUM_MEAN(context_type_catalog) by session_id_not_skipped',
#  'CUM_MEAN(context_type_charts) by session_id_not_skipped',
#  'CUM_MEAN(context_type_editorial_playlist) by session_id_not_skipped',
#  'CUM_MEAN(context_type_personalized_playlist) by session_id_not_skipped',
#  'CUM_MEAN(context_type_radio) by session_id_not_skipped',
#  'CUM_MEAN(context_type_user_collection) by session_id_not_skipped',
#  'CUM_MEAN(hist_user_behavior_reason_start_appload) by session_id_not_skipped',
#  'CUM_MEAN(hist_user_behavior_reason_start_backbtn) by session_id_not_skipped',
#  'CUM_MEAN(hist_user_behavior_reason_start_clickrow) by session_id_not_skipped',
#  'CUM_MEAN(hist_user_behavior_reason_start_endplay) by session_id_not_skipped',
#  'CUM_MEAN(hist_user_behavior_reason_start_fwdbtn) by session_id_not_skipped',
#  'CUM_MEAN(hist_user_behavior_reason_start_playbtn) by session_id_not_skipped',
#  'CUM_MEAN(hist_user_behavior_reason_start_remote) by session_id_not_skipped',
#  'CUM_MEAN(hist_user_behavior_reason_start_trackdone) by session_id_not_skipped',
#  'CUM_MEAN(hist_user_behavior_reason_start_trackerror) by session_id_not_skipped',
#  'CUM_MEAN(hour_of_day) by session_id_not_skipped',
#  'CUM_MEAN(long_pause_before_play) by session_id_not_skipped',
#  'CUM_MEAN(no_pause_before_play) by session_id_not_skipped',
#  'CUM_MEAN(session_position) by session_id_not_skipped',
#  'CUM_MEAN(short_pause_before_play) by session_id_not_skipped',
#  'CUM_MIN(context_switch) by session_id_not_skipped',
#  'CUM_MIN(context_type_catalog) by session_id_not_skipped',
#  'CUM_MIN(context_type_charts) by session_id_not_skipped',
#  'CUM_MIN(context_type_editorial_playlist) by session_id_not_skipped',
#  'CUM_MIN(context_type_personalized_playlist) by session_id_not_skipped',
#  'CUM_MIN(context_type_radio) by session_id_not_skipped',
#  'CUM_MIN(context_type_user_collection) by session_id_not_skipped',
#  'CUM_MIN(hist_user_behavior_reason_start_appload) by session_id_not_skipped',
#  'CUM_MIN(hist_user_behavior_reason_start_backbtn) by session_id_not_skipped',
#  'CUM_MIN(hist_user_behavior_reason_start_clickrow) by session_id_not_skipped',
#  'CUM_MIN(hist_user_behavior_reason_start_endplay) by session_id_not_skipped',
#  'CUM_MIN(hist_user_behavior_reason_start_fwdbtn) by session_id_not_skipped',
#  'CUM_MIN(hist_user_behavior_reason_start_playbtn) by session_id_not_skipped',
#  'CUM_MIN(hist_user_behavior_reason_start_remote) by session_id_not_skipped',
#  'CUM_MIN(hist_user_behavior_reason_start_trackdone) by session_id_not_skipped',
#  'CUM_MIN(hist_user_behavior_reason_start_trackerror) by session_id_not_skipped',
#  'CUM_MIN(hour_of_day) by session_id_not_skipped',
#  'CUM_MIN(long_pause_before_play) by session_id_not_skipped',
#  'CUM_MIN(no_pause_before_play) by session_id_not_skipped',
#  'CUM_MIN(session_position) by session_id_not_skipped',
#  'CUM_MIN(short_pause_before_play) by session_id_not_skipped',
#  'CUM_SUM(context_switch) by session_id_not_skipped',
#  'CUM_SUM(context_type_catalog) by session_id_not_skipped',
#  'CUM_SUM(context_type_charts) by session_id_not_skipped',
#  'CUM_SUM(context_type_editorial_playlist) by session_id_not_skipped',
#  'CUM_SUM(context_type_personalized_playlist) by session_id_not_skipped',
#  'CUM_SUM(context_type_radio) by session_id_not_skipped',
#  'CUM_SUM(context_type_user_collection) by session_id_not_skipped',
#  'CUM_SUM(hist_user_behavior_reason_start_appload) by session_id_not_skipped',
#  'CUM_SUM(hist_user_behavior_reason_start_backbtn) by session_id_not_skipped',
#  'CUM_SUM(hist_user_behavior_reason_start_clickrow) by session_id_not_skipped',
#  'CUM_SUM(hist_user_behavior_reason_start_endplay) by session_id_not_skipped',
#  'CUM_SUM(hist_user_behavior_reason_start_fwdbtn) by session_id_not_skipped',
#  'CUM_SUM(hist_user_behavior_reason_start_playbtn) by session_id_not_skipped',
#  'CUM_SUM(hist_user_behavior_reason_start_remote) by session_id_not_skipped',
#  'CUM_SUM(hist_user_behavior_reason_start_trackdone) by session_id_not_skipped',
#  'CUM_SUM(hist_user_behavior_reason_start_trackerror) by session_id_not_skipped',
#  'CUM_SUM(hour_of_day) by session_id_not_skipped',
#  'CUM_SUM(long_pause_before_play) by session_id_not_skipped',
#  'CUM_SUM(no_pause_before_play) by session_id_not_skipped',
#  'CUM_SUM(session_position) by session_id_not_skipped',
#  'CUM_SUM(short_pause_before_play) by session_id_not_skipped',
#  'DIFF(context_switch) by session_id_not_skipped',
#  'DIFF(context_type_catalog) by session_id_not_skipped',
#  'DIFF(context_type_charts) by session_id_not_skipped',
#  'DIFF(context_type_editorial_playlist) by session_id_not_skipped',
#  'DIFF(context_type_personalized_playlist) by session_id_not_skipped',
#  'DIFF(context_type_radio) by session_id_not_skipped',
#  'DIFF(context_type_user_collection) by session_id_not_skipped',
#  'DIFF(hist_user_behavior_reason_start_appload) by session_id_not_skipped',
#  'DIFF(hist_user_behavior_reason_start_backbtn) by session_id_not_skipped',
#  'DIFF(hist_user_behavior_reason_start_clickrow) by session_id_not_skipped',
#  'DIFF(hist_user_behavior_reason_start_endplay) by session_id_not_skipped',
#  'DIFF(hist_user_behavior_reason_start_fwdbtn) by session_id_not_skipped',
#  'DIFF(hist_user_behavior_reason_start_playbtn) by session_id_not_skipped',
#  'DIFF(hist_user_behavior_reason_start_remote) by session_id_not_skipped',
#  'DIFF(hist_user_behavior_reason_start_trackdone) by session_id_not_skipped',
#  'DIFF(hist_user_behavior_reason_start_trackerror) by session_id_not_skipped',
#  'DIFF(hour_of_day) by session_id_not_skipped',
#  'DIFF(long_pause_before_play) by session_id_not_skipped',
#  'DIFF(no_pause_before_play) by session_id_not_skipped',
#  'DIFF(session_position) by session_id_not_skipped',
#  'DIFF(short_pause_before_play) by session_id_not_skipped',
#  'CUM_MAX(tf.acoustic_vector_0) by session_id_not_skipped',
#  'CUM_MAX(tf.acoustic_vector_1) by session_id_not_skipped',
#  'CUM_MAX(tf.acoustic_vector_2) by session_id_not_skipped',
#  'CUM_MAX(tf.acoustic_vector_3) by session_id_not_skipped',
#  'CUM_MAX(tf.acoustic_vector_4) by session_id_not_skipped',
#  'CUM_MAX(tf.acoustic_vector_5) by session_id_not_skipped',
#  'CUM_MAX(tf.acoustic_vector_6) by session_id_not_skipped',
#  'CUM_MAX(tf.acoustic_vector_7) by session_id_not_skipped',
#  'CUM_MAX(tf.acousticness) by session_id_not_skipped',
#  'CUM_MAX(tf.beat_strength) by session_id_not_skipped',
#  'CUM_MAX(tf.bounciness) by session_id_not_skipped',
#  'CUM_MAX(tf.danceability) by session_id_not_skipped',
#  'CUM_MAX(tf.duration) by session_id_not_skipped',
#  'CUM_MAX(tf.dyn_range_mean) by session_id_not_skipped',
#  'CUM_MAX(tf.energy) by session_id_not_skipped',
#  'CUM_MAX(tf.flatness) by session_id_not_skipped',
#  'CUM_MAX(tf.instrumentalness) by session_id_not_skipped',
#  'CUM_MAX(tf.key_0) by session_id_not_skipped',
#  'CUM_MAX(tf.key_1) by session_id_not_skipped',
#  'CUM_MAX(tf.key_10) by session_id_not_skipped',
#  'CUM_MAX(tf.key_11) by session_id_not_skipped',
#  'CUM_MAX(tf.key_2) by session_id_not_skipped',
#  'CUM_MAX(tf.key_3) by session_id_not_skipped',
#  'CUM_MAX(tf.key_4) by session_id_not_skipped',
#  'CUM_MAX(tf.key_5) by session_id_not_skipped',
#  'CUM_MAX(tf.key_6) by session_id_not_skipped',
#  'CUM_MAX(tf.key_7) by session_id_not_skipped',
#  'CUM_MAX(tf.key_8) by session_id_not_skipped',
#  'CUM_MAX(tf.key_9) by session_id_not_skipped',
#  'CUM_MAX(tf.liveness) by session_id_not_skipped',
#  'CUM_MAX(tf.loudness) by session_id_not_skipped',
#  'CUM_MAX(tf.mechanism) by session_id_not_skipped',
#  'CUM_MAX(tf.mode_major) by session_id_not_skipped',
#  'CUM_MAX(tf.mode_minor) by session_id_not_skipped',
#  'CUM_MAX(tf.organism) by session_id_not_skipped',
#  'CUM_MAX(tf.release_year) by session_id_not_skipped',
#  'CUM_MAX(tf.speechiness) by session_id_not_skipped',
#  'CUM_MAX(tf.tempo) by session_id_not_skipped',
#  'CUM_MAX(tf.time_signature_0) by session_id_not_skipped',
#  'CUM_MAX(tf.time_signature_1) by session_id_not_skipped',
#  'CUM_MAX(tf.time_signature_3) by session_id_not_skipped',
#  'CUM_MAX(tf.time_signature_4) by session_id_not_skipped',
#  'CUM_MAX(tf.time_signature_5) by session_id_not_skipped',
#  'CUM_MAX(tf.us_popularity_estimate) by session_id_not_skipped',
#  'CUM_MAX(tf.valence) by session_id_not_skipped',
#  'CUM_MEAN(tf.acoustic_vector_0) by session_id_not_skipped',
#  'CUM_MEAN(tf.acoustic_vector_1) by session_id_not_skipped',
#  'CUM_MEAN(tf.acoustic_vector_2) by session_id_not_skipped',
#  'CUM_MEAN(tf.acoustic_vector_3) by session_id_not_skipped',
#  'CUM_MEAN(tf.acoustic_vector_4) by session_id_not_skipped',
#  'CUM_MEAN(tf.acoustic_vector_5) by session_id_not_skipped',
#  'CUM_MEAN(tf.acoustic_vector_6) by session_id_not_skipped',
#  'CUM_MEAN(tf.acoustic_vector_7) by session_id_not_skipped',
#  'CUM_MEAN(tf.acousticness) by session_id_not_skipped',
#  'CUM_MEAN(tf.beat_strength) by session_id_not_skipped',
#  'CUM_MEAN(tf.bounciness) by session_id_not_skipped',
#  'CUM_MEAN(tf.danceability) by session_id_not_skipped',
#  'CUM_MEAN(tf.duration) by session_id_not_skipped',
#  'CUM_MEAN(tf.dyn_range_mean) by session_id_not_skipped',
#  'CUM_MEAN(tf.energy) by session_id_not_skipped',
#  'CUM_MEAN(tf.flatness) by session_id_not_skipped',
#  'CUM_MEAN(tf.instrumentalness) by session_id_not_skipped',
#  'CUM_MEAN(tf.key_0) by session_id_not_skipped',
#  'CUM_MEAN(tf.key_1) by session_id_not_skipped',
#  'CUM_MEAN(tf.key_10) by session_id_not_skipped',
#  'CUM_MEAN(tf.key_11) by session_id_not_skipped',
#  'CUM_MEAN(tf.key_2) by session_id_not_skipped',
#  'CUM_MEAN(tf.key_3) by session_id_not_skipped',
#  'CUM_MEAN(tf.key_4) by session_id_not_skipped',
#  'CUM_MEAN(tf.key_5) by session_id_not_skipped',
#  'CUM_MEAN(tf.key_6) by session_id_not_skipped',
#  'CUM_MEAN(tf.key_7) by session_id_not_skipped',
#  'CUM_MEAN(tf.key_8) by session_id_not_skipped',
#  'CUM_MEAN(tf.key_9) by session_id_not_skipped',
#  'CUM_MEAN(tf.liveness) by session_id_not_skipped',
#  'CUM_MEAN(tf.loudness) by session_id_not_skipped',
#  'CUM_MEAN(tf.mechanism) by session_id_not_skipped',
#  'CUM_MEAN(tf.mode_major) by session_id_not_skipped',
#  'CUM_MEAN(tf.mode_minor) by session_id_not_skipped',
#  'CUM_MEAN(tf.organism) by session_id_not_skipped',
#  'CUM_MEAN(tf.release_year) by session_id_not_skipped',
#  'CUM_MEAN(tf.speechiness) by session_id_not_skipped',
#  'CUM_MEAN(tf.tempo) by session_id_not_skipped',
#  'CUM_MEAN(tf.time_signature_0) by session_id_not_skipped',
#  'CUM_MEAN(tf.time_signature_1) by session_id_not_skipped',
#  'CUM_MEAN(tf.time_signature_3) by session_id_not_skipped',
#  'CUM_MEAN(tf.time_signature_4) by session_id_not_skipped',
#  'CUM_MEAN(tf.time_signature_5) by session_id_not_skipped',
#  'CUM_MEAN(tf.us_popularity_estimate) by session_id_not_skipped',
#  'CUM_MEAN(tf.valence) by session_id_not_skipped',
#  'CUM_MIN(tf.acoustic_vector_0) by session_id_not_skipped',
#  'CUM_MIN(tf.acoustic_vector_1) by session_id_not_skipped',
#  'CUM_MIN(tf.acoustic_vector_2) by session_id_not_skipped',
#  'CUM_MIN(tf.acoustic_vector_3) by session_id_not_skipped',
#  'CUM_MIN(tf.acoustic_vector_4) by session_id_not_skipped',
#  'CUM_MIN(tf.acoustic_vector_5) by session_id_not_skipped',
#  'CUM_MIN(tf.acoustic_vector_6) by session_id_not_skipped',
#  'CUM_MIN(tf.acoustic_vector_7) by session_id_not_skipped',
#  'CUM_MIN(tf.acousticness) by session_id_not_skipped',
#  'CUM_MIN(tf.beat_strength) by session_id_not_skipped',
#  'CUM_MIN(tf.bounciness) by session_id_not_skipped',
#  'CUM_MIN(tf.danceability) by session_id_not_skipped',
#  'CUM_MIN(tf.duration) by session_id_not_skipped',
#  'CUM_MIN(tf.dyn_range_mean) by session_id_not_skipped',
#  'CUM_MIN(tf.energy) by session_id_not_skipped',
#  'CUM_MIN(tf.flatness) by session_id_not_skipped',
#  'CUM_MIN(tf.instrumentalness) by session_id_not_skipped',
#  'CUM_MIN(tf.key_0) by session_id_not_skipped',
#  'CUM_MIN(tf.key_1) by session_id_not_skipped',
#  'CUM_MIN(tf.key_10) by session_id_not_skipped',
#  'CUM_MIN(tf.key_11) by session_id_not_skipped',
#  'CUM_MIN(tf.key_2) by session_id_not_skipped',
#  'CUM_MIN(tf.key_3) by session_id_not_skipped',
#  'CUM_MIN(tf.key_4) by session_id_not_skipped',
#  'CUM_MIN(tf.key_5) by session_id_not_skipped',
#  'CUM_MIN(tf.key_6) by session_id_not_skipped',
#  'CUM_MIN(tf.key_7) by session_id_not_skipped',
#  'CUM_MIN(tf.key_8) by session_id_not_skipped',
#  'CUM_MIN(tf.key_9) by session_id_not_skipped',
#  'CUM_MIN(tf.liveness) by session_id_not_skipped',
#  'CUM_MIN(tf.loudness) by session_id_not_skipped',
#  'CUM_MIN(tf.mechanism) by session_id_not_skipped',
#  'CUM_MIN(tf.mode_major) by session_id_not_skipped',
#  'CUM_MIN(tf.mode_minor) by session_id_not_skipped',
#  'CUM_MIN(tf.organism) by session_id_not_skipped',
#  'CUM_MIN(tf.release_year) by session_id_not_skipped',
#  'CUM_MIN(tf.speechiness) by session_id_not_skipped',
#  'CUM_MIN(tf.tempo) by session_id_not_skipped',
#  'CUM_MIN(tf.time_signature_0) by session_id_not_skipped',
#  'CUM_MIN(tf.time_signature_1) by session_id_not_skipped',
#  'CUM_MIN(tf.time_signature_3) by session_id_not_skipped',
#  'CUM_MIN(tf.time_signature_4) by session_id_not_skipped',
#  'CUM_MIN(tf.time_signature_5) by session_id_not_skipped',
#  'CUM_MIN(tf.us_popularity_estimate) by session_id_not_skipped',
#  'CUM_MIN(tf.valence) by session_id_not_skipped',
#  'CUM_SUM(tf.acoustic_vector_0) by session_id_not_skipped',
#  'CUM_SUM(tf.acoustic_vector_1) by session_id_not_skipped',
#  'CUM_SUM(tf.acoustic_vector_2) by session_id_not_skipped',
#  'CUM_SUM(tf.acoustic_vector_3) by session_id_not_skipped',
#  'CUM_SUM(tf.acoustic_vector_4) by session_id_not_skipped',
#  'CUM_SUM(tf.acoustic_vector_5) by session_id_not_skipped',
#  'CUM_SUM(tf.acoustic_vector_6) by session_id_not_skipped',
#  'CUM_SUM(tf.acoustic_vector_7) by session_id_not_skipped',
#  'CUM_SUM(tf.acousticness) by session_id_not_skipped',
#  'CUM_SUM(tf.beat_strength) by session_id_not_skipped',
#  'CUM_SUM(tf.bounciness) by session_id_not_skipped',
#  'CUM_SUM(tf.danceability) by session_id_not_skipped',
#  'CUM_SUM(tf.duration) by session_id_not_skipped',
#  'CUM_SUM(tf.dyn_range_mean) by session_id_not_skipped',
#  'CUM_SUM(tf.energy) by session_id_not_skipped',
#  'CUM_SUM(tf.flatness) by session_id_not_skipped',
#  'CUM_SUM(tf.instrumentalness) by session_id_not_skipped',
#  'CUM_SUM(tf.key_0) by session_id_not_skipped',
#  'CUM_SUM(tf.key_1) by session_id_not_skipped',
#  'CUM_SUM(tf.key_10) by session_id_not_skipped',
#  'CUM_SUM(tf.key_11) by session_id_not_skipped',
#  'CUM_SUM(tf.key_2) by session_id_not_skipped',
#  'CUM_SUM(tf.key_3) by session_id_not_skipped',
#  'CUM_SUM(tf.key_4) by session_id_not_skipped',
#  'CUM_SUM(tf.key_5) by session_id_not_skipped',
#  'CUM_SUM(tf.key_6) by session_id_not_skipped',
#  'CUM_SUM(tf.key_7) by session_id_not_skipped',
#  'CUM_SUM(tf.key_8) by session_id_not_skipped',
#  'CUM_SUM(tf.key_9) by session_id_not_skipped',
#  'CUM_SUM(tf.liveness) by session_id_not_skipped',
#  'CUM_SUM(tf.loudness) by session_id_not_skipped',
#  'CUM_SUM(tf.mechanism) by session_id_not_skipped',
#  'CUM_SUM(tf.mode_major) by session_id_not_skipped',
#  'CUM_SUM(tf.mode_minor) by session_id_not_skipped',
#  'CUM_SUM(tf.organism) by session_id_not_skipped',
#  'CUM_SUM(tf.release_year) by session_id_not_skipped',
#  'CUM_SUM(tf.speechiness) by session_id_not_skipped',
#  'CUM_SUM(tf.tempo) by session_id_not_skipped',
#  'CUM_SUM(tf.time_signature_0) by session_id_not_skipped',
#  'CUM_SUM(tf.time_signature_1) by session_id_not_skipped',
#  'CUM_SUM(tf.time_signature_3) by session_id_not_skipped',
#  'CUM_SUM(tf.time_signature_4) by session_id_not_skipped',
#  'CUM_SUM(tf.time_signature_5) by session_id_not_skipped',
#  'CUM_SUM(tf.us_popularity_estimate) by session_id_not_skipped',
#  'CUM_SUM(tf.valence) by session_id_not_skipped',
#  'DIFF(tf.acoustic_vector_0) by session_id_not_skipped',
#  'DIFF(tf.acoustic_vector_1) by session_id_not_skipped',
#  'DIFF(tf.acoustic_vector_2) by session_id_not_skipped',
#  'DIFF(tf.acoustic_vector_3) by session_id_not_skipped',
#  'DIFF(tf.acoustic_vector_4) by session_id_not_skipped',
#  'DIFF(tf.acoustic_vector_5) by session_id_not_skipped',
#  'DIFF(tf.acoustic_vector_6) by session_id_not_skipped',
#  'DIFF(tf.acoustic_vector_7) by session_id_not_skipped',
#  'DIFF(tf.acousticness) by session_id_not_skipped',
#  'DIFF(tf.beat_strength) by session_id_not_skipped',
#  'DIFF(tf.bounciness) by session_id_not_skipped',
#  'DIFF(tf.danceability) by session_id_not_skipped',
#  'DIFF(tf.duration) by session_id_not_skipped',
#  'DIFF(tf.dyn_range_mean) by session_id_not_skipped',
#  'DIFF(tf.energy) by session_id_not_skipped',
#  'DIFF(tf.flatness) by session_id_not_skipped',
#  'DIFF(tf.instrumentalness) by session_id_not_skipped',
#  'DIFF(tf.key_0) by session_id_not_skipped',
#  'DIFF(tf.key_1) by session_id_not_skipped',
#  'DIFF(tf.key_10) by session_id_not_skipped',
#  'DIFF(tf.key_11) by session_id_not_skipped',
#  'DIFF(tf.key_2) by session_id_not_skipped',
#  'DIFF(tf.key_3) by session_id_not_skipped',
#  'DIFF(tf.key_4) by session_id_not_skipped',
#  'DIFF(tf.key_5) by session_id_not_skipped',
#  'DIFF(tf.key_6) by session_id_not_skipped',
#  'DIFF(tf.key_7) by session_id_not_skipped',
#  'DIFF(tf.key_8) by session_id_not_skipped',
#  'DIFF(tf.key_9) by session_id_not_skipped',
#  'DIFF(tf.liveness) by session_id_not_skipped',
#  'DIFF(tf.loudness) by session_id_not_skipped',
#  'DIFF(tf.mechanism) by session_id_not_skipped',
#  'DIFF(tf.mode_major) by session_id_not_skipped',
#  'DIFF(tf.mode_minor) by session_id_not_skipped',
#  'DIFF(tf.organism) by session_id_not_skipped',
#  'DIFF(tf.release_year) by session_id_not_skipped',
#  'DIFF(tf.speechiness) by session_id_not_skipped',
#  'DIFF(tf.tempo) by session_id_not_skipped',
#  'DIFF(tf.time_signature_0) by session_id_not_skipped',
#  'DIFF(tf.time_signature_1) by session_id_not_skipped',
#  'DIFF(tf.time_signature_3) by session_id_not_skipped',
#  'DIFF(tf.time_signature_4) by session_id_not_skipped',
#  'DIFF(tf.time_signature_5) by session_id_not_skipped',
#  'DIFF(tf.us_popularity_estimate) by session_id_not_skipped',
#  'DIFF(tf.valence) by session_id_not_skipped']

# %%
feature_matrix2['session_id_not_skipped'].isna()
# Out:
# 0         False
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 167875    False
# 167876     True
# 167877     True
# 167878     True
# 167879    False
# Name: session_id_not_skipped, Length: 167880, dtype: bool

# %%
feature_matrix2.loc[feature_matrix2['session_id_not_skipped'].isna(),sel_cols] = np.nan
b = feature_matrix2[feature_matrix2['session_id'] == '0_00006f66-33e5-4de7-a324-2d18e439fc1e']
b[['tf.speechiness','CUM_SUM(tf.speechiness) by session_id','session_id','CUM_SUM(tf.speechiness) by session_id_not_skipped','session_id_not_skipped','session_position']]
# Out:
#         tf.speechiness  CUM_SUM(tf.speechiness) by session_id  \
# 0             0.069717                               0.069717
# 10000         0.061158                               0.130874
# 20000         0.045354                               0.176229
# 30000         0.229936                               0.406164
# 40000         0.240980                               0.647144
# 50000         0.133586                               0.780730
# 60000         0.409848                               1.190578
# 70000         0.103687                               1.294266
# 80000         0.049853                               1.344119
# 90000         0.154609                               1.498729
# 100000        0.027932                               1.526660
# 109181        0.414651                               1.941311
# 117610        0.364139                               2.305451
# 125393        0.256456                               2.561906
# 132629        0.125605                               2.687512
# 139406        0.424763                               3.112275
# 145748        0.067412                               3.179687
# 151751        0.140268                               3.319955
# 157434        0.104258                               3.424213
# 162814        0.419025                               3.843238
#
#                                     session_id  \
# 0       0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 10000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 20000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 30000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 40000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 50000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 60000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 70000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 80000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 90000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 100000  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 109181  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 117610  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 125393  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 132629  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 139406  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 145748  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 151751  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 157434  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 162814  0_00006f66-33e5-4de7-a324-2d18e439fc1e
#
#         CUM_SUM(tf.speechiness) by session_id_not_skipped  \
# 0                                                0.069717
# 10000                                            0.130874
# 20000                                            0.176229
# 30000                                            0.406164
# 40000                                            0.647144
# 50000                                                 NaN
# 60000                                                 NaN
# 70000                                                 NaN
# 80000                                                 NaN
# 90000                                                 NaN
# 100000                                                NaN
# 109181                                                NaN
# 117610                                                NaN
# 125393                                           0.903600
# 132629                                                NaN
# 139406                                                NaN
# 145748                                                NaN
# 151751                                                NaN
# 157434                                                NaN
# 162814                                                NaN
#
#                         session_id_not_skipped  session_position
# 0       0_00006f66-33e5-4de7-a324-2d18e439fc1e                 1
# 10000   0_00006f66-33e5-4de7-a324-2d18e439fc1e                 2
# 20000   0_00006f66-33e5-4de7-a324-2d18e439fc1e                 3
# 30000   0_00006f66-33e5-4de7-a324-2d18e439fc1e                 4
# 40000   0_00006f66-33e5-4de7-a324-2d18e439fc1e                 5
# 50000                                      NaN                 6
# 60000                                      NaN                 7
# 70000                                      NaN                 8
# 80000                                      NaN                 9
# 90000                                      NaN                10
# 100000                                     NaN                11
# 109181                                     NaN                12
# 117610                                     NaN                13
# 125393  0_00006f66-33e5-4de7-a324-2d18e439fc1e                14
# 132629                                     NaN                15
# 139406                                     NaN                16
# 145748                                     NaN                17
# 151751                                     NaN                18
# 157434                                     NaN                19
# 162814                                     NaN                20

# %%
feature_matrix3 = feature_matrix2.sort_values(by = ['session_id','session_position']).copy()
start_time = time.time()
for s_id in pd.unique(df['session_id']):
    temp = []
    temp = feature_matrix3[feature_matrix3['session_id']==s_id]
    temp.fillna(method = 'ffill', axis = 0, inplace=True)
    feature_matrix3[feature_matrix3['session_id']==s_id] = temp

print('***It takes ',(time.time() - start_time), ' secs.***')
    

#feature_matrix4 = feature_matrix3.groupby(['session_id']).fillna(method = 'ffill')
#feature_matrix3.fillna(method = 'ffill', axis = 0, inplace=True)

c = feature_matrix3[feature_matrix3['session_id'] == '0_00006f66-33e5-4de7-a324-2d18e439fc1e']
c[['tf.speechiness','CUM_SUM(tf.speechiness) by session_id','session_id','CUM_SUM(tf.speechiness) by session_id_not_skipped','session_id_not_skipped','not_skipped','session_position']]
# Out:
# ***It takes  926.4477832317352  secs.***
#         tf.speechiness  CUM_SUM(tf.speechiness) by session_id  \
# 0             0.069717                               0.069717
# 10000         0.061158                               0.130874
# 20000         0.045354                               0.176229
# 30000         0.229936                               0.406164
# 40000         0.240980                               0.647144
# 50000         0.133586                               0.780730
# 60000         0.409848                               1.190578
# 70000         0.103687                               1.294266
# 80000         0.049853                               1.344119
# 90000         0.154609                               1.498729
# 100000        0.027932                               1.526660
# 109181        0.414651                               1.941311
# 117610        0.364139                               2.305451
# 125393        0.256456                               2.561906
# 132629        0.125605                               2.687512
# 139406        0.424763                               3.112275
# 145748        0.067412                               3.179687
# 151751        0.140268                               3.319955
# 157434        0.104258                               3.424213
# 162814        0.419025                               3.843238
#
#                                     session_id  \
# 0       0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 10000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 20000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 30000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 40000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 50000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 60000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 70000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 80000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 90000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 100000  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 109181  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 117610  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 125393  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 132629  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 139406  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 145748  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 151751  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 157434  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 162814  0_00006f66-33e5-4de7-a324-2d18e439fc1e
#
#         CUM_SUM(tf.speechiness) by session_id_not_skipped  \
# 0                                                0.069717
# 10000                                            0.130874
# 20000                                            0.176229
# 30000                                            0.406164
# 40000                                            0.647144
# 50000                                            0.647144
# 60000                                            0.647144
# 70000                                            0.647144
# 80000                                            0.647144
# 90000                                            0.647144
# 100000                                           0.647144
# 109181                                           0.647144
# 117610                                           0.647144
# 125393                                           0.903600
# 132629                                           0.903600
# 139406                                           0.903600
# 145748                                           0.903600
# 151751                                           0.903600
# 157434                                           0.903600
# 162814                                           0.903600
#
#                         session_id_not_skipped  not_skipped  session_position
# 0       0_00006f66-33e5-4de7-a324-2d18e439fc1e         True                 1
# 10000   0_00006f66-33e5-4de7-a324-2d18e439fc1e         True                 2
# 20000   0_00006f66-33e5-4de7-a324-2d18e439fc1e         True                 3
# 30000   0_00006f66-33e5-4de7-a324-2d18e439fc1e         True                 4
# 40000   0_00006f66-33e5-4de7-a324-2d18e439fc1e         True                 5
# 50000   0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                 6
# 60000   0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                 7
# 70000   0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                 8
# 80000   0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                 9
# 90000   0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                10
# 100000  0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                11
# 109181  0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                12
# 117610  0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                13
# 125393  0_00006f66-33e5-4de7-a324-2d18e439fc1e         True                14
# 132629  0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                15
# 139406  0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                16
# 145748  0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                17
# 151751  0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                18
# 157434  0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                19
# 162814  0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                20

# %%
d = feature_matrix3[feature_matrix3['session_id'] == '0_0000a72b-09ac-412f-b452-9b9e79bded8f']
d[['tf.speechiness','CUM_SUM(tf.speechiness) by session_id','session_id','CUM_SUM(tf.speechiness) by session_id_not_skipped','session_id_not_skipped','not_skipped','session_position']]
# Out:
#         tf.speechiness  CUM_SUM(tf.speechiness) by session_id  \
# 1             0.192012                               0.192012
# 10001         0.068105                               0.260117
# 20001         0.075064                               0.335181
# 30001         0.045026                               0.380207
# 40001         0.124050                               0.504257
# 50001         0.239021                               0.743278
# 60001         0.039155                               0.782433
# 70001         0.041675                               0.824108
# 80001         0.134822                               0.958929
# 90001         0.140254                               1.099183
# 100001        0.134822                               1.234005
# 109182        0.140254                               1.374259
# 117611        0.262717                               1.636976
# 125394        0.061724                               1.698700
# 132630        0.045784                               1.744484
# 139407        0.062405                               1.806889
# 145749        0.045784                               1.852672
# 151752        0.062405                               1.915078
# 157435        0.043028                               1.958106
# 162815        0.048796                               2.006902
#
#                                     session_id  \
# 1       0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 10001   0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 20001   0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 30001   0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 40001   0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 50001   0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 60001   0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 70001   0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 80001   0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 90001   0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 100001  0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 109182  0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 117611  0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 125394  0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 132630  0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 139407  0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 145749  0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 151752  0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 157435  0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 162815  0_0000a72b-09ac-412f-b452-9b9e79bded8f
#
#         CUM_SUM(tf.speechiness) by session_id_not_skipped  \
# 1                                                     NaN
# 10001                                                 NaN
# 20001                                                 NaN
# 30001                                                 NaN
# 40001                                                 NaN
# 50001                                                 NaN
# 60001                                                 NaN
# 70001                                                 NaN
# 80001                                                 NaN
# 90001                                                 NaN
# 100001                                           0.134822
# 109182                                           0.275076
# 117611                                           0.275076
# 125394                                           0.336800
# 132630                                           0.336800
# 139407                                           0.336800
# 145749                                           0.382583
# 151752                                           0.382583
# 157435                                           0.425612
# 162815                                           0.474408
#
#                         session_id_not_skipped  not_skipped  session_position
# 1                                          NaN        False                 1
# 10001                                      NaN        False                 2
# 20001                                      NaN        False                 3
# 30001                                      NaN        False                 4
# 40001                                      NaN        False                 5
# 50001                                      NaN        False                 6
# 60001                                      NaN        False                 7
# 70001                                      NaN        False                 8
# 80001                                      NaN        False                 9
# 90001                                      NaN        False                10
# 100001  0_0000a72b-09ac-412f-b452-9b9e79bded8f         True                11
# 109182  0_0000a72b-09ac-412f-b452-9b9e79bded8f         True                12
# 117611  0_0000a72b-09ac-412f-b452-9b9e79bded8f        False                13
# 125394  0_0000a72b-09ac-412f-b452-9b9e79bded8f         True                14
# 132630  0_0000a72b-09ac-412f-b452-9b9e79bded8f        False                15
# 139407  0_0000a72b-09ac-412f-b452-9b9e79bded8f        False                16
# 145749  0_0000a72b-09ac-412f-b452-9b9e79bded8f         True                17
# 151752  0_0000a72b-09ac-412f-b452-9b9e79bded8f        False                18
# 157435  0_0000a72b-09ac-412f-b452-9b9e79bded8f         True                19
# 162815  0_0000a72b-09ac-412f-b452-9b9e79bded8f         True                20

# %%
feature_matrix.to_csv('../data/processed/feature_matrix_skip_processed.csv')

# %% [markdown]
# # Scale standardization & training/testing data split will be performed at the model fitting stage.
