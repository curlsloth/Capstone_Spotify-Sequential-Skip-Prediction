# %% [markdown]
# # **Will you skip this music track or not?**
#
#
# The public part of the dataset consists of roughly 130 million listening sessions with associated user interactions on the Spotify service.
#
# The task is to predict whether individual tracks encountered in a listening session will be skipped by a particular user. In order to do this, complete information about the first half of a user’s listening session is provided, while the prediction is to be carried out on the second half. Participants have access to metadata, as well as acoustic descriptors, for all the tracks encountered in listening sessions.
#
# https://www.aicrowd.com/challenges/spotify-sequential-skip-prediction-challenge
#
# Brost, B., Mehrotra, R., & Jehan, T. (2019, May). The music streaming sessions dataset. In The World Wide Web Conference (pp. 2594-2600).

# %% [markdown]
# As the entire dataset is too big to experiment data manipulation, Spotify provided a mini dataset for this purpose.
#
# In this script, we will do data wrangling to inspect the quality of the data, and do data engineering to generate features for machine learning modeling.

# %% [markdown]
# # Mount Google drive to Colab

# %%
# # For Colab only
#from google.colab import drive
#drive.mount('/content/drive')
#%cd /content/drive/MyDrive/Capstone_SpotifyStreaming/notebooks

#!pip install featuretools==0.4.0
#!pip install -U featuretools
#!pip install featuretools

# # check the installed packages
# pip list -v

# %%
import numpy as np
import pandas as pd
import featuretools as ft
import time
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load the data and perform some data cleaning/re-coding as described in 2_mini_EDA

# %%
# load the track information (mini version)

tf_df = pd.read_csv('../data/raw/data/track_features/tf_mini.csv')
log_df = pd.read_csv('../data/raw/data/training_set/log_mini.csv')

# %%
# perform some data cleaning/re-coding as described in 2_mini_EDA

tf_df_dummy = pd.get_dummies(tf_df, columns=['key','time_signature','mode'])
log_df_dummy = pd.get_dummies(log_df.drop(columns = ['session_length',  'hist_user_behavior_reason_end', 'hist_user_behavior_n_seekfwd','hist_user_behavior_n_seekback']), columns=['hist_user_behavior_reason_start', 'context_type'])

# %%
tf_df_dummy.head().T

# %%
log_df_dummy.head().T

# %% [markdown]
# # add skipping information as new columns

# %%
session_id = log_df_dummy['session_id'].unique()
print('number of sessions in this mini dataset:',len(session_id))

# %%
# the function of integrating the skipping labels into one column
def skip_label(df):
    skip = (df['not_skipped']==False).astype(int)*4 # no skip: 0, ultra-late skip: 4
    # It has to go under this order. If skip_1 = True, then skip_2 and _3 will be True too.
    skip[df['skip_3']==True] = 3 # late skip
    skip[df['skip_2']==True] = 2 # mid skip
    skip[df['skip_1']==True] = 1 # early skip
    return skip

log_df_dummy['skip_label'] = skip_label(log_df_dummy)

# %%
# make a column which has session ID and skip info
log_df_dummy['session_id_skip_label'] = log_df_dummy['session_id'] + '_skip_' + log_df_dummy['skip_label'].astype(str)
log_df_dummy['session_id_skip_1_False'] = log_df_dummy['session_id'] * (log_df_dummy['skip_1'] == False)
log_df_dummy['session_id_skip_1_True'] = log_df_dummy['session_id'] * (log_df_dummy['skip_1'] == True)
log_df_dummy['session_id_not_skipped_True'] = log_df_dummy['session_id'] * (log_df_dummy['not_skipped'] == True)
log_df_dummy['session_id_not_skipped_False'] = log_df_dummy['session_id'] * (log_df_dummy['not_skipped'] == False)

log_df_dummy.head(10).T

# %% [markdown]
# # Calculate the feature distance/similarity between adjacent tracks
#
# The track information dataframe contains acoustic analysis and scores of each track on 8 acoustic features (see: https://benanne.github.io/2014/08/05/spotify-cnns.html). Therefore, within each session, I would like to calculate the ***distance*** or ***similarity*** of each track to the other tracks.

# %%
# extract the acoustic features of each track
df = log_df_dummy.merge(tf_df_dummy[['track_id','acousticness','beat_strength','danceability',
                                     'dyn_range_mean', 'energy', 'flatness','instrumentalness', 'liveness', 
                                     'loudness', 'mechanism', 'organism','speechiness','valence',
                                     'acoustic_vector_0','acoustic_vector_1', 'acoustic_vector_2', 'acoustic_vector_3',
                                     'acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6','acoustic_vector_7']], 
                        left_on = 'track_id_clean', 
                        right_on = 'track_id')
df.sort_values(by = ['session_id', 'session_position'],inplace = True)
df.head().T

# %%
temp_data = df.loc[df['session_id'] == session_id[0]]
temp_data

# %%
def cal_dist(x):
    from scipy.spatial.distance import cdist
    Y_euc = cdist(x, x, 'euclidean')
    Y_cos = cdist(x, x, 'cosine')
    Y_man = cdist(x, x, 'cityblock')
    # The 1st track of each session should have unreasonably far distance
    euc_dist = [0]
    cos_dist = [0]
    man_dist = [0]
    for n in range(1,len(x)):
        euc_dist.append(Y_euc[n,n-1])
        cos_dist.append(Y_cos[n,n-1])
        man_dist.append(Y_man[n,n-1])
    return euc_dist, cos_dist, man_dist

# %%
# calculate the distance/similarity within each session
from sklearn.preprocessing import StandardScaler

# as the last 20% of the rows of each session will be used as the testing dataset, they should not be fitted by the scaler
train_perc = 0.8

sel_col_names = ['skip_label','acousticness','beat_strength','danceability',
                        'dyn_range_mean', 'energy', 'flatness','instrumentalness', 'liveness', 
                        'loudness', 'mechanism', 'organism','speechiness','valence',
                        'acoustic_vector_0','acoustic_vector_1', 'acoustic_vector_2', 'acoustic_vector_3',
                        'acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6','acoustic_vector_7']

start_time = time.time()

for s_id in session_id:
    temp_data = []
    temp_mat = []
    temp_data = df.loc[df['session_id'] == s_id, sel_col_names]
    temp_mat = temp_data.drop(columns = ['skip_label']).copy()
    scaler = StandardScaler()
    scaler.fit(temp_mat[0:round(len(temp_mat)*train_perc)])
    temp_mat_scaled = scaler.transform(temp_mat)
#     temp_mat_scaled_skip0 = temp_mat_scaled[temp_data['skip_label']==0]
#     temp_mat_scaled_skip1 = temp_mat_scaled[temp_data['skip_label']==1]
#     temp_mat_scaled_skipR = temp_mat_scaled[temp_data['skip_label']>1]
    
    
    euc_dist_all, cos_dist_all, man_dist_all = cal_dist(temp_mat_scaled)
    df.loc[temp_data.index, 'euc_dist_all'] = euc_dist_all
    df.loc[temp_data.index, 'cos_dist_all'] = cos_dist_all
    df.loc[temp_data.index, 'man_dist_all'] = man_dist_all
    
#     euc_dist_skip0, cos_dist_skip0, man_dist_skip0 = cal_dist(temp_mat_scaled_skip0)
#     loc_index0 = temp_data.index[temp_data['skip_label']==0].tolist()
#     df.loc[loc_index0, 'euc_dist_skip0'] = euc_dist_skip0
#     df.loc[loc_index0, 'cos_dist_skip0'] = cos_dist_skip0
#     df.loc[loc_index0, 'man_dist_skip0'] = man_dist_skip0
    
#     euc_dist_skip1, cos_dist_skip1, man_dist_skip1 = cal_dist(temp_mat_scaled_skip1)
#     loc_index1 = temp_data.index[temp_data['skip_label']==1].tolist()
#     df.loc[loc_index1, 'euc_dist_skip1'] = euc_dist_skip1
#     df.loc[loc_index1, 'cos_dist_skip1'] = cos_dist_skip1
#     df.loc[loc_index1, 'man_dist_skip1'] = man_dist_skip1
    
#     euc_dist_skipR, cos_dist_skipR, man_dist_skipR = cal_dist(temp_mat_scaled_skipR)
#     loc_indexR = temp_data.index[temp_data['skip_label']>1].tolist()
#     df.loc[loc_indexR, 'euc_dist_skipR'] = euc_dist_skipR
#     df.loc[loc_indexR, 'cos_dist_skipR'] = cos_dist_skipR
#     df.loc[loc_indexR, 'man_dist_skipR'] = man_dist_skipR

print('***It takes ',(time.time() - start_time)/60, ' minutes.***')

# %%
log_df_dummy2 = df.drop(columns = ['skip_label','track_id','acousticness','beat_strength','danceability',
                                     'dyn_range_mean', 'energy', 'flatness','instrumentalness', 'liveness', 
                                     'loudness', 'mechanism', 'organism','speechiness','valence',
                                     'acoustic_vector_0','acoustic_vector_1', 'acoustic_vector_2', 'acoustic_vector_3',
                                     'acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6','acoustic_vector_7'])
log_df_dummy2['session_id_skip_label'] = log_df_dummy2['session_id_skip_label'].astype('category')
log_df_dummy2['session_id_skip_1_False'] = log_df_dummy2['session_id_skip_1_False'].astype('category')
log_df_dummy2['session_id_skip_1_True'] = log_df_dummy2['session_id_skip_1_True'].astype('category')
log_df_dummy2['session_id_not_skipped_True'] = log_df_dummy2['session_id_not_skipped_True'].astype('category')
log_df_dummy2['session_id_not_skipped_False'] = log_df_dummy2['session_id_not_skipped_False'].astype('category')

# %% [markdown]
# # **Use featuretool to do automatic feature engineering**

# %%
#First, initializing an EntitySet with a name
es = ft.EntitySet(id="spotify_data")

# %%
from woodwork.logical_types import Categorical, PostalCode

es = es.add_dataframe(
    dataframe_name="tf",
    dataframe=tf_df_dummy,
    index="track_id",
)

es

# %%
es['tf'].ww.schema

# %%
# add dataframe
# the 'session_position' contains order information within each session

es = es.add_dataframe(
    dataframe_name="log", dataframe=log_df_dummy2, make_index = True, index="event_id", time_index="session_position",
)

es

# %%
es['log'].ww.schema

# %%
# When two DataFrames have a one-to-many relationship, we call the “one” DataFrame, the “parent DataFrame”. A relationship between a parent and child is defined like this:
# (parent_dataframe, parent_column, child_dataframe, child_column)
es = es.add_relationship("tf", "track_id", "log", "track_id_clean")
es

# %%
# turn on "features_only = True" to experiment with the function without computing the feature_matrix

primi_parameters = {
    "include_groupby_columns":{"log": ["session_id","session_id_skip_1_False","session_id_skip_1_True","session_id_not_skipped_True","session_id_not_skipped_False"]},
    "ignore_groupby_dataframes": ["tf"],
    "ignore_columns": {"log":["context_type_catalog","context_type_charts","context_type_editorial_playlist","context_type_personalized_playlist","context_type_radio","context_type_user_collection","hour_of_day","date"]}
                   }
primi_parameters

# %%
primi_parameters_ignoreCategoricalAcoustic = primi_parameters.copy()


key_cols = [col for col in tf_df_dummy.columns if 'key_' in col]
time_cols = [col for col in tf_df_dummy.columns if 'time_signature_' in col]

primi_parameters_ignoreCategoricalAcoustic['ignore_columns']['tf'] = key_cols+time_cols
primi_parameters_ignoreCategoricalAcoustic

# %%
feature_defs_test = ft.dfs(entityset=es,
                        target_dataframe_name="log",
                        groupby_trans_primitives=["Diff","CumSum", "CumMean", "CumMin", "CumMax"],
                        agg_primitives=[],
                        trans_primitives=[],
                        primitive_options={"diff": primi_parameters,
                                           "cum_sum": primi_parameters,
                                           "cum_mean": primi_parameters,
                                           "cum_min": primi_parameters_ignoreCategoricalAcoustic,
                                           "cum_max": primi_parameters_ignoreCategoricalAcoustic
                                          },
                        features_only = True,
                        n_jobs=-1)


# feature_defs_test = ft.dfs(entityset=es,
#                         target_dataframe_name="log",
#                         groupby_trans_primitives=["Diff","CumSum", "CumMean", "CumMin", "CumMax"],
#                         agg_primitives=[],
#                         trans_primitives=[],
#                         primitive_options={"diff": {"include_groupby_columns": {"log": ["session_id","session_id_skip_1_False","session_id_skip_1_True","session_id_not_skipped_True","session_id_not_skipped_False"]},"ignore_groupby_dataframes": ["tf"]},
#                                         "cum_sum": {"include_groupby_columns": {"log": ["session_id","session_id_skip_1_False","session_id_skip_1_True","session_id_not_skipped_True","session_id_not_skipped_False"]},"ignore_groupby_dataframes": ["tf"]},
#                                         "cum_mean": {"include_groupby_columns": {"log": ["session_id","session_id_skip_1_False","session_id_skip_1_True","session_id_not_skipped_True","session_id_not_skipped_False"]},"ignore_groupby_dataframes": ["tf"]},
#                                         "cum_min": {"include_groupby_columns": {"log": ["session_id","session_id_skip_1_False","session_id_skip_1_True","session_id_not_skipped_True","session_id_not_skipped_False"]},"ignore_groupby_dataframes": ["tf"]},
#                                         "cum_max": {"include_groupby_columns": {"log": ["session_id","session_id_skip_1_False","session_id_skip_1_True","session_id_not_skipped_True","session_id_not_skipped_False"]},"ignore_groupby_dataframes": ["tf"]}},
#                         features_only = True,
#                         n_jobs=-1)

feature_defs_test

# %%
len(feature_defs_test)

# %%
import warnings
def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
#warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# %%
# check this for specifying groupby: https://featuretools.alteryx.com/en/stable/guides/specifying_primitive_options.html
# The 'session_id' was specified as GroupBy option as we care what happend in each session.
# The tf (track inforamtion) dataframe does not contain any order or session information, so it does not be be specified as GroupBy option.

#warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
# warnings.simplefilter("ignore")


start_time = time.time()

feature_matrix, feature_defs = ft.dfs(entityset=es,
                        target_dataframe_name="log",
                        groupby_trans_primitives=["Diff","CumSum", "CumCount", "CumMean", "CumMin", "CumMax"],
                        agg_primitives=[],
                        trans_primitives=[],
                        primitive_options={"diff": {"include_groupby_columns": {"log": ["session_id","session_id_skip_label"]},"ignore_groupby_dataframes": ["tf"]},
                                        "cum_sum": {"include_groupby_columns": {"log": ["session_id","session_id_skip_label"]},"ignore_groupby_dataframes": ["tf"]},
                                        "cum_count": {"include_groupby_columns": {"log": ["session_id","session_id_skip_label"]},"ignore_groupby_dataframes": ["tf"]},
                                        "cum_mean": {"include_groupby_columns": {"log": ["session_id","session_id_skip_label"]},"ignore_groupby_dataframes": ["tf"]},
                                        "cum_min": {"include_groupby_columns": {"log": ["session_id","session_id_skip_label"]},"ignore_groupby_dataframes": ["tf"]},
                                        "cum_max": {"include_groupby_columns": {"log": ["session_id","session_id_skip_label"]},"ignore_groupby_dataframes": ["tf"]}},
                        features_only = False,
                        n_jobs=-1)

print('***It takes ',(time.time() - start_time)/60, ' minutes.***')

# save feature matrix
feature_matrix.to_csv('../data/processed/feature_matrix_noSkip_skip1_TF.csv')

# %%
feature_matrix

# %%
feature_defs

# %%
print(feature_defs[350])
ft.describe_feature(feature_defs[350])

# %%
feature_matrix.ww.schema
# Out:
#                                                    Logical Type  \
# Column
# session_id                                          Categorical
# session_position                                        Integer
# skip_1                                                  Boolean
# skip_2                                                  Boolean
# skip_3                                                  Boolean
# ...                                                         ...
# DIFF(tf.time_signature_5) by session_id_skip_label       Double
# DIFF(tf.us_popularity_estimate) by session_id            Double
# DIFF(tf.us_popularity_estimate) by session_id_s...       Double
# DIFF(tf.valence) by session_id                           Double
# DIFF(tf.valence) by session_id_skip_label                Double
#
#                                                    Semantic Tag(s)
# Column
# session_id                                            ['category']
# session_position                                       ['numeric']
# skip_1                                                          []
# skip_2                                                          []
# skip_3                                                          []
# ...                                                            ...
# DIFF(tf.time_signature_5) by session_id_skip_label     ['numeric']
# DIFF(tf.us_popularity_estimate) by session_id          ['numeric']
# DIFF(tf.us_popularity_estimate) by session_id_s...     ['numeric']
# DIFF(tf.valence) by session_id                         ['numeric']
# DIFF(tf.valence) by session_id_skip_label              ['numeric']
#
# [773 rows x 2 columns]

# %% [markdown]
# # Check the results of Featuretools

# %%
# load the feature matrix to check whether it was properly saved.

feature_matrix2 = pd.read_csv('../data/processed/feature_matrix_skipLabel_distance.csv')
feature_matrix2.sort_values(by = ['session_id','session_position'],inplace=True)
feature_matrix2.head().T
# Out:
#                                                                                      0      \
# event_id                                                                                 0
# session_id                                          0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                         1
# skip_1                                                                               False
# skip_2                                                                               False
# ...                                                                                    ...
# DIFF(tf.time_signature_5) by session_id_skip_label                                     NaN
# DIFF(tf.us_popularity_estimate) by session_id                                          NaN
# DIFF(tf.us_popularity_estimate) by session_id_s...                                     NaN
# DIFF(tf.valence) by session_id                                                         NaN
# DIFF(tf.valence) by session_id_skip_label                                              NaN
#
#                                                                                      10000  \
# event_id                                                                                 1
# session_id                                          0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                         2
# skip_1                                                                               False
# skip_2                                                                               False
# ...                                                                                    ...
# DIFF(tf.time_signature_5) by session_id_skip_label                                     0.0
# DIFF(tf.us_popularity_estimate) by session_id                                    -0.071405
# DIFF(tf.us_popularity_estimate) by session_id_s...                               -0.071405
# DIFF(tf.valence) by session_id                                                    0.184898
# DIFF(tf.valence) by session_id_skip_label                                         0.184898
#
#                                                                                      20000  \
# event_id                                                                                 2
# session_id                                          0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                         3
# skip_1                                                                               False
# skip_2                                                                               False
# ...                                                                                    ...
# DIFF(tf.time_signature_5) by session_id_skip_label                                     0.0
# DIFF(tf.us_popularity_estimate) by session_id                                     0.103248
# DIFF(tf.us_popularity_estimate) by session_id_s...                                0.103248
# DIFF(tf.valence) by session_id                                                     0.03671
# DIFF(tf.valence) by session_id_skip_label                                          0.03671
#
#                                                                                      30000  \
# event_id                                                                                 3
# session_id                                          0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                         4
# skip_1                                                                               False
# skip_2                                                                               False
# ...                                                                                    ...
# DIFF(tf.time_signature_5) by session_id_skip_label                                     0.0
# DIFF(tf.us_popularity_estimate) by session_id                                    -0.004938
# DIFF(tf.us_popularity_estimate) by session_id_s...                               -0.004938
# DIFF(tf.valence) by session_id                                                    0.275558
# DIFF(tf.valence) by session_id_skip_label                                         0.275558
#
#                                                                                      40000
# event_id                                                                                 4
# session_id                                          0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                         5
# skip_1                                                                               False
# skip_2                                                                               False
# ...                                                                                    ...
# DIFF(tf.time_signature_5) by session_id_skip_label                                     0.0
# DIFF(tf.us_popularity_estimate) by session_id                                      0.00346
# DIFF(tf.us_popularity_estimate) by session_id_s...                                 0.00346
# DIFF(tf.valence) by session_id                                                    0.003501
# DIFF(tf.valence) by session_id_skip_label                                         0.003501
#
# [774 rows x 5 columns]

# %%
# inspect the data of a session
a = feature_matrix2[feature_matrix2['session_id'] == '0_00006f66-33e5-4de7-a324-2d18e439fc1e']
# inspect whether the featuretools generated features considered the session and the order information. The answer appears yes.
a[['tf.speechiness','CUM_SUM(tf.speechiness) by session_id','session_id','CUM_SUM(tf.speechiness) by session_id_skip_label','session_id_skip_label','session_position']]
# Out:
#         tf.speechiness  CUM_SUM(tf.speechiness) by session_id  \
# 0             0.069717                               0.069717
# 10000         0.061158                               0.130874
# 20000         0.045354                               0.176229
# 30000         0.229936                               0.406164
# 40000         0.240980                               0.647144
# 50000         0.133586                               0.780730
# 60000         0.409848                               1.190578
# 70000         0.103687                               1.294266
# 80000         0.049853                               1.344119
# 90000         0.154609                               1.498729
# 100000        0.027932                               1.526660
# 109181        0.414651                               1.941311
# 117610        0.364139                               2.305451
# 125393        0.256456                               2.561906
# 132629        0.125605                               2.687512
# 139406        0.424763                               3.112275
# 145748        0.067412                               3.179687
# 151751        0.140268                               3.319955
# 157434        0.104258                               3.424213
# 162814        0.419025                               3.843238
#
#                                     session_id  \
# 0       0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 10000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 20000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 30000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 40000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 50000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 60000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 70000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 80000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 90000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 100000  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 109181  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 117610  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 125393  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 132629  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 139406  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 145748  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 151751  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 157434  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 162814  0_00006f66-33e5-4de7-a324-2d18e439fc1e
#
#         CUM_SUM(tf.speechiness) by session_id_skip_label  \
# 0                                               0.069717
# 10000                                           0.130874
# 20000                                           0.176229
# 30000                                           0.406164
# 40000                                           0.647144
# 50000                                           0.133586
# 60000                                           0.409848
# 70000                                           0.513535
# 80000                                           0.049853
# 90000                                           0.668145
# 100000                                          0.696077
# 109181                                          1.110727
# 117610                                          1.474867
# 125393                                          0.903600
# 132629                                          0.175459
# 139406                                          0.600222
# 145748                                          0.667634
# 151751                                          0.807902
# 157434                                          1.579125
# 162814                                          1.998150
#
#                                 session_id_skip_label  session_position
# 0       0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_0                 1
# 10000   0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_0                 2
# 20000   0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_0                 3
# 30000   0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_0                 4
# 40000   0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_0                 5
# 50000   0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_3                 6
# 60000   0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_1                 7
# 70000   0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_1                 8
# 80000   0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_2                 9
# 90000   0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_1                10
# 100000  0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_1                11
# 109181  0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_1                12
# 117610  0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_1                13
# 125393  0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_0                14
# 132629  0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_2                15
# 139406  0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_2                16
# 145748  0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_2                17
# 151751  0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_2                18
# 157434  0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_1                19
# 162814  0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_1                20

# %%
sel_cols = [col for col in feature_matrix2.columns if 'by session_id_skip_label' in col]
sel_cols
# Out:
# ['CUM_COUNT(session_id) by session_id_skip_label',
#  'CUM_COUNT(session_id_skip_label) by session_id_skip_label',
#  'CUM_COUNT(track_id_clean) by session_id_skip_label',
#  'CUM_MAX(context_switch) by session_id_skip_label',
#  'CUM_MAX(context_type_catalog) by session_id_skip_label',
#  'CUM_MAX(context_type_charts) by session_id_skip_label',
#  'CUM_MAX(context_type_editorial_playlist) by session_id_skip_label',
#  'CUM_MAX(context_type_personalized_playlist) by session_id_skip_label',
#  'CUM_MAX(context_type_radio) by session_id_skip_label',
#  'CUM_MAX(context_type_user_collection) by session_id_skip_label',
#  'CUM_MAX(cos_dist_all) by session_id_skip_label',
#  'CUM_MAX(euc_dist_all) by session_id_skip_label',
#  'CUM_MAX(hist_user_behavior_reason_start_appload) by session_id_skip_label',
#  'CUM_MAX(hist_user_behavior_reason_start_backbtn) by session_id_skip_label',
#  'CUM_MAX(hist_user_behavior_reason_start_clickrow) by session_id_skip_label',
#  'CUM_MAX(hist_user_behavior_reason_start_endplay) by session_id_skip_label',
#  'CUM_MAX(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_label',
#  'CUM_MAX(hist_user_behavior_reason_start_playbtn) by session_id_skip_label',
#  'CUM_MAX(hist_user_behavior_reason_start_remote) by session_id_skip_label',
#  'CUM_MAX(hist_user_behavior_reason_start_trackdone) by session_id_skip_label',
#  'CUM_MAX(hist_user_behavior_reason_start_trackerror) by session_id_skip_label',
#  'CUM_MAX(hour_of_day) by session_id_skip_label',
#  'CUM_MAX(long_pause_before_play) by session_id_skip_label',
#  'CUM_MAX(man_dist_all) by session_id_skip_label',
#  'CUM_MAX(no_pause_before_play) by session_id_skip_label',
#  'CUM_MAX(session_position) by session_id_skip_label',
#  'CUM_MAX(short_pause_before_play) by session_id_skip_label',
#  'CUM_MEAN(context_switch) by session_id_skip_label',
#  'CUM_MEAN(context_type_catalog) by session_id_skip_label',
#  'CUM_MEAN(context_type_charts) by session_id_skip_label',
#  'CUM_MEAN(context_type_editorial_playlist) by session_id_skip_label',
#  'CUM_MEAN(context_type_personalized_playlist) by session_id_skip_label',
#  'CUM_MEAN(context_type_radio) by session_id_skip_label',
#  'CUM_MEAN(context_type_user_collection) by session_id_skip_label',
#  'CUM_MEAN(cos_dist_all) by session_id_skip_label',
#  'CUM_MEAN(euc_dist_all) by session_id_skip_label',
#  'CUM_MEAN(hist_user_behavior_reason_start_appload) by session_id_skip_label',
#  'CUM_MEAN(hist_user_behavior_reason_start_backbtn) by session_id_skip_label',
#  'CUM_MEAN(hist_user_behavior_reason_start_clickrow) by session_id_skip_label',
#  'CUM_MEAN(hist_user_behavior_reason_start_endplay) by session_id_skip_label',
#  'CUM_MEAN(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_label',
#  'CUM_MEAN(hist_user_behavior_reason_start_playbtn) by session_id_skip_label',
#  'CUM_MEAN(hist_user_behavior_reason_start_remote) by session_id_skip_label',
#  'CUM_MEAN(hist_user_behavior_reason_start_trackdone) by session_id_skip_label',
#  'CUM_MEAN(hist_user_behavior_reason_start_trackerror) by session_id_skip_label',
#  'CUM_MEAN(hour_of_day) by session_id_skip_label',
#  'CUM_MEAN(long_pause_before_play) by session_id_skip_label',
#  'CUM_MEAN(man_dist_all) by session_id_skip_label',
#  'CUM_MEAN(no_pause_before_play) by session_id_skip_label',
#  'CUM_MEAN(session_position) by session_id_skip_label',
#  'CUM_MEAN(short_pause_before_play) by session_id_skip_label',
#  'CUM_MIN(context_switch) by session_id_skip_label',
#  'CUM_MIN(context_type_catalog) by session_id_skip_label',
#  'CUM_MIN(context_type_charts) by session_id_skip_label',
#  'CUM_MIN(context_type_editorial_playlist) by session_id_skip_label',
#  'CUM_MIN(context_type_personalized_playlist) by session_id_skip_label',
#  'CUM_MIN(context_type_radio) by session_id_skip_label',
#  'CUM_MIN(context_type_user_collection) by session_id_skip_label',
#  'CUM_MIN(cos_dist_all) by session_id_skip_label',
#  'CUM_MIN(euc_dist_all) by session_id_skip_label',
#  'CUM_MIN(hist_user_behavior_reason_start_appload) by session_id_skip_label',
#  'CUM_MIN(hist_user_behavior_reason_start_backbtn) by session_id_skip_label',
#  'CUM_MIN(hist_user_behavior_reason_start_clickrow) by session_id_skip_label',
#  'CUM_MIN(hist_user_behavior_reason_start_endplay) by session_id_skip_label',
#  'CUM_MIN(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_label',
#  'CUM_MIN(hist_user_behavior_reason_start_playbtn) by session_id_skip_label',
#  'CUM_MIN(hist_user_behavior_reason_start_remote) by session_id_skip_label',
#  'CUM_MIN(hist_user_behavior_reason_start_trackdone) by session_id_skip_label',
#  'CUM_MIN(hist_user_behavior_reason_start_trackerror) by session_id_skip_label',
#  'CUM_MIN(hour_of_day) by session_id_skip_label',
#  'CUM_MIN(long_pause_before_play) by session_id_skip_label',
#  'CUM_MIN(man_dist_all) by session_id_skip_label',
#  'CUM_MIN(no_pause_before_play) by session_id_skip_label',
#  'CUM_MIN(session_position) by session_id_skip_label',
#  'CUM_MIN(short_pause_before_play) by session_id_skip_label',
#  'CUM_SUM(context_switch) by session_id_skip_label',
#  'CUM_SUM(context_type_catalog) by session_id_skip_label',
#  'CUM_SUM(context_type_charts) by session_id_skip_label',
#  'CUM_SUM(context_type_editorial_playlist) by session_id_skip_label',
#  'CUM_SUM(context_type_personalized_playlist) by session_id_skip_label',
#  'CUM_SUM(context_type_radio) by session_id_skip_label',
#  'CUM_SUM(context_type_user_collection) by session_id_skip_label',
#  'CUM_SUM(cos_dist_all) by session_id_skip_label',
#  'CUM_SUM(euc_dist_all) by session_id_skip_label',
#  'CUM_SUM(hist_user_behavior_reason_start_appload) by session_id_skip_label',
#  'CUM_SUM(hist_user_behavior_reason_start_backbtn) by session_id_skip_label',
#  'CUM_SUM(hist_user_behavior_reason_start_clickrow) by session_id_skip_label',
#  'CUM_SUM(hist_user_behavior_reason_start_endplay) by session_id_skip_label',
#  'CUM_SUM(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_label',
#  'CUM_SUM(hist_user_behavior_reason_start_playbtn) by session_id_skip_label',
#  'CUM_SUM(hist_user_behavior_reason_start_remote) by session_id_skip_label',
#  'CUM_SUM(hist_user_behavior_reason_start_trackdone) by session_id_skip_label',
#  'CUM_SUM(hist_user_behavior_reason_start_trackerror) by session_id_skip_label',
#  'CUM_SUM(hour_of_day) by session_id_skip_label',
#  'CUM_SUM(long_pause_before_play) by session_id_skip_label',
#  'CUM_SUM(man_dist_all) by session_id_skip_label',
#  'CUM_SUM(no_pause_before_play) by session_id_skip_label',
#  'CUM_SUM(session_position) by session_id_skip_label',
#  'CUM_SUM(short_pause_before_play) by session_id_skip_label',
#  'DIFF(context_switch) by session_id_skip_label',
#  'DIFF(context_type_catalog) by session_id_skip_label',
#  'DIFF(context_type_charts) by session_id_skip_label',
#  'DIFF(context_type_editorial_playlist) by session_id_skip_label',
#  'DIFF(context_type_personalized_playlist) by session_id_skip_label',
#  'DIFF(context_type_radio) by session_id_skip_label',
#  'DIFF(context_type_user_collection) by session_id_skip_label',
#  'DIFF(cos_dist_all) by session_id_skip_label',
#  'DIFF(euc_dist_all) by session_id_skip_label',
#  'DIFF(hist_user_behavior_reason_start_appload) by session_id_skip_label',
#  'DIFF(hist_user_behavior_reason_start_backbtn) by session_id_skip_label',
#  'DIFF(hist_user_behavior_reason_start_clickrow) by session_id_skip_label',
#  'DIFF(hist_user_behavior_reason_start_endplay) by session_id_skip_label',
#  'DIFF(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_label',
#  'DIFF(hist_user_behavior_reason_start_playbtn) by session_id_skip_label',
#  'DIFF(hist_user_behavior_reason_start_remote) by session_id_skip_label',
#  'DIFF(hist_user_behavior_reason_start_trackdone) by session_id_skip_label',
#  'DIFF(hist_user_behavior_reason_start_trackerror) by session_id_skip_label',
#  'DIFF(hour_of_day) by session_id_skip_label',
#  'DIFF(long_pause_before_play) by session_id_skip_label',
#  'DIFF(man_dist_all) by session_id_skip_label',
#  'DIFF(no_pause_before_play) by session_id_skip_label',
#  'DIFF(session_position) by session_id_skip_label',
#  'DIFF(short_pause_before_play) by session_id_skip_label',
#  'CUM_MAX(tf.acoustic_vector_0) by session_id_skip_label',
#  'CUM_MAX(tf.acoustic_vector_1) by session_id_skip_label',
#  'CUM_MAX(tf.acoustic_vector_2) by session_id_skip_label',
#  'CUM_MAX(tf.acoustic_vector_3) by session_id_skip_label',
#  'CUM_MAX(tf.acoustic_vector_4) by session_id_skip_label',
#  'CUM_MAX(tf.acoustic_vector_5) by session_id_skip_label',
#  'CUM_MAX(tf.acoustic_vector_6) by session_id_skip_label',
#  'CUM_MAX(tf.acoustic_vector_7) by session_id_skip_label',
#  'CUM_MAX(tf.acousticness) by session_id_skip_label',
#  'CUM_MAX(tf.beat_strength) by session_id_skip_label',
#  'CUM_MAX(tf.bounciness) by session_id_skip_label',
#  'CUM_MAX(tf.danceability) by session_id_skip_label',
#  'CUM_MAX(tf.duration) by session_id_skip_label',
#  'CUM_MAX(tf.dyn_range_mean) by session_id_skip_label',
#  'CUM_MAX(tf.energy) by session_id_skip_label',
#  'CUM_MAX(tf.flatness) by session_id_skip_label',
#  'CUM_MAX(tf.instrumentalness) by session_id_skip_label',
#  'CUM_MAX(tf.key_0) by session_id_skip_label',
#  'CUM_MAX(tf.key_1) by session_id_skip_label',
#  'CUM_MAX(tf.key_10) by session_id_skip_label',
#  'CUM_MAX(tf.key_11) by session_id_skip_label',
#  'CUM_MAX(tf.key_2) by session_id_skip_label',
#  'CUM_MAX(tf.key_3) by session_id_skip_label',
#  'CUM_MAX(tf.key_4) by session_id_skip_label',
#  'CUM_MAX(tf.key_5) by session_id_skip_label',
#  'CUM_MAX(tf.key_6) by session_id_skip_label',
#  'CUM_MAX(tf.key_7) by session_id_skip_label',
#  'CUM_MAX(tf.key_8) by session_id_skip_label',
#  'CUM_MAX(tf.key_9) by session_id_skip_label',
#  'CUM_MAX(tf.liveness) by session_id_skip_label',
#  'CUM_MAX(tf.loudness) by session_id_skip_label',
#  'CUM_MAX(tf.mechanism) by session_id_skip_label',
#  'CUM_MAX(tf.mode_major) by session_id_skip_label',
#  'CUM_MAX(tf.mode_minor) by session_id_skip_label',
#  'CUM_MAX(tf.organism) by session_id_skip_label',
#  'CUM_MAX(tf.release_year) by session_id_skip_label',
#  'CUM_MAX(tf.speechiness) by session_id_skip_label',
#  'CUM_MAX(tf.tempo) by session_id_skip_label',
#  'CUM_MAX(tf.time_signature_0) by session_id_skip_label',
#  'CUM_MAX(tf.time_signature_1) by session_id_skip_label',
#  'CUM_MAX(tf.time_signature_3) by session_id_skip_label',
#  'CUM_MAX(tf.time_signature_4) by session_id_skip_label',
#  'CUM_MAX(tf.time_signature_5) by session_id_skip_label',
#  'CUM_MAX(tf.us_popularity_estimate) by session_id_skip_label',
#  'CUM_MAX(tf.valence) by session_id_skip_label',
#  'CUM_MEAN(tf.acoustic_vector_0) by session_id_skip_label',
#  'CUM_MEAN(tf.acoustic_vector_1) by session_id_skip_label',
#  'CUM_MEAN(tf.acoustic_vector_2) by session_id_skip_label',
#  'CUM_MEAN(tf.acoustic_vector_3) by session_id_skip_label',
#  'CUM_MEAN(tf.acoustic_vector_4) by session_id_skip_label',
#  'CUM_MEAN(tf.acoustic_vector_5) by session_id_skip_label',
#  'CUM_MEAN(tf.acoustic_vector_6) by session_id_skip_label',
#  'CUM_MEAN(tf.acoustic_vector_7) by session_id_skip_label',
#  'CUM_MEAN(tf.acousticness) by session_id_skip_label',
#  'CUM_MEAN(tf.beat_strength) by session_id_skip_label',
#  'CUM_MEAN(tf.bounciness) by session_id_skip_label',
#  'CUM_MEAN(tf.danceability) by session_id_skip_label',
#  'CUM_MEAN(tf.duration) by session_id_skip_label',
#  'CUM_MEAN(tf.dyn_range_mean) by session_id_skip_label',
#  'CUM_MEAN(tf.energy) by session_id_skip_label',
#  'CUM_MEAN(tf.flatness) by session_id_skip_label',
#  'CUM_MEAN(tf.instrumentalness) by session_id_skip_label',
#  'CUM_MEAN(tf.key_0) by session_id_skip_label',
#  'CUM_MEAN(tf.key_1) by session_id_skip_label',
#  'CUM_MEAN(tf.key_10) by session_id_skip_label',
#  'CUM_MEAN(tf.key_11) by session_id_skip_label',
#  'CUM_MEAN(tf.key_2) by session_id_skip_label',
#  'CUM_MEAN(tf.key_3) by session_id_skip_label',
#  'CUM_MEAN(tf.key_4) by session_id_skip_label',
#  'CUM_MEAN(tf.key_5) by session_id_skip_label',
#  'CUM_MEAN(tf.key_6) by session_id_skip_label',
#  'CUM_MEAN(tf.key_7) by session_id_skip_label',
#  'CUM_MEAN(tf.key_8) by session_id_skip_label',
#  'CUM_MEAN(tf.key_9) by session_id_skip_label',
#  'CUM_MEAN(tf.liveness) by session_id_skip_label',
#  'CUM_MEAN(tf.loudness) by session_id_skip_label',
#  'CUM_MEAN(tf.mechanism) by session_id_skip_label',
#  'CUM_MEAN(tf.mode_major) by session_id_skip_label',
#  'CUM_MEAN(tf.mode_minor) by session_id_skip_label',
#  'CUM_MEAN(tf.organism) by session_id_skip_label',
#  'CUM_MEAN(tf.release_year) by session_id_skip_label',
#  'CUM_MEAN(tf.speechiness) by session_id_skip_label',
#  'CUM_MEAN(tf.tempo) by session_id_skip_label',
#  'CUM_MEAN(tf.time_signature_0) by session_id_skip_label',
#  'CUM_MEAN(tf.time_signature_1) by session_id_skip_label',
#  'CUM_MEAN(tf.time_signature_3) by session_id_skip_label',
#  'CUM_MEAN(tf.time_signature_4) by session_id_skip_label',
#  'CUM_MEAN(tf.time_signature_5) by session_id_skip_label',
#  'CUM_MEAN(tf.us_popularity_estimate) by session_id_skip_label',
#  'CUM_MEAN(tf.valence) by session_id_skip_label',
#  'CUM_MIN(tf.acoustic_vector_0) by session_id_skip_label',
#  'CUM_MIN(tf.acoustic_vector_1) by session_id_skip_label',
#  'CUM_MIN(tf.acoustic_vector_2) by session_id_skip_label',
#  'CUM_MIN(tf.acoustic_vector_3) by session_id_skip_label',
#  'CUM_MIN(tf.acoustic_vector_4) by session_id_skip_label',
#  'CUM_MIN(tf.acoustic_vector_5) by session_id_skip_label',
#  'CUM_MIN(tf.acoustic_vector_6) by session_id_skip_label',
#  'CUM_MIN(tf.acoustic_vector_7) by session_id_skip_label',
#  'CUM_MIN(tf.acousticness) by session_id_skip_label',
#  'CUM_MIN(tf.beat_strength) by session_id_skip_label',
#  'CUM_MIN(tf.bounciness) by session_id_skip_label',
#  'CUM_MIN(tf.danceability) by session_id_skip_label',
#  'CUM_MIN(tf.duration) by session_id_skip_label',
#  'CUM_MIN(tf.dyn_range_mean) by session_id_skip_label',
#  'CUM_MIN(tf.energy) by session_id_skip_label',
#  'CUM_MIN(tf.flatness) by session_id_skip_label',
#  'CUM_MIN(tf.instrumentalness) by session_id_skip_label',
#  'CUM_MIN(tf.key_0) by session_id_skip_label',
#  'CUM_MIN(tf.key_1) by session_id_skip_label',
#  'CUM_MIN(tf.key_10) by session_id_skip_label',
#  'CUM_MIN(tf.key_11) by session_id_skip_label',
#  'CUM_MIN(tf.key_2) by session_id_skip_label',
#  'CUM_MIN(tf.key_3) by session_id_skip_label',
#  'CUM_MIN(tf.key_4) by session_id_skip_label',
#  'CUM_MIN(tf.key_5) by session_id_skip_label',
#  'CUM_MIN(tf.key_6) by session_id_skip_label',
#  'CUM_MIN(tf.key_7) by session_id_skip_label',
#  'CUM_MIN(tf.key_8) by session_id_skip_label',
#  'CUM_MIN(tf.key_9) by session_id_skip_label',
#  'CUM_MIN(tf.liveness) by session_id_skip_label',
#  'CUM_MIN(tf.loudness) by session_id_skip_label',
#  'CUM_MIN(tf.mechanism) by session_id_skip_label',
#  'CUM_MIN(tf.mode_major) by session_id_skip_label',
#  'CUM_MIN(tf.mode_minor) by session_id_skip_label',
#  'CUM_MIN(tf.organism) by session_id_skip_label',
#  'CUM_MIN(tf.release_year) by session_id_skip_label',
#  'CUM_MIN(tf.speechiness) by session_id_skip_label',
#  'CUM_MIN(tf.tempo) by session_id_skip_label',
#  'CUM_MIN(tf.time_signature_0) by session_id_skip_label',
#  'CUM_MIN(tf.time_signature_1) by session_id_skip_label',
#  'CUM_MIN(tf.time_signature_3) by session_id_skip_label',
#  'CUM_MIN(tf.time_signature_4) by session_id_skip_label',
#  'CUM_MIN(tf.time_signature_5) by session_id_skip_label',
#  'CUM_MIN(tf.us_popularity_estimate) by session_id_skip_label',
#  'CUM_MIN(tf.valence) by session_id_skip_label',
#  'CUM_SUM(tf.acoustic_vector_0) by session_id_skip_label',
#  'CUM_SUM(tf.acoustic_vector_1) by session_id_skip_label',
#  'CUM_SUM(tf.acoustic_vector_2) by session_id_skip_label',
#  'CUM_SUM(tf.acoustic_vector_3) by session_id_skip_label',
#  'CUM_SUM(tf.acoustic_vector_4) by session_id_skip_label',
#  'CUM_SUM(tf.acoustic_vector_5) by session_id_skip_label',
#  'CUM_SUM(tf.acoustic_vector_6) by session_id_skip_label',
#  'CUM_SUM(tf.acoustic_vector_7) by session_id_skip_label',
#  'CUM_SUM(tf.acousticness) by session_id_skip_label',
#  'CUM_SUM(tf.beat_strength) by session_id_skip_label',
#  'CUM_SUM(tf.bounciness) by session_id_skip_label',
#  'CUM_SUM(tf.danceability) by session_id_skip_label',
#  'CUM_SUM(tf.duration) by session_id_skip_label',
#  'CUM_SUM(tf.dyn_range_mean) by session_id_skip_label',
#  'CUM_SUM(tf.energy) by session_id_skip_label',
#  'CUM_SUM(tf.flatness) by session_id_skip_label',
#  'CUM_SUM(tf.instrumentalness) by session_id_skip_label',
#  'CUM_SUM(tf.key_0) by session_id_skip_label',
#  'CUM_SUM(tf.key_1) by session_id_skip_label',
#  'CUM_SUM(tf.key_10) by session_id_skip_label',
#  'CUM_SUM(tf.key_11) by session_id_skip_label',
#  'CUM_SUM(tf.key_2) by session_id_skip_label',
#  'CUM_SUM(tf.key_3) by session_id_skip_label',
#  'CUM_SUM(tf.key_4) by session_id_skip_label',
#  'CUM_SUM(tf.key_5) by session_id_skip_label',
#  'CUM_SUM(tf.key_6) by session_id_skip_label',
#  'CUM_SUM(tf.key_7) by session_id_skip_label',
#  'CUM_SUM(tf.key_8) by session_id_skip_label',
#  'CUM_SUM(tf.key_9) by session_id_skip_label',
#  'CUM_SUM(tf.liveness) by session_id_skip_label',
#  'CUM_SUM(tf.loudness) by session_id_skip_label',
#  'CUM_SUM(tf.mechanism) by session_id_skip_label',
#  'CUM_SUM(tf.mode_major) by session_id_skip_label',
#  'CUM_SUM(tf.mode_minor) by session_id_skip_label',
#  'CUM_SUM(tf.organism) by session_id_skip_label',
#  'CUM_SUM(tf.release_year) by session_id_skip_label',
#  'CUM_SUM(tf.speechiness) by session_id_skip_label',
#  'CUM_SUM(tf.tempo) by session_id_skip_label',
#  'CUM_SUM(tf.time_signature_0) by session_id_skip_label',
#  'CUM_SUM(tf.time_signature_1) by session_id_skip_label',
#  'CUM_SUM(tf.time_signature_3) by session_id_skip_label',
#  'CUM_SUM(tf.time_signature_4) by session_id_skip_label',
#  'CUM_SUM(tf.time_signature_5) by session_id_skip_label',
#  'CUM_SUM(tf.us_popularity_estimate) by session_id_skip_label',
#  'CUM_SUM(tf.valence) by session_id_skip_label',
#  'DIFF(tf.acoustic_vector_0) by session_id_skip_label',
#  'DIFF(tf.acoustic_vector_1) by session_id_skip_label',
#  'DIFF(tf.acoustic_vector_2) by session_id_skip_label',
#  'DIFF(tf.acoustic_vector_3) by session_id_skip_label',
#  'DIFF(tf.acoustic_vector_4) by session_id_skip_label',
#  'DIFF(tf.acoustic_vector_5) by session_id_skip_label',
#  'DIFF(tf.acoustic_vector_6) by session_id_skip_label',
#  'DIFF(tf.acoustic_vector_7) by session_id_skip_label',
#  'DIFF(tf.acousticness) by session_id_skip_label',
#  'DIFF(tf.beat_strength) by session_id_skip_label',
#  'DIFF(tf.bounciness) by session_id_skip_label',
#  'DIFF(tf.danceability) by session_id_skip_label',
#  'DIFF(tf.duration) by session_id_skip_label',
#  'DIFF(tf.dyn_range_mean) by session_id_skip_label',
#  'DIFF(tf.energy) by session_id_skip_label',
#  'DIFF(tf.flatness) by session_id_skip_label',
#  'DIFF(tf.instrumentalness) by session_id_skip_label',
#  'DIFF(tf.key_0) by session_id_skip_label',
#  'DIFF(tf.key_1) by session_id_skip_label',
#  'DIFF(tf.key_10) by session_id_skip_label',
#  'DIFF(tf.key_11) by session_id_skip_label',
#  'DIFF(tf.key_2) by session_id_skip_label',
#  'DIFF(tf.key_3) by session_id_skip_label',
#  'DIFF(tf.key_4) by session_id_skip_label',
#  'DIFF(tf.key_5) by session_id_skip_label',
#  'DIFF(tf.key_6) by session_id_skip_label',
#  'DIFF(tf.key_7) by session_id_skip_label',
#  'DIFF(tf.key_8) by session_id_skip_label',
#  'DIFF(tf.key_9) by session_id_skip_label',
#  'DIFF(tf.liveness) by session_id_skip_label',
#  'DIFF(tf.loudness) by session_id_skip_label',
#  'DIFF(tf.mechanism) by session_id_skip_label',
#  'DIFF(tf.mode_major) by session_id_skip_label',
#  'DIFF(tf.mode_minor) by session_id_skip_label',
#  'DIFF(tf.organism) by session_id_skip_label',
#  'DIFF(tf.release_year) by session_id_skip_label',
#  'DIFF(tf.speechiness) by session_id_skip_label',
#  'DIFF(tf.tempo) by session_id_skip_label',
#  'DIFF(tf.time_signature_0) by session_id_skip_label',
#  'DIFF(tf.time_signature_1) by session_id_skip_label',
#  'DIFF(tf.time_signature_3) by session_id_skip_label',
#  'DIFF(tf.time_signature_4) by session_id_skip_label',
#  'DIFF(tf.time_signature_5) by session_id_skip_label',
#  'DIFF(tf.us_popularity_estimate) by session_id_skip_label',
#  'DIFF(tf.valence) by session_id_skip_label']

# %%
feature_matrix2['session_id_skip_label'].isna().sum()
# Out:
# 0

# %%
start_time = time.time()
for s_id in pd.unique(feature_matrix2['session_id']):
    temp = []
    temp = feature_matrix2[feature_matrix2['session_id']==s_id]
    # shift the rows down by 1 within each session because it reflects the history (no_skip) up to the previous row
    # without shifting, the information of no_skip will leak into the features!!
    temp[sel_cols] = temp[sel_cols].shift(periods=1, axis=0, fill_value=0) 
    #temp.fillna(method = 'ffill', axis = 0, inplace=True)
    feature_matrix2[feature_matrix2['session_id']==s_id] = temp

print('***It takes ',(time.time() - start_time)/60, ' mins.***')
# Out:
# ***It takes  26.485645016034443  mins.***

# %%
# check the data again after shifting the rows
b = feature_matrix2[feature_matrix2['session_id'] == '0_00006f66-33e5-4de7-a324-2d18e439fc1e']
# inspect whether the featuretools generated features considered the session and the order information. The answer appears yes.
b[['tf.speechiness','CUM_SUM(tf.speechiness) by session_id','session_id','CUM_SUM(tf.speechiness) by session_id_skip_label','session_id_skip_label','session_position']]
# Out:
#         tf.speechiness  CUM_SUM(tf.speechiness) by session_id  \
# 0             0.069717                               0.069717
# 10000         0.061158                               0.130874
# 20000         0.045354                               0.176229
# 30000         0.229936                               0.406164
# 40000         0.240980                               0.647144
# 50000         0.133586                               0.780730
# 60000         0.409848                               1.190578
# 70000         0.103687                               1.294266
# 80000         0.049853                               1.344119
# 90000         0.154609                               1.498729
# 100000        0.027932                               1.526660
# 109181        0.414651                               1.941311
# 117610        0.364139                               2.305451
# 125393        0.256456                               2.561906
# 132629        0.125605                               2.687512
# 139406        0.424763                               3.112275
# 145748        0.067412                               3.179687
# 151751        0.140268                               3.319955
# 157434        0.104258                               3.424213
# 162814        0.419025                               3.843238
#
#                                     session_id  \
# 0       0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 10000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 20000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 30000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 40000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 50000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 60000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 70000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 80000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 90000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 100000  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 109181  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 117610  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 125393  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 132629  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 139406  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 145748  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 151751  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 157434  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 162814  0_00006f66-33e5-4de7-a324-2d18e439fc1e
#
#         CUM_SUM(tf.speechiness) by session_id_skip_label  \
# 0                                               0.000000
# 10000                                           0.069717
# 20000                                           0.130874
# 30000                                           0.176229
# 40000                                           0.406164
# 50000                                           0.647144
# 60000                                           0.133586
# 70000                                           0.409848
# 80000                                           0.513535
# 90000                                           0.049853
# 100000                                          0.668145
# 109181                                          0.696077
# 117610                                          1.110727
# 125393                                          1.474867
# 132629                                          0.903600
# 139406                                          0.175459
# 145748                                          0.600222
# 151751                                          0.667634
# 157434                                          0.807902
# 162814                                          1.579125
#
#                                 session_id_skip_label  session_position
# 0       0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_0                 1
# 10000   0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_0                 2
# 20000   0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_0                 3
# 30000   0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_0                 4
# 40000   0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_0                 5
# 50000   0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_3                 6
# 60000   0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_1                 7
# 70000   0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_1                 8
# 80000   0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_2                 9
# 90000   0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_1                10
# 100000  0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_1                11
# 109181  0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_1                12
# 117610  0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_1                13
# 125393  0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_0                14
# 132629  0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_2                15
# 139406  0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_2                16
# 145748  0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_2                17
# 151751  0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_2                18
# 157434  0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_1                19
# 162814  0_00006f66-33e5-4de7-a324-2d18e439fc1e_skip_1                20

# %%
# feature_matrix2.loc[feature_matrix2['session_id_not_skipped'].isna(),sel_cols] = np.nan
# b = feature_matrix2[feature_matrix2['session_id'] == '0_00006f66-33e5-4de7-a324-2d18e439fc1e']
# b[['tf.speechiness','CUM_SUM(tf.speechiness) by session_id','session_id','CUM_SUM(tf.speechiness) by session_id_not_skipped','session_id_not_skipped','session_position']]
# Out:
#         tf.speechiness  CUM_SUM(tf.speechiness) by session_id  \
# 0             0.069717                               0.069717
# 10000         0.061158                               0.130874
# 20000         0.045354                               0.176229
# 30000         0.229936                               0.406164
# 40000         0.240980                               0.647144
# 50000         0.133586                               0.780730
# 60000         0.409848                               1.190578
# 70000         0.103687                               1.294266
# 80000         0.049853                               1.344119
# 90000         0.154609                               1.498729
# 100000        0.027932                               1.526660
# 109181        0.414651                               1.941311
# 117610        0.364139                               2.305451
# 125393        0.256456                               2.561906
# 132629        0.125605                               2.687512
# 139406        0.424763                               3.112275
# 145748        0.067412                               3.179687
# 151751        0.140268                               3.319955
# 157434        0.104258                               3.424213
# 162814        0.419025                               3.843238
#
#                                     session_id  \
# 0       0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 10000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 20000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 30000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 40000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 50000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 60000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 70000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 80000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 90000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 100000  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 109181  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 117610  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 125393  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 132629  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 139406  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 145748  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 151751  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 157434  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 162814  0_00006f66-33e5-4de7-a324-2d18e439fc1e
#
#         CUM_SUM(tf.speechiness) by session_id_not_skipped  \
# 0                                                0.069717
# 10000                                            0.130874
# 20000                                            0.176229
# 30000                                            0.406164
# 40000                                            0.647144
# 50000                                                 NaN
# 60000                                                 NaN
# 70000                                                 NaN
# 80000                                                 NaN
# 90000                                                 NaN
# 100000                                                NaN
# 109181                                                NaN
# 117610                                                NaN
# 125393                                           0.903600
# 132629                                                NaN
# 139406                                                NaN
# 145748                                                NaN
# 151751                                                NaN
# 157434                                                NaN
# 162814                                                NaN
#
#                         session_id_not_skipped  session_position
# 0       0_00006f66-33e5-4de7-a324-2d18e439fc1e                 1
# 10000   0_00006f66-33e5-4de7-a324-2d18e439fc1e                 2
# 20000   0_00006f66-33e5-4de7-a324-2d18e439fc1e                 3
# 30000   0_00006f66-33e5-4de7-a324-2d18e439fc1e                 4
# 40000   0_00006f66-33e5-4de7-a324-2d18e439fc1e                 5
# 50000                                      NaN                 6
# 60000                                      NaN                 7
# 70000                                      NaN                 8
# 80000                                      NaN                 9
# 90000                                      NaN                10
# 100000                                     NaN                11
# 109181                                     NaN                12
# 117610                                     NaN                13
# 125393  0_00006f66-33e5-4de7-a324-2d18e439fc1e                14
# 132629                                     NaN                15
# 139406                                     NaN                16
# 145748                                     NaN                17
# 151751                                     NaN                18
# 157434                                     NaN                19
# 162814                                     NaN                20

# %%
# feature_matrix3 = feature_matrix2.sort_values(by = ['session_id','session_position']).copy()
# start_time = time.time()
# for s_id in pd.unique(feature_matrix2['session_id']):
#     temp = []
#     temp = feature_matrix3[feature_matrix3['session_id']==s_id]
#     # shift the rows down by 1 within each session because it reflects the history (no_skip) up to the previous row
#     # without shifting, the information of no_skip will leak into the features!!
#     temp[sel_cols] = temp[sel_cols].shift(periods=1, axis=0) 
#     temp.fillna(method = 'ffill', axis = 0, inplace=True)
#     feature_matrix3[feature_matrix3['session_id']==s_id] = temp

# print('***It takes ',(time.time() - start_time)/60, ' mins.***')


# c = feature_matrix3[feature_matrix3['session_id'] == '0_00006f66-33e5-4de7-a324-2d18e439fc1e']
# c[['tf.speechiness','CUM_SUM(tf.speechiness) by session_id','session_id','CUM_SUM(tf.speechiness) by session_id_not_skipped','session_id_not_skipped','not_skipped','session_position']]
# Out:
# ***It takes  1416.1911041736603  secs.***
#         tf.speechiness  CUM_SUM(tf.speechiness) by session_id  \
# 0             0.069717                               0.069717
# 10000         0.061158                               0.130874
# 20000         0.045354                               0.176229
# 30000         0.229936                               0.406164
# 40000         0.240980                               0.647144
# 50000         0.133586                               0.780730
# 60000         0.409848                               1.190578
# 70000         0.103687                               1.294266
# 80000         0.049853                               1.344119
# 90000         0.154609                               1.498729
# 100000        0.027932                               1.526660
# 109181        0.414651                               1.941311
# 117610        0.364139                               2.305451
# 125393        0.256456                               2.561906
# 132629        0.125605                               2.687512
# 139406        0.424763                               3.112275
# 145748        0.067412                               3.179687
# 151751        0.140268                               3.319955
# 157434        0.104258                               3.424213
# 162814        0.419025                               3.843238
#
#                                     session_id  \
# 0       0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 10000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 20000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 30000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 40000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 50000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 60000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 70000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 80000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 90000   0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 100000  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 109181  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 117610  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 125393  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 132629  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 139406  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 145748  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 151751  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 157434  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 162814  0_00006f66-33e5-4de7-a324-2d18e439fc1e
#
#         CUM_SUM(tf.speechiness) by session_id_not_skipped  \
# 0                                                     NaN
# 10000                                            0.069717
# 20000                                            0.130874
# 30000                                            0.176229
# 40000                                            0.406164
# 50000                                            0.647144
# 60000                                            0.647144
# 70000                                            0.647144
# 80000                                            0.647144
# 90000                                            0.647144
# 100000                                           0.647144
# 109181                                           0.647144
# 117610                                           0.647144
# 125393                                           0.647144
# 132629                                           0.903600
# 139406                                           0.903600
# 145748                                           0.903600
# 151751                                           0.903600
# 157434                                           0.903600
# 162814                                           0.903600
#
#                         session_id_not_skipped  not_skipped  session_position
# 0       0_00006f66-33e5-4de7-a324-2d18e439fc1e         True                 1
# 10000   0_00006f66-33e5-4de7-a324-2d18e439fc1e         True                 2
# 20000   0_00006f66-33e5-4de7-a324-2d18e439fc1e         True                 3
# 30000   0_00006f66-33e5-4de7-a324-2d18e439fc1e         True                 4
# 40000   0_00006f66-33e5-4de7-a324-2d18e439fc1e         True                 5
# 50000   0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                 6
# 60000   0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                 7
# 70000   0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                 8
# 80000   0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                 9
# 90000   0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                10
# 100000  0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                11
# 109181  0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                12
# 117610  0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                13
# 125393  0_00006f66-33e5-4de7-a324-2d18e439fc1e         True                14
# 132629  0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                15
# 139406  0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                16
# 145748  0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                17
# 151751  0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                18
# 157434  0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                19
# 162814  0_00006f66-33e5-4de7-a324-2d18e439fc1e        False                20

# %%
d = feature_matrix3[feature_matrix3['session_id'] == '0_0000a72b-09ac-412f-b452-9b9e79bded8f']
d[['tf.speechiness','CUM_SUM(tf.speechiness) by session_id','session_id','CUM_SUM(tf.speechiness) by session_id_not_skipped','session_id_not_skipped','not_skipped','session_position']]
# Out:
#         tf.speechiness  CUM_SUM(tf.speechiness) by session_id  \
# 1             0.192012                               0.192012
# 10001         0.068105                               0.260117
# 20001         0.075064                               0.335181
# 30001         0.045026                               0.380207
# 40001         0.124050                               0.504257
# 50001         0.239021                               0.743278
# 60001         0.039155                               0.782433
# 70001         0.041675                               0.824108
# 80001         0.134822                               0.958929
# 90001         0.140254                               1.099183
# 100001        0.134822                               1.234005
# 109182        0.140254                               1.374259
# 117611        0.262717                               1.636976
# 125394        0.061724                               1.698700
# 132630        0.045784                               1.744484
# 139407        0.062405                               1.806889
# 145749        0.045784                               1.852672
# 151752        0.062405                               1.915078
# 157435        0.043028                               1.958106
# 162815        0.048796                               2.006902
#
#                                     session_id  \
# 1       0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 10001   0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 20001   0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 30001   0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 40001   0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 50001   0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 60001   0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 70001   0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 80001   0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 90001   0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 100001  0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 109182  0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 117611  0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 125394  0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 132630  0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 139407  0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 145749  0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 151752  0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 157435  0_0000a72b-09ac-412f-b452-9b9e79bded8f
# 162815  0_0000a72b-09ac-412f-b452-9b9e79bded8f
#
#         CUM_SUM(tf.speechiness) by session_id_not_skipped  \
# 1                                                     NaN
# 10001                                                 NaN
# 20001                                                 NaN
# 30001                                                 NaN
# 40001                                                 NaN
# 50001                                                 NaN
# 60001                                                 NaN
# 70001                                                 NaN
# 80001                                                 NaN
# 90001                                                 NaN
# 100001                                                NaN
# 109182                                           0.134822
# 117611                                           0.275076
# 125394                                           0.275076
# 132630                                           0.336800
# 139407                                           0.336800
# 145749                                           0.336800
# 151752                                           0.382583
# 157435                                           0.382583
# 162815                                           0.425612
#
#                         session_id_not_skipped  not_skipped  session_position
# 1                                          NaN        False                 1
# 10001                                      NaN        False                 2
# 20001                                      NaN        False                 3
# 30001                                      NaN        False                 4
# 40001                                      NaN        False                 5
# 50001                                      NaN        False                 6
# 60001                                      NaN        False                 7
# 70001                                      NaN        False                 8
# 80001                                      NaN        False                 9
# 90001                                      NaN        False                10
# 100001  0_0000a72b-09ac-412f-b452-9b9e79bded8f         True                11
# 109182  0_0000a72b-09ac-412f-b452-9b9e79bded8f         True                12
# 117611  0_0000a72b-09ac-412f-b452-9b9e79bded8f        False                13
# 125394  0_0000a72b-09ac-412f-b452-9b9e79bded8f         True                14
# 132630  0_0000a72b-09ac-412f-b452-9b9e79bded8f        False                15
# 139407  0_0000a72b-09ac-412f-b452-9b9e79bded8f        False                16
# 145749  0_0000a72b-09ac-412f-b452-9b9e79bded8f         True                17
# 151752  0_0000a72b-09ac-412f-b452-9b9e79bded8f        False                18
# 157435  0_0000a72b-09ac-412f-b452-9b9e79bded8f         True                19
# 162815  0_0000a72b-09ac-412f-b452-9b9e79bded8f         True                20

# %%
feature_matrix3.to_csv('../data/processed/feature_matrix_skip_processed.csv')

# %% [markdown]
# # Scale standardization & training/testing data split will be performed at the model fitting stage.
