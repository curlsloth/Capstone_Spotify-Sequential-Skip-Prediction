# %% [markdown]
# # How good a simple model can predict without any feature engineering?
#
# This section aims to establish a baseline of how good a simple model can predict without doing any extensive feature engineering.

# %% [markdown]
# # Data preparation

# %%
import numpy as np
import pandas as pd
import featuretools as ft
import time
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# load the track information (mini version)

tf_df = pd.read_csv('../data/raw/data/track_features/tf_mini.csv')
log_df = pd.read_csv('../data/raw/data/training_set/log_mini.csv')

# %%
# perform some data cleaning/re-coding as described in 2_mini_EDA

tf_df_dummy = pd.get_dummies(tf_df, columns=['key','time_signature','mode'])
log_df_dummy = pd.get_dummies(log_df.drop(columns = ['session_length',  'hist_user_behavior_reason_end', 'hist_user_behavior_n_seekfwd','hist_user_behavior_n_seekback']), columns=['hist_user_behavior_reason_start', 'context_type'])

# %%
# perform a simple dataframe join
df = log_df_dummy.merge(tf_df_dummy, left_on = 'track_id_clean', right_on = 'track_id')
df.sort_values(by = ['session_id', 'session_position'],inplace = True)
df.head().T
# Out:
#                                                      0    \
# session_id        0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                       1
# track_id_clean    t_0479f24c-27d2-46d6-a00c-7ec928f2b539
# skip_1                                             False
# skip_2                                             False
# ...                                                  ...
# time_signature_3                                       0
# time_signature_4                                       1
# time_signature_5                                       0
# mode_major                                             1
# mode_minor                                             0
#
#                                                      45   \
# session_id        0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                       2
# track_id_clean    t_9099cd7b-c238-47b7-9381-f23f2c1d1043
# skip_1                                             False
# skip_2                                             False
# ...                                                  ...
# time_signature_3                                       0
# time_signature_4                                       1
# time_signature_5                                       0
# mode_major                                             0
# mode_minor                                             1
#
#                                                      50   \
# session_id        0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                       3
# track_id_clean    t_fc5df5ba-5396-49a7-8b29-35d0d28249e0
# skip_1                                             False
# skip_2                                             False
# ...                                                  ...
# time_signature_3                                       0
# time_signature_4                                       1
# time_signature_5                                       0
# mode_major                                             1
# mode_minor                                             0
#
#                                                      327  \
# session_id        0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                       4
# track_id_clean    t_23cff8d6-d874-4b20-83dc-94e450e8aa20
# skip_1                                             False
# skip_2                                             False
# ...                                                  ...
# time_signature_3                                       0
# time_signature_4                                       1
# time_signature_5                                       0
# mode_major                                             1
# mode_minor                                             0
#
#                                                      353
# session_id        0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                       5
# track_id_clean    t_64f3743c-f624-46bb-a579-0f3f9a07a123
# skip_1                                             False
# skip_2                                             False
# ...                                                  ...
# time_signature_3                                       0
# time_signature_4                                       1
# time_signature_5                                       0
# mode_major                                             1
# mode_minor                                             0
#
# [76 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['session_id', 'session_position', 'track_id_clean', 'skip_1', 'skip_2',
#        'skip_3', 'not_skipped', 'context_switch', 'no_pause_before_play',
#        'short_pause_before_play', 'long_pause_before_play',
#        'hist_user_behavior_is_shuffle', 'hour_of_day', 'date', 'premium',
#        'hist_user_behavior_reason_start_appload',
#        'hist_user_behavior_reason_start_backbtn',
#        'hist_user_behavior_reason_start_clickrow',
#        'hist_user_behavior_reason_start_endplay',
#        'hist_user_behavior_reason_start_fwdbtn',
#        'hist_user_behavior_reason_start_playbtn',
#        'hist_user_behavior_reason_start_remote',
#        'hist_user_behavior_reason_start_trackdone',
#        'hist_user_behavior_reason_start_trackerror', 'context_type_catalog',
#        'context_type_charts', 'context_type_editorial_playlist',
#        'context_type_personalized_playlist', 'context_type_radio',
#        'context_type_user_collection', 'track_id', 'duration', 'release_year',
#        'us_popularity_estimate', 'acousticness', 'beat_strength', 'bounciness',
#        'danceability', 'dyn_range_mean', 'energy', 'flatness',
#        'instrumentalness', 'liveness', 'loudness', 'mechanism', 'organism',
#        'speechiness', 'tempo', 'valence', 'acoustic_vector_0',
#        'acoustic_vector_1', 'acoustic_vector_2', 'acoustic_vector_3',
#        'acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6',
#        'acoustic_vector_7', 'key_0', 'key_1', 'key_2', 'key_3', 'key_4',
#        'key_5', 'key_6', 'key_7', 'key_8', 'key_9', 'key_10', 'key_11',
#        'time_signature_0', 'time_signature_1', 'time_signature_3',
#        'time_signature_4', 'time_signature_5', 'mode_major', 'mode_minor'],
#       dtype='object')

# %%
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 167880 entries, 0 to 134498
# Data columns (total 76 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   session_id                                  167880 non-null  object
#  1   session_position                            167880 non-null  int64
#  2   track_id_clean                              167880 non-null  object
#  3   skip_1                                      167880 non-null  bool
#  4   skip_2                                      167880 non-null  bool
#  5   skip_3                                      167880 non-null  bool
#  6   not_skipped                                 167880 non-null  bool
#  7   context_switch                              167880 non-null  int64
#  8   no_pause_before_play                        167880 non-null  int64
#  9   short_pause_before_play                     167880 non-null  int64
#  10  long_pause_before_play                      167880 non-null  int64
#  11  hist_user_behavior_is_shuffle               167880 non-null  bool
#  12  hour_of_day                                 167880 non-null  int64
#  13  date                                        167880 non-null  datetime64[ns]
#  14  premium                                     167880 non-null  bool
#  15  hist_user_behavior_reason_start_appload     167880 non-null  uint8
#  16  hist_user_behavior_reason_start_backbtn     167880 non-null  uint8
#  17  hist_user_behavior_reason_start_clickrow    167880 non-null  uint8
#  18  hist_user_behavior_reason_start_endplay     167880 non-null  uint8
#  19  hist_user_behavior_reason_start_fwdbtn      167880 non-null  uint8
#  20  hist_user_behavior_reason_start_playbtn     167880 non-null  uint8
#  21  hist_user_behavior_reason_start_remote      167880 non-null  uint8
#  22  hist_user_behavior_reason_start_trackdone   167880 non-null  uint8
#  23  hist_user_behavior_reason_start_trackerror  167880 non-null  uint8
#  24  context_type_catalog                        167880 non-null  uint8
#  25  context_type_charts                         167880 non-null  uint8
#  26  context_type_editorial_playlist             167880 non-null  uint8
#  27  context_type_personalized_playlist          167880 non-null  uint8
#  28  context_type_radio                          167880 non-null  uint8
#  29  context_type_user_collection                167880 non-null  uint8
#  30  track_id                                    167880 non-null  object
#  31  duration                                    167880 non-null  float64
#  32  release_year                                167880 non-null  int64
#  33  us_popularity_estimate                      167880 non-null  float64
#  34  acousticness                                167880 non-null  float64
#  35  beat_strength                               167880 non-null  float64
#  36  bounciness                                  167880 non-null  float64
#  37  danceability                                167880 non-null  float64
#  38  dyn_range_mean                              167880 non-null  float64
#  39  energy                                      167880 non-null  float64
#  40  flatness                                    167880 non-null  float64
#  41  instrumentalness                            167880 non-null  float64
#  42  liveness                                    167880 non-null  float64
#  43  loudness                                    167880 non-null  float64
#  44  mechanism                                   167880 non-null  float64
#  45  organism                                    167880 non-null  float64
#  46  speechiness                                 167880 non-null  float64
#  47  tempo                                       167880 non-null  float64
#  48  valence                                     167880 non-null  float64
#  49  acoustic_vector_0                           167880 non-null  float64
#  50  acoustic_vector_1                           167880 non-null  float64
#  51  acoustic_vector_2                           167880 non-null  float64
#  52  acoustic_vector_3                           167880 non-null  float64
#  53  acoustic_vector_4                           167880 non-null  float64
#  54  acoustic_vector_5                           167880 non-null  float64
#  55  acoustic_vector_6                           167880 non-null  float64
#  56  acoustic_vector_7                           167880 non-null  float64
#  57  key_0                                       167880 non-null  uint8
#  58  key_1                                       167880 non-null  uint8
#  59  key_2                                       167880 non-null  uint8
#  60  key_3                                       167880 non-null  uint8
#  61  key_4                                       167880 non-null  uint8
#  62  key_5                                       167880 non-null  uint8
#  63  key_6                                       167880 non-null  uint8
#  64  key_7                                       167880 non-null  uint8
#  65  key_8                                       167880 non-null  uint8
#  66  key_9                                       167880 non-null  uint8
#  67  key_10                                      167880 non-null  uint8
#  68  key_11                                      167880 non-null  uint8
#  69  time_signature_0                            167880 non-null  uint8
#  70  time_signature_1                            167880 non-null  uint8
#  71  time_signature_3                            167880 non-null  uint8
#  72  time_signature_4                            167880 non-null  uint8
#  73  time_signature_5                            167880 non-null  uint8
#  74  mode_major                                  167880 non-null  uint8
#  75  mode_minor                                  167880 non-null  uint8
# dtypes: bool(6), datetime64[ns](1), float64(25), int64(7), object(3), uint8(34)
# memory usage: 53.8+ MB

# %% [markdown]
# # Simple model 1: split the beginning/end of each sequence, random forest classifier, skip_2 (binary)
#
# This model take the first 80% of tracks of each listening sequence as training dataset, and the last 20% of tracks as testing dataset. This approach respects the data's temporal order and test how generalizable the model is.

# %%
import pandas as pd
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import __version__ as sklearn_version
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, learning_curve, StratifiedKFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, confusion_matrix, classification_report
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.svm import SVC
import datetime

#from library.sb_utils import save_file

# %%
s_list = df['session_id'].unique()
print('# of sessions:',len(s_list))
# Out:
# # of sessions: 10000

# %%
# the beginning 'train_perc'% of the tracks of each session were taken as training dataset, 
# and the rest as testing dataset.

train_perc = 0.8

data_train_append = []
data_test_append = []
for s_id in s_list:
    temp = []
    temp = df.loc[df['session_id']==s_id,:]
    data_train_append.append(temp.iloc[0:round(len(temp)*train_perc),:])
    data_test_append.append(temp.iloc[round(len(temp)*train_perc):,:])

data_train = pd.concat(data_train_append)
data_test = pd.concat(data_test_append)

# %%
X_train = data_train.drop(columns=['not_skipped', 'skip_1', 'skip_2', 'skip_3', 'session_id','track_id_clean','track_id','date'])
X_test = data_test.drop(columns=['not_skipped', 'skip_1', 'skip_2', 'skip_3', 'session_id','track_id_clean','track_id','date'])

y_train = data_train['skip_2']
y_test = data_test['skip_2']

# %%
print('skip_2 rate in training dataset: ',y_train.mean())
print('skip_2 rate in testing dataset: ',y_test.mean())
# Out:
# skip_2 rate in training dataset:  0.5274078593003705
# skip_2 rate in testing dataset:  0.4760951413374768

# %%
RF_sSplit = RandomForestClassifier(random_state=23, n_jobs = -1)
RF_sSplit.fit(X_train, y_train)
score_sSplit_train = RF_sSplit.score(X_train,y_train)
score_sSplit_test = RF_sSplit.score(X_test,y_test)
print('score_train',score_sSplit_train)
print('score_test',score_sSplit_test)
# Out:
# score_train 0.9963694258038597
# score_test 0.7497758919500388

# %%
importances = pd.DataFrame({'FEATURE':X_train.columns,'IMPORTANCE':np.round(RF_sSplit.feature_importances_,3)})
importances = importances.sort_values('IMPORTANCE',ascending=False).set_index('FEATURE')

fig, ax = plt.subplots(figsize=(10,5)) 
sel_range = 30
sns.barplot(y = importances[0:sel_range].index, x = importances['IMPORTANCE'][0:sel_range], orient = 'h', ax = ax)

plt.tight_layout()
plt.show()

# %%
y_test_pred = RF_sSplit.predict(X_test)
pl = confusion_matrix(y_test,y_test_pred)
ax= plt.subplot()
p=sns.heatmap(pl, annot=True,cmap ='Blues',ax=ax)
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels');

# %%
print(classification_report(y_test,y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.81      0.69      0.74     17533
#         True       0.70      0.82      0.76     15933
#
#     accuracy                           0.75     33466
#    macro avg       0.76      0.75      0.75     33466
# weighted avg       0.76      0.75      0.75     33466

# %%
y_train_pred = RF_sSplit.predict(X_train)
print(classification_report(y_train,y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00     63523
#         True       1.00      1.00      1.00     70891
#
#     accuracy                           1.00    134414
#    macro avg       1.00      1.00      1.00    134414
# weighted avg       1.00      1.00      1.00    134414

# %% [markdown]
# **Results of Simple Model 2:** Despite that the data was split according to the listening order, the prediction results are almost identical as random split. It is not surprising as the features did not contain any information regarding the listening history (yet), so the way of splitting the data should have no effect on the results.

# %% [markdown]
# # Simple model 3: split the beginning/end of each sequence, random forest classifier, muticlasses
#
# This model will predict all the early and late skipping behavior.

# %%
def skip_label(df):
    skip = (df['not_skipped']==False).astype(int)*4 # no skip: 0, ultra-late skip: 4
    # It has to go under this order. If skip_1 = True, then skip_2 and _3 will be True too.
    skip[df['skip_3']==True] = 3 # late skip
    skip[df['skip_2']==True] = 2 # mid skip
    skip[df['skip_1']==True] = 1 # early skip
    return skip

#print(skip.head(20))
#print(df[['not_skipped','skip_1','skip_2','skip_3']].head(20))

# %%
data_train_append = []
data_test_append = []
for s_id in s_list:
    temp = []
    temp = df.loc[df['session_id']==s_id,:]
    data_train_append.append(temp.iloc[0:round(len(temp)*0.8),:])
    data_test_append.append(temp.iloc[round(len(temp)*0.8):,:])

data_train = pd.concat(data_train_append)
data_test = pd.concat(data_test_append)

X_train = data_train.drop(columns=['not_skipped', 'skip_1', 'skip_2', 'skip_3', 'session_id','track_id_clean','track_id','date'])
X_test = data_test.drop(columns=['not_skipped', 'skip_1', 'skip_2', 'skip_3', 'session_id','track_id_clean','track_id','date'])

y_train = skip_label(data_train)
y_test = skip_label(data_test)

# %%
fig, (ax1, ax2) = plt.subplots(figsize=(8,4), ncols=2) 

y_train.hist(ax = ax1, density = True)
ax1.set_xlabel('label')
ax1.title.set_text('training')

y_test.hist(ax = ax2)
ax2.set_xlabel('label')
ax2.title.set_text('testing')

# %%
RF_MulClass = RandomForestClassifier(random_state=23, n_jobs = -1)
RF_MulClass.fit(X_train, y_train)
score_MulClass_train = RF_MulClass.score(X_train,y_train)
score_MulClass_test = RF_MulClass.score(X_test,y_test)
print('score_train',score_MulClass_train)
print('score_test',score_MulClass_test)
# Out:
# score_train 0.994472301992352
# score_test 0.6213470387856331

# %%
importances = pd.DataFrame({'FEATURE':X_train.columns,'IMPORTANCE':np.round(RF_MulClass.feature_importances_,3)})
importances = importances.sort_values('IMPORTANCE',ascending=False).set_index('FEATURE')

fig, ax = plt.subplots(figsize=(10,5)) 
sel_range = 30
sns.barplot(y = importances[0:sel_range].index, x = importances['IMPORTANCE'][0:sel_range], orient = 'h', ax = ax)

plt.tight_layout()
plt.show()

# %%
y_test_pred = RF_MulClass.predict(X_test)
pl = confusion_matrix(y_test,y_test_pred)
ax= plt.subplot()
p=sns.heatmap(pl, annot=True,cmap ='Blues',ax=ax)
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels');

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.64      0.69     12976
#            1       0.63      0.86      0.73     13007
#            2       0.21      0.09      0.12      2926
#            3       0.31      0.23      0.27      3989
#            4       0.26      0.05      0.09       568
#
#     accuracy                           0.62     33466
#    macro avg       0.43      0.38      0.38     33466
# weighted avg       0.59      0.62      0.59     33466

# %% [markdown]
# **Results of Model 3:** The model performs relatively well for no skip (0) and early skip (1), which is likely because they have more cases. But in general the model performance is not so good, compared to binary classification.

# %% [markdown]
# # Simple model 4: split the beginning/end of each sequence, random forest classifier with hyperparameter tuning, skip_2 (binary)
# Not sure whether it can still be called as a simple model, but the hyperparameter tunning will be implemented here.

# %%
s_list = df['session_id'].unique()
train_perc = 0.8

data_train_append = []
data_test_append = []
for s_id in s_list:
    temp = []
    temp = df.loc[df['session_id']==s_id,:]
    data_train_append.append(temp.iloc[0:round(len(temp)*train_perc),:])
    data_test_append.append(temp.iloc[round(len(temp)*train_perc):,:])

data_train = pd.concat(data_train_append)
data_test = pd.concat(data_test_append)

X_train = data_train.drop(columns=['not_skipped', 'skip_1', 'skip_2', 'skip_3', 'session_id','track_id_clean','track_id','date'])
X_test = data_test.drop(columns=['not_skipped', 'skip_1', 'skip_2', 'skip_3', 'session_id','track_id_clean','track_id','date'])

y_train = data_train['skip_2']
y_test = data_test['skip_2']

# %%
from sklearn.metrics import make_scorer, accuracy_score, balanced_accuracy_score, roc_auc_score


param_grid = {'n_estimators':np.arange(20,200,20), 
             'max_depth':[np.arange(10,100,10),None], 
             'class_weight': ['balanced', None]}
RF_MulClass_pt = RandomForestClassifier(random_state=23, n_jobs = -1)
rf_cv= GridSearchCV(RF_MulClass_pt,
                    param_grid,
                    cv=5, 
                    n_jobs = 6)
rf_cv.fit(X_train,y_train)


pd.DataFrame(rf_cv.cv_results_).to_csv('../models/simpleModel/RF_skip2_GridSearchCV_20221121.csv')
# from joblib import dump, load
# dump(rf_cv, '../models/simpleModel/RF_skip2_GridSearchCV_20221121.joblib')
# Out:
# ['../models/simpleModel/RF_skip2_GridSearchCV_20221121.joblib']

# %%
pd.DataFrame(rf_cv.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.633517      0.008629         0.000000        0.000000
# 1        0.329145      0.162989         0.000000        0.000000
# 2        0.384059      0.058509         0.000000        0.000000
# 3        0.534886      0.079295         0.000000        0.000000
# 4        0.371310      0.057066         0.000000        0.000000
# 5        0.512980      0.045986         0.000000        0.000000
# 6        0.442013      0.209407         0.000000        0.000000
# 7        0.426606      0.341663         0.000000        0.000000
# 8        0.280710      0.013909         0.000000        0.000000
# 9       12.003906      0.204292         0.070793        0.004980
# 10      24.473044      5.277153         0.350662        0.054233
# 11      43.795670      2.042121         0.464201        0.029872
# 12      53.902213      1.213999         0.647919        0.148264
# 13      56.264367      3.274580         0.805735        0.075571
# 14      69.449944      2.259161         1.009910        0.085508
# 15      83.145910      0.247367         1.213180        0.027782
# 16      92.097411      1.528715         1.306589        0.110222
# 17      97.659268      5.763450         2.085263        0.474354
# 18       1.458036      0.323686         0.000000        0.000000
# 19       1.452512      0.324763         0.000000        0.000000
# 20       1.127553      0.077263         0.000000        0.000000
# 21       0.896951      0.099386         0.000000        0.000000
# 22       1.152158      0.114675         0.000000        0.000000
# 23       0.955998      0.250705         0.000000        0.000000
# 24       0.941869      0.074792         0.000000        0.000000
# 25       1.050846      0.275716         0.000000        0.000000
# 26       0.840720      0.263389         0.000000        0.000000
# 27      14.322505      4.244305         0.174672        0.085263
# 28      31.879654      0.669615         0.441064        0.125877
# 29      50.529120      1.060919         0.665885        0.224682
# 30      58.337072      0.742325         0.834431        0.224803
# 31      62.031836      6.150727         0.759742        0.046792
# 32      68.665224      2.343931         1.019307        0.032373
# 33      81.223017      1.939210         1.182447        0.117571
# 34      96.983936      3.946587         1.597293        0.074445
# 35      95.076099     13.839105         0.898642        0.367226
#
#    param_class_weight                       param_max_depth  \
# 0            balanced  [10, 20, 30, 40, 50, 60, 70, 80, 90]
# 1            balanced  [10, 20, 30, 40, 50, 60, 70, 80, 90]
# 2            balanced  [10, 20, 30, 40, 50, 60, 70, 80, 90]
# 3            balanced  [10, 20, 30, 40, 50, 60, 70, 80, 90]
# 4            balanced  [10, 20, 30, 40, 50, 60, 70, 80, 90]
# 5            balanced  [10, 20, 30, 40, 50, 60, 70, 80, 90]
# 6            balanced  [10, 20, 30, 40, 50, 60, 70, 80, 90]
# 7            balanced  [10, 20, 30, 40, 50, 60, 70, 80, 90]
# 8            balanced  [10, 20, 30, 40, 50, 60, 70, 80, 90]
# 9            balanced                                  None
# 10           balanced                                  None
# 11           balanced                                  None
# 12           balanced                                  None
# 13           balanced                                  None
# 14           balanced                                  None
# 15           balanced                                  None
# 16           balanced                                  None
# 17           balanced                                  None
# 18               None  [10, 20, 30, 40, 50, 60, 70, 80, 90]
# 19               None  [10, 20, 30, 40, 50, 60, 70, 80, 90]
# 20               None  [10, 20, 30, 40, 50, 60, 70, 80, 90]
# 21               None  [10, 20, 30, 40, 50, 60, 70, 80, 90]
# 22               None  [10, 20, 30, 40, 50, 60, 70, 80, 90]
# 23               None  [10, 20, 30, 40, 50, 60, 70, 80, 90]
# 24               None  [10, 20, 30, 40, 50, 60, 70, 80, 90]
# 25               None  [10, 20, 30, 40, 50, 60, 70, 80, 90]
# 26               None  [10, 20, 30, 40, 50, 60, 70, 80, 90]
# 27               None                                  None
# 28               None                                  None
# 29               None                                  None
# 30               None                                  None
# 31               None                                  None
# 32               None                                  None
# 33               None                                  None
# 34               None                                  None
# 35               None                                  None
#
#    param_n_estimators                                             params  \
# 0                  20  {'class_weight': 'balanced', 'max_depth': [10,...
# 1                  40  {'class_weight': 'balanced', 'max_depth': [10,...
# 2                  60  {'class_weight': 'balanced', 'max_depth': [10,...
# 3                  80  {'class_weight': 'balanced', 'max_depth': [10,...
# 4                 100  {'class_weight': 'balanced', 'max_depth': [10,...
# 5                 120  {'class_weight': 'balanced', 'max_depth': [10,...
# 6                 140  {'class_weight': 'balanced', 'max_depth': [10,...
# 7                 160  {'class_weight': 'balanced', 'max_depth': [10,...
# 8                 180  {'class_weight': 'balanced', 'max_depth': [10,...
# 9                  20  {'class_weight': 'balanced', 'max_depth': None...
# 10                 40  {'class_weight': 'balanced', 'max_depth': None...
# 11                 60  {'class_weight': 'balanced', 'max_depth': None...
# 12                 80  {'class_weight': 'balanced', 'max_depth': None...
# 13                100  {'class_weight': 'balanced', 'max_depth': None...
# 14                120  {'class_weight': 'balanced', 'max_depth': None...
# 15                140  {'class_weight': 'balanced', 'max_depth': None...
# 16                160  {'class_weight': 'balanced', 'max_depth': None...
# 17                180  {'class_weight': 'balanced', 'max_depth': None...
# 18                 20  {'class_weight': None, 'max_depth': [10, 20, 3...
# 19                 40  {'class_weight': None, 'max_depth': [10, 20, 3...
# 20                 60  {'class_weight': None, 'max_depth': [10, 20, 3...
# 21                 80  {'class_weight': None, 'max_depth': [10, 20, 3...
# 22                100  {'class_weight': None, 'max_depth': [10, 20, 3...
# 23                120  {'class_weight': None, 'max_depth': [10, 20, 3...
# 24                140  {'class_weight': None, 'max_depth': [10, 20, 3...
# 25                160  {'class_weight': None, 'max_depth': [10, 20, 3...
# 26                180  {'class_weight': None, 'max_depth': [10, 20, 3...
# 27                 20  {'class_weight': None, 'max_depth': None, 'n_e...
# 28                 40  {'class_weight': None, 'max_depth': None, 'n_e...
# 29                 60  {'class_weight': None, 'max_depth': None, 'n_e...
# 30                 80  {'class_weight': None, 'max_depth': None, 'n_e...
# 31                100  {'class_weight': None, 'max_depth': None, 'n_e...
# 32                120  {'class_weight': None, 'max_depth': None, 'n_e...
# 33                140  {'class_weight': None, 'max_depth': None, 'n_e...
# 34                160  {'class_weight': None, 'max_depth': None, 'n_e...
# 35                180  {'class_weight': None, 'max_depth': None, 'n_e...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9            0.736227           0.737604           0.739984
# 10           0.741919           0.743407           0.747982
# 11           0.743630           0.745713           0.748912
# 12           0.743630           0.745601           0.749842
# 13           0.743667           0.747796           0.749805
# 14           0.743369           0.746606           0.749470
# 15           0.744002           0.747238           0.750251
# 16           0.744523           0.747312           0.750921
# 17           0.744895           0.746903           0.749879
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20                NaN                NaN                NaN
# 21                NaN                NaN                NaN
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
# 24                NaN                NaN                NaN
# 25                NaN                NaN                NaN
# 26                NaN                NaN                NaN
# 27           0.736823           0.737306           0.737827
# 28           0.740356           0.742253           0.743295
# 29           0.744895           0.744932           0.746754
# 30           0.745341           0.746382           0.747238
# 31           0.744039           0.746345           0.748800
# 32           0.744932           0.746754           0.748875
# 33           0.745267           0.747461           0.748689
# 34           0.744932           0.748056           0.749210
# 35           0.744188           0.748800           0.748912
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0                 NaN                NaN              NaN             NaN
# 1                 NaN                NaN              NaN             NaN
# 2                 NaN                NaN              NaN             NaN
# 3                 NaN                NaN              NaN             NaN
# 4                 NaN                NaN              NaN             NaN
# 5                 NaN                NaN              NaN             NaN
# 6                 NaN                NaN              NaN             NaN
# 7                 NaN                NaN              NaN             NaN
# 8                 NaN                NaN              NaN             NaN
# 9            0.733028           0.743546         0.738078        0.003541
# 10           0.740617           0.747787         0.744342        0.003025
# 11           0.741249           0.746596         0.745220        0.002610
# 12           0.741993           0.748345         0.745882        0.002899
# 13           0.742142           0.748084         0.746299        0.002896
# 14           0.742328           0.748233         0.746001        0.002749
# 15           0.742439           0.748307         0.746448        0.002849
# 16           0.742774           0.748493         0.746805        0.002881
# 17           0.742439           0.749014         0.746626        0.002716
# 18                NaN                NaN              NaN             NaN
# 19                NaN                NaN              NaN             NaN
# 20                NaN                NaN              NaN             NaN
# 21                NaN                NaN              NaN             NaN
# 22                NaN                NaN              NaN             NaN
# 23                NaN                NaN              NaN             NaN
# 24                NaN                NaN              NaN             NaN
# 25                NaN                NaN              NaN             NaN
# 26                NaN                NaN              NaN             NaN
# 27           0.732917           0.739603         0.736895        0.002200
# 28           0.738385           0.744364         0.741731        0.002133
# 29           0.741361           0.745741         0.744736        0.001819
# 30           0.741733           0.748307         0.745800        0.002256
# 31           0.740505           0.747898         0.745518        0.002981
# 32           0.740654           0.748159         0.745875        0.002937
# 33           0.740356           0.748568         0.746068        0.003109
# 34           0.741733           0.748754         0.746537        0.002829
# 35           0.741807           0.748828         0.746507        0.002963
#
#     rank_test_score
# 0                36
# 1                29
# 2                30
# 3                27
# 4                20
# 5                34
# 6                33
# 7                32
# 8                31
# 9                17
# 10               15
# 11               13
# 12                9
# 13                6
# 14                8
# 15                5
# 16                1
# 17                2
# 18               28
# 19               24
# 20               26
# 21               25
# 22               35
# 23               23
# 24               21
# 25               19
# 26               22
# 27               18
# 28               16
# 29               14
# 30               11
# 31               12
# 32               10
# 33                7
# 34                3
# 35                4

# %%
print("Best Score:" + str(rf_cv.best_score_))
print("Best Parameters: " + str(rf_cv.best_params_))
# Out:
# Best Score:0.7468046608891543
# Best Parameters: {'class_weight': 'balanced', 'max_depth': None, 'n_estimators': 160}

# %%
pd.DataFrame(rf_cv.cv_results_).columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_class_weight', 'param_max_depth', 'param_n_estimators', 'params',
#        'split0_test_score', 'split1_test_score', 'split2_test_score',
#        'split3_test_score', 'split4_test_score', 'mean_test_score',
#        'std_test_score', 'rank_test_score'],
#       dtype='object')

# %% [markdown]
# **Results of Model 4:** Without feature engineering, the best parameters of the random forest model are {'class_weight': None, 'max_depth': 10, 'n_estimators': 50}, and the best accuracy was 64.4%, which is only 2% better.

# %% [markdown]
# # Split each sequence: multi-class (SVM)

# %%
# clf = make_pipeline(StandardScaler(), SVC(verbose = True, random_state=23))
# clf.fit(X_train, y_train)
# Out:
# [LibSVM]..............................................................................................................................*..............................................................................................................................*.*
# optimization finished, #iter = 252227
# obj = -36073.929342, rho = 0.292277
# nSV = 47263, nBSV = 30604
# .................................................*................................*
# optimization finished, #iter = 81440
# obj = -23087.018105, rho = -0.397195
# nSV = 28683, nBSV = 21009
# .................................................................*...........................................*.*
# optimization finished, #iter = 108221
# obj = -29105.703096, rho = -0.295036
# nSV = 35559, nBSV = 26185
# ......................................................................................*.........................................................................................*.*
# optimization finished, #iter = 176460
# obj = -22031.591988, rho = -0.638465
# nSV = 31130, nBSV = 17789
# ........................................................................................*..............................................................................................*.*
# optimization finished, #iter = 183320
# obj = -24430.266497, rho = -0.537772
# nSV = 33717, nBSV = 20304
# ...........................*.......*
# optimization finished, #iter = 34578
# obj = -23280.588160, rho = 0.101338
# nSV = 26783, nBSV = 23298
# Total nSV = 94099
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(random_state=23, verbose=True))])

# %%
# score_clf_train = clf.score(X_train,y_train)
# score_clf_test = clf.score(X_test,y_test)
# print('score_train',score_clf_train)
# print('score_test',score_clf_test)
# Out:
# score_train 0.6678768580653801
# score_test 0.6515568039203968

# %%
# from joblib import dump, load
# dump(clf, '../models/simpleModel/SVC_simple.joblib')
# Out:
# ['../models/simpleModel/SVC_simple.joblib']
