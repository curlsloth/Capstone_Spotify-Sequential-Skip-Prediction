# %% [markdown]
# # **Will you skip this music track or not?**
#
#
# The public part of the dataset consists of roughly 130 million listening sessions with associated user interactions on the Spotify service.
#
# The task is to predict whether individual tracks encountered in a listening session will be skipped by a particular user. In order to do this, complete information about the first half of a user’s listening session is provided, while the prediction is to be carried out on the second half. Participants have access to metadata, as well as acoustic descriptors, for all the tracks encountered in listening sessions.
#
# https://www.aicrowd.com/challenges/spotify-sequential-skip-prediction-challenge
#
# Brost, B., Mehrotra, R., & Jehan, T. (2019, May). The music streaming sessions dataset. In The World Wide Web Conference (pp. 2594-2600).

# %% [markdown]
# As the entire dataset is too big to experiment data manipulation, Spotify provided a mini dataset for this purpose.
#
# In this script, we will do data wrangling to inspect the quality of the data, and do data engineering to generate features for machine learning modeling.

# %% [markdown]
# # Mount Google drive to Colab

# %%
# # For Colab only
#from google.colab import drive
#drive.mount('/content/drive')
#%cd /content/drive/MyDrive/Capstone_SpotifyStreaming/notebooks

#!pip install featuretools==0.4.0
#!pip install -U featuretools
#!pip install featuretools

# # check the installed packages
# pip list -v

# %%
import numpy as np
import pandas as pd
import featuretools as ft
import time
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load the data and perform some data cleaning/re-coding as described in 2_mini_EDA

# %%
# load the track information (mini version)

tf_df = pd.read_csv('../data/raw/data/track_features/tf_mini.csv')
log_df = pd.read_csv('../data/raw/data/training_set/log_mini.csv')

# %%
# perform some data cleaning/re-coding as described in 2_mini_EDA

tf_df_dummy = pd.get_dummies(tf_df, columns=['key','time_signature','mode'])
log_df_dummy = pd.get_dummies(log_df.drop(columns = ['session_length',  'hist_user_behavior_reason_end', 'hist_user_behavior_n_seekfwd','hist_user_behavior_n_seekback']), columns=['hist_user_behavior_reason_start', 'context_type'])

# %%
tf_df_dummy.head().T
# Out:
#                                                              0  \
# track_id                t_a540e552-16d4-42f8-a185-232bd650ea7d
# duration                                            109.706673
# release_year                                              1950
# us_popularity_estimate                               99.975414
# acousticness                                           0.45804
# beat_strength                                         0.519497
# bounciness                                            0.504949
# danceability                                          0.399767
# dyn_range_mean                                         7.51188
# energy                                                0.817709
# flatness                                              0.903753
# instrumentalness                                      0.000003
# liveness                                              0.132124
# loudness                                               -11.238
# mechanism                                               0.3861
# organism                                              0.541606
# speechiness                                           0.079985
# tempo                                               166.287003
# valence                                               0.935512
# acoustic_vector_0                                    -0.033284
# acoustic_vector_1                                    -0.411896
# acoustic_vector_2                                     -0.02858
# acoustic_vector_3                                     0.349438
# acoustic_vector_4                                     0.832467
# acoustic_vector_5                                    -0.213871
# acoustic_vector_6                                    -0.299464
# acoustic_vector_7                                    -0.675907
# key_0                                                        1
# key_1                                                        0
# key_2                                                        0
# key_3                                                        0
# key_4                                                        0
# key_5                                                        0
# key_6                                                        0
# key_7                                                        0
# key_8                                                        0
# key_9                                                        0
# key_10                                                       0
# key_11                                                       0
# time_signature_0                                             0
# time_signature_1                                             0
# time_signature_3                                             0
# time_signature_4                                             1
# time_signature_5                                             0
# mode_major                                                   1
# mode_minor                                                   0
#
#                                                              1  \
# track_id                t_67965da0-132b-4b1e-8a69-0ef99b32287c
# duration                                            187.693329
# release_year                                              1950
# us_popularity_estimate                                99.96943
# acousticness                                          0.916272
# beat_strength                                         0.419223
# bounciness                                             0.54553
# danceability                                          0.491235
# dyn_range_mean                                        9.098376
# energy                                                0.154258
# flatness                                              1.037952
# instrumentalness                                           0.0
# liveness                                              0.163281
# loudness                                               -13.706
# mechanism                                                0.125
# organism                                              0.895874
# speechiness                                           0.083877
# tempo                                                95.261002
# valence                                               0.359675
# acoustic_vector_0                                     0.145703
# acoustic_vector_1                                    -0.850372
# acoustic_vector_2                                      0.12386
# acoustic_vector_3                                     0.746904
# acoustic_vector_4                                     0.371803
# acoustic_vector_5                                    -0.420558
# acoustic_vector_6                                     -0.21312
# acoustic_vector_7                                    -0.525795
# key_0                                                        1
# key_1                                                        0
# key_2                                                        0
# key_3                                                        0
# key_4                                                        0
# key_5                                                        0
# key_6                                                        0
# key_7                                                        0
# key_8                                                        0
# key_9                                                        0
# key_10                                                       0
# key_11                                                       0
# time_signature_0                                             0
# time_signature_1                                             0
# time_signature_3                                             1
# time_signature_4                                             0
# time_signature_5                                             0
# mode_major                                                   1
# mode_minor                                                   0
#
#                                                              2  \
# track_id                t_0614ecd3-a7d5-40a1-816e-156d5872a467
# duration                                            160.839996
# release_year                                              1951
# us_popularity_estimate                               99.602549
# acousticness                                          0.812884
# beat_strength                                          0.42589
# bounciness                                             0.50828
# danceability                                          0.491625
# dyn_range_mean                                         8.36867
# energy                                                0.358813
# flatness                                              1.004268
# instrumentalness                                           0.0
# liveness                                              0.090115
# loudness                                               -10.522
# mechanism                                             0.200669
# organism                                              0.806136
# speechiness                                           0.038777
# tempo                                               105.185997
# valence                                               0.726769
# acoustic_vector_0                                      0.02172
# acoustic_vector_1                                    -0.743634
# acoustic_vector_2                                     0.333247
# acoustic_vector_3                                     0.568447
# acoustic_vector_4                                     0.411094
# acoustic_vector_5                                    -0.187749
# acoustic_vector_6                                    -0.387599
# acoustic_vector_7                                    -0.433496
# key_0                                                        1
# key_1                                                        0
# key_2                                                        0
# key_3                                                        0
# key_4                                                        0
# key_5                                                        0
# key_6                                                        0
# key_7                                                        0
# key_8                                                        0
# key_9                                                        0
# key_10                                                       0
# key_11                                                       0
# time_signature_0                                             0
# time_signature_1                                             0
# time_signature_3                                             0
# time_signature_4                                             1
# time_signature_5                                             0
# mode_major                                                   0
# mode_minor                                                   1
#
#                                                              3  \
# track_id                t_070a63a0-744a-434e-9913-a97b02926a29
# duration                                            175.399994
# release_year                                              1951
# us_popularity_estimate                               99.665018
# acousticness                                          0.396854
# beat_strength                                         0.400934
# bounciness                                             0.35999
# danceability                                          0.552227
# dyn_range_mean                                        5.967346
# energy                                                0.514585
# flatness                                              0.975138
# instrumentalness                                           0.0
# liveness                                              0.360924
# loudness                                               -11.032
# mechanism                                             0.427152
# organism                                              0.492772
# speechiness                                           0.038337
# tempo                                               119.441002
# valence                                               0.859075
# acoustic_vector_0                                     0.039143
# acoustic_vector_1                                    -0.267555
# acoustic_vector_2                                    -0.051825
# acoustic_vector_3                                     0.106173
# acoustic_vector_4                                     0.614825
# acoustic_vector_5                                    -0.111419
# acoustic_vector_6                                    -0.265953
# acoustic_vector_7                                    -0.542753
# key_0                                                        1
# key_1                                                        0
# key_2                                                        0
# key_3                                                        0
# key_4                                                        0
# key_5                                                        0
# key_6                                                        0
# key_7                                                        0
# key_8                                                        0
# key_9                                                        0
# key_10                                                       0
# key_11                                                       0
# time_signature_0                                             0
# time_signature_1                                             0
# time_signature_3                                             0
# time_signature_4                                             1
# time_signature_5                                             0
# mode_major                                                   1
# mode_minor                                                   0
#
#                                                              4
# track_id                t_d6990e17-9c31-4b01-8559-47d9ce476df1
# duration                                            369.600006
# release_year                                              1951
# us_popularity_estimate                               99.991764
# acousticness                                          0.728831
# beat_strength                                         0.371328
# bounciness                                            0.335115
# danceability                                          0.483044
# dyn_range_mean                                        5.802681
# energy                                                0.721442
# flatness                                              0.976866
# instrumentalness                                           0.0
# liveness                                              0.189162
# loudness                                                -6.836
# mechanism                                              0.28125
# organism                                              0.723808
# speechiness                                           0.032043
# tempo                                                95.261002
# valence                                               0.562343
# acoustic_vector_0                                     0.131931
# acoustic_vector_1                                    -0.292523
# acoustic_vector_2                                    -0.174819
# acoustic_vector_3                                    -0.034422
# acoustic_vector_4                                     0.717229
# acoustic_vector_5                                    -0.016239
# acoustic_vector_6                                    -0.392694
# acoustic_vector_7                                    -0.455496
# key_0                                                        1
# key_1                                                        0
# key_2                                                        0
# key_3                                                        0
# key_4                                                        0
# key_5                                                        0
# key_6                                                        0
# key_7                                                        0
# key_8                                                        0
# key_9                                                        0
# key_10                                                       0
# key_11                                                       0
# time_signature_0                                             0
# time_signature_1                                             0
# time_signature_3                                             0
# time_signature_4                                             1
# time_signature_5                                             0
# mode_major                                                   1
# mode_minor                                                   0

# %%
log_df_dummy.head().T
# Out:
#                                                                                  0  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 1
# track_id_clean                              t_0479f24c-27d2-46d6-a00c-7ec928f2b539
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             0
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
#
#                                                                                  1  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 2
# track_id_clean                              t_9099cd7b-c238-47b7-9381-f23f2c1d1043
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
#
#                                                                                  2  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 3
# track_id_clean                              t_fc5df5ba-5396-49a7-8b29-35d0d28249e0
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
#
#                                                                                  3  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 4
# track_id_clean                              t_23cff8d6-d874-4b20-83dc-94e450e8aa20
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
#
#                                                                                  4
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 5
# track_id_clean                              t_64f3743c-f624-46bb-a579-0f3f9a07a123
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0

# %% [markdown]
# # add skipping information as new columns

# %%
session_id = log_df_dummy['session_id'].unique()
print('number of sessions in this mini dataset:',len(session_id))
# Out:
# number of sessions in this mini dataset: 10000

# %%
# # the function of integrating the skipping labels into one column
# def skip_label(df):
#     skip = (df['not_skipped']==False).astype(int)*4 # no skip: 0, ultra-late skip: 4
#     # It has to go under this order. If skip_1 = True, then skip_2 and _3 will be True too.
#     skip[df['skip_3']==True] = 3 # late skip
#     skip[df['skip_2']==True] = 2 # mid skip
#     skip[df['skip_1']==True] = 1 # early skip
#     return skip

# log_df_dummy['skip_label'] = skip_label(log_df_dummy)

# %%
# make a column which has session ID and skip info
# log_df_dummy['session_id_skip_label'] = log_df_dummy['session_id'] + '_skip_' + log_df_dummy['skip_label'].astype(str)
log_df_dummy['session_id_skip_2_False'] = log_df_dummy['session_id'] * (log_df_dummy['skip_2'] == False)
log_df_dummy['session_id_skip_2_True'] = log_df_dummy['session_id'] * (log_df_dummy['skip_2'] == True)
# log_df_dummy['session_id_not_skipped_True'] = log_df_dummy['session_id'] * (log_df_dummy['not_skipped'] == True)
# log_df_dummy['session_id_not_skipped_False'] = log_df_dummy['session_id'] * (log_df_dummy['not_skipped'] == False)

log_df_dummy.head(10).T
# Out:
#                                                                                  0  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 1
# track_id_clean                              t_0479f24c-27d2-46d6-a00c-7ec928f2b539
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             0
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# session_id_skip_2_False                     0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_id_skip_2_True
#
#                                                                                  1  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 2
# track_id_clean                              t_9099cd7b-c238-47b7-9381-f23f2c1d1043
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# session_id_skip_2_False                     0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_id_skip_2_True
#
#                                                                                  2  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 3
# track_id_clean                              t_fc5df5ba-5396-49a7-8b29-35d0d28249e0
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# session_id_skip_2_False                     0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_id_skip_2_True
#
#                                                                                  3  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 4
# track_id_clean                              t_23cff8d6-d874-4b20-83dc-94e450e8aa20
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# session_id_skip_2_False                     0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_id_skip_2_True
#
#                                                                                  4  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 5
# track_id_clean                              t_64f3743c-f624-46bb-a579-0f3f9a07a123
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# session_id_skip_2_False                     0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_id_skip_2_True
#
#                                                                                  5  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 6
# track_id_clean                              t_c815228b-3212-4f9e-9d4f-9cb19b248184
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                        True
# not_skipped                                                                  False
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# session_id_skip_2_False                     0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_id_skip_2_True
#
#                                                                                  6  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 7
# track_id_clean                              t_e23c19f5-4c32-4557-aa44-81372c2e3705
# skip_1                                                                        True
# skip_2                                                                        True
# skip_3                                                                        True
# not_skipped                                                                  False
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           1
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        0
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# session_id_skip_2_False
# session_id_skip_2_True                      0_00006f66-33e5-4de7-a324-2d18e439fc1e
#
#                                                                                  7  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 8
# track_id_clean                              t_0be6eced-f56f-48bd-8086-f2e0b760fdee
# skip_1                                                                        True
# skip_2                                                                        True
# skip_3                                                                        True
# not_skipped                                                                  False
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           1
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        0
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# session_id_skip_2_False
# session_id_skip_2_True                      0_00006f66-33e5-4de7-a324-2d18e439fc1e
#
#                                                                                  8  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 9
# track_id_clean                              t_f3ecbd3b-9e8e-4557-b8e0-39cfcd7e65dd
# skip_1                                                                       False
# skip_2                                                                        True
# skip_3                                                                        True
# not_skipped                                                                  False
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           1
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        0
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# session_id_skip_2_False
# session_id_skip_2_True                      0_00006f66-33e5-4de7-a324-2d18e439fc1e
#
#                                                                                  9
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                10
# track_id_clean                              t_2af4dfa0-7df3-4b7e-b7ab-353ba48237f9
# skip_1                                                                        True
# skip_2                                                                        True
# skip_3                                                                        True
# not_skipped                                                                  False
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           1
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        0
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# session_id_skip_2_False
# session_id_skip_2_True                      0_00006f66-33e5-4de7-a324-2d18e439fc1e

# %% [markdown]
# # Calculate the feature distance/similarity between adjacent tracks
#
# The track information dataframe contains acoustic analysis and scores of each track on 8 acoustic features (see: https://benanne.github.io/2014/08/05/spotify-cnns.html). Therefore, within each session, I would like to calculate the ***distance*** or ***similarity*** of each track to the other tracks.

# %%
# extract the acoustic features of each track
df = log_df_dummy.merge(tf_df_dummy[['track_id','acousticness','beat_strength','danceability',
                                     'dyn_range_mean', 'energy', 'flatness','instrumentalness', 'liveness', 
                                     'loudness', 'mechanism', 'organism','speechiness','valence',
                                     'acoustic_vector_0','acoustic_vector_1', 'acoustic_vector_2', 'acoustic_vector_3',
                                     'acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6','acoustic_vector_7']], 
                        left_on = 'track_id_clean', 
                        right_on = 'track_id')
df.sort_values(by = ['session_id', 'session_position'],inplace = True)
df.head().T
# Out:
#                                                                                0    \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 1
# track_id_clean                              t_0479f24c-27d2-46d6-a00c-7ec928f2b539
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             0
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# session_id_skip_2_False                     0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_id_skip_2_True
# track_id                                    t_0479f24c-27d2-46d6-a00c-7ec928f2b539
# acousticness                                                              0.015848
# beat_strength                                                             0.438551
# danceability                                                              0.653119
# dyn_range_mean                                                            7.660024
# energy                                                                    0.553465
# flatness                                                                  1.035007
# instrumentalness                                                          0.003484
# liveness                                                                  0.678553
# loudness                                                                    -6.577
# mechanism                                                                 0.546784
# organism                                                                  0.320668
# speechiness                                                               0.069717
# valence                                                                   0.152255
# acoustic_vector_0                                                        -0.815775
# acoustic_vector_1                                                         0.386409
# acoustic_vector_2                                                          0.23016
# acoustic_vector_3                                                         0.028028
# acoustic_vector_4                                                        -0.333373
# acoustic_vector_5                                                         0.015452
# acoustic_vector_6                                                         -0.35359
# acoustic_vector_7                                                         0.205826
#
#                                                                                45   \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 2
# track_id_clean                              t_9099cd7b-c238-47b7-9381-f23f2c1d1043
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# session_id_skip_2_False                     0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_id_skip_2_True
# track_id                                    t_9099cd7b-c238-47b7-9381-f23f2c1d1043
# acousticness                                                              0.061811
# beat_strength                                                             0.654804
# danceability                                                              0.877393
# dyn_range_mean                                                            11.30875
# energy                                                                    0.726828
# flatness                                                                  1.025636
# instrumentalness                                                               0.0
# liveness                                                                  0.104322
# loudness                                                                    -5.319
# mechanism                                                                 0.824766
# organism                                                                  0.131391
# speechiness                                                               0.061158
# valence                                                                   0.337152
# acoustic_vector_0                                                        -0.713646
# acoustic_vector_1                                                         0.363718
# acoustic_vector_2                                                         0.310315
# acoustic_vector_3                                                        -0.042222
# acoustic_vector_4                                                        -0.383164
# acoustic_vector_5                                                         0.066357
# acoustic_vector_6                                                        -0.365308
# acoustic_vector_7                                                          0.15792
#
#                                                                                50   \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 3
# track_id_clean                              t_fc5df5ba-5396-49a7-8b29-35d0d28249e0
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# session_id_skip_2_False                     0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_id_skip_2_True
# track_id                                    t_fc5df5ba-5396-49a7-8b29-35d0d28249e0
# acousticness                                                              0.354116
# beat_strength                                                             0.532155
# danceability                                                              0.679719
# dyn_range_mean                                                            8.065802
# energy                                                                    0.563009
# flatness                                                                  1.029465
# instrumentalness                                                               0.0
# liveness                                                                  0.135776
# loudness                                                                    -5.843
# mechanism                                                                 0.774327
# organism                                                                  0.296923
# speechiness                                                               0.045354
# valence                                                                   0.373862
# acoustic_vector_0                                                        -0.742541
# acoustic_vector_1                                                         0.375599
# acoustic_vector_2                                                          0.25266
# acoustic_vector_3                                                        -0.049007
# acoustic_vector_4                                                        -0.299745
# acoustic_vector_5                                                         0.063341
# acoustic_vector_6                                                        -0.486689
# acoustic_vector_7                                                         0.181604
#
#                                                                                327  \
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 4
# track_id_clean                              t_23cff8d6-d874-4b20-83dc-94e450e8aa20
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# session_id_skip_2_False                     0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_id_skip_2_True
# track_id                                    t_23cff8d6-d874-4b20-83dc-94e450e8aa20
# acousticness                                                              0.769225
# beat_strength                                                             0.641756
# danceability                                                              0.864881
# dyn_range_mean                                                           11.287586
# energy                                                                    0.529484
# flatness                                                                   0.99352
# instrumentalness                                                          0.000007
# liveness                                                                  0.103722
# loudness                                                                    -7.756
# mechanism                                                                 0.630996
# organism                                                                  0.603271
# speechiness                                                               0.229936
# valence                                                                    0.64942
# acoustic_vector_0                                                        -0.705116
# acoustic_vector_1                                                         0.317562
# acoustic_vector_2                                                         0.289141
# acoustic_vector_3                                                         -0.03892
# acoustic_vector_4                                                        -0.393358
# acoustic_vector_5                                                         0.092719
# acoustic_vector_6                                                        -0.364418
# acoustic_vector_7                                                         0.285603
#
#                                                                                353
# session_id                                  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                 5
# track_id_clean                              t_64f3743c-f624-46bb-a579-0f3f9a07a123
# skip_1                                                                       False
# skip_2                                                                       False
# skip_3                                                                       False
# not_skipped                                                                   True
# context_switch                                                                   0
# no_pause_before_play                                                             1
# short_pause_before_play                                                          0
# long_pause_before_play                                                           0
# hist_user_behavior_is_shuffle                                                 True
# hour_of_day                                                                     16
# date                                                                    2018-07-15
# premium                                                                       True
# hist_user_behavior_reason_start_appload                                          0
# hist_user_behavior_reason_start_backbtn                                          0
# hist_user_behavior_reason_start_clickrow                                         0
# hist_user_behavior_reason_start_endplay                                          0
# hist_user_behavior_reason_start_fwdbtn                                           0
# hist_user_behavior_reason_start_playbtn                                          0
# hist_user_behavior_reason_start_remote                                           0
# hist_user_behavior_reason_start_trackdone                                        1
# hist_user_behavior_reason_start_trackerror                                       0
# context_type_catalog                                                             0
# context_type_charts                                                              0
# context_type_editorial_playlist                                                  1
# context_type_personalized_playlist                                               0
# context_type_radio                                                               0
# context_type_user_collection                                                     0
# session_id_skip_2_False                     0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_id_skip_2_True
# track_id                                    t_64f3743c-f624-46bb-a579-0f3f9a07a123
# acousticness                                                              0.006602
# beat_strength                                                             0.732428
# danceability                                                              0.857778
# dyn_range_mean                                                           12.181586
# energy                                                                    0.650057
# flatness                                                                  1.000571
# instrumentalness                                                          0.000002
# liveness                                                                  0.120842
# loudness                                                                    -4.919
# mechanism                                                                 0.759465
# organism                                                                  0.170148
# speechiness                                                                0.24098
# valence                                                                   0.652921
# acoustic_vector_0                                                        -0.868489
# acoustic_vector_1                                                          0.33128
# acoustic_vector_2                                                         0.210478
# acoustic_vector_3                                                          0.08474
# acoustic_vector_4                                                        -0.333287
# acoustic_vector_5                                                        -0.025706
# acoustic_vector_6                                                         -0.51035
# acoustic_vector_7                                                         0.182315

# %%
temp_data = df.loc[df['session_id'] == session_id[0]]
temp_data
# Out:
#                                  session_id  session_position  \
# 0    0_00006f66-33e5-4de7-a324-2d18e439fc1e                 1
# 45   0_00006f66-33e5-4de7-a324-2d18e439fc1e                 2
# 50   0_00006f66-33e5-4de7-a324-2d18e439fc1e                 3
# 327  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 4
# 353  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 5
# 475  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 6
# 537  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 7
# 540  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 8
# 541  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 9
# 601  0_00006f66-33e5-4de7-a324-2d18e439fc1e                10
# 610  0_00006f66-33e5-4de7-a324-2d18e439fc1e                11
# 621  0_00006f66-33e5-4de7-a324-2d18e439fc1e                12
# 623  0_00006f66-33e5-4de7-a324-2d18e439fc1e                13
# 650  0_00006f66-33e5-4de7-a324-2d18e439fc1e                14
# 712  0_00006f66-33e5-4de7-a324-2d18e439fc1e                15
# 720  0_00006f66-33e5-4de7-a324-2d18e439fc1e                16
# 736  0_00006f66-33e5-4de7-a324-2d18e439fc1e                17
# 737  0_00006f66-33e5-4de7-a324-2d18e439fc1e                18
# 790  0_00006f66-33e5-4de7-a324-2d18e439fc1e                19
# 823  0_00006f66-33e5-4de7-a324-2d18e439fc1e                20
#
#                              track_id_clean  skip_1  skip_2  skip_3  \
# 0    t_0479f24c-27d2-46d6-a00c-7ec928f2b539   False   False   False
# 45   t_9099cd7b-c238-47b7-9381-f23f2c1d1043   False   False   False
# 50   t_fc5df5ba-5396-49a7-8b29-35d0d28249e0   False   False   False
# 327  t_23cff8d6-d874-4b20-83dc-94e450e8aa20   False   False   False
# 353  t_64f3743c-f624-46bb-a579-0f3f9a07a123   False   False   False
# 475  t_c815228b-3212-4f9e-9d4f-9cb19b248184   False   False    True
# 537  t_e23c19f5-4c32-4557-aa44-81372c2e3705    True    True    True
# 540  t_0be6eced-f56f-48bd-8086-f2e0b760fdee    True    True    True
# 541  t_f3ecbd3b-9e8e-4557-b8e0-39cfcd7e65dd   False    True    True
# 601  t_2af4dfa0-7df3-4b7e-b7ab-353ba48237f9    True    True    True
# 610  t_79570b2a-639a-4ec0-9853-71c5299ac44d    True    True    True
# 621  t_69016f19-84aa-40c0-afa9-54404397b7a2    True    True    True
# 623  t_59dc3fcd-7aec-4da5-a747-b59b19bab3bb    True    True    True
# 650  t_a157ba98-7eae-4e7d-99d5-ed760b2c0978   False   False   False
# 712  t_87d95b75-af5c-4ef6-8dc4-cd888ae17cce   False    True    True
# 720  t_db945033-3dc5-4a22-8889-c72fd2781299   False    True    True
# 736  t_bff5b6c6-6968-41be-b723-7e860b372975   False    True    True
# 737  t_bf496d77-9eb2-4fe1-80f7-2c7ecd6f9b8e   False    True    True
# 790  t_1051bc37-1a73-4301-812b-f83ae0c9bbcd    True    True    True
# 823  t_358c9cce-7a1e-4dd4-81de-206dda80363f    True    True    True
#
#      not_skipped  context_switch  no_pause_before_play  \
# 0           True               0                     0
# 45          True               0                     1
# 50          True               0                     1
# 327         True               0                     1
# 353         True               0                     1
# 475        False               0                     1
# 537        False               0                     1
# 540        False               0                     1
# 541        False               0                     1
# 601        False               0                     1
# 610        False               0                     1
# 621        False               0                     1
# 623        False               0                     1
# 650         True               0                     1
# 712        False               0                     1
# 720        False               0                     0
# 736        False               0                     1
# 737        False               0                     1
# 790        False               0                     1
# 823        False               0                     1
#
#      short_pause_before_play  ...  speechiness   valence  acoustic_vector_0  \
# 0                          0  ...     0.069717  0.152255          -0.815775
# 45                         0  ...     0.061158  0.337152          -0.713646
# 50                         0  ...     0.045354  0.373862          -0.742541
# 327                        0  ...     0.229936  0.649420          -0.705116
# 353                        0  ...     0.240980  0.652921          -0.868489
# 475                        0  ...     0.133586  0.661081          -0.817504
# 537                        0  ...     0.409848  0.109420          -0.748412
# 540                        0  ...     0.103687  0.389913          -0.921928
# 541                        0  ...     0.049853  0.338321          -0.744412
# 601                        0  ...     0.154609  0.257672          -0.647221
# 610                        0  ...     0.027932  0.037998          -0.573548
# 621                        0  ...     0.414651  0.650353          -1.056293
# 623                        0  ...     0.364139  0.306544          -0.800501
# 650                        0  ...     0.256456  0.538387          -0.858347
# 712                        0  ...     0.125605  0.413239          -0.797031
# 720                        1  ...     0.424763  0.150389          -0.815604
# 736                        0  ...     0.067412  0.283693          -0.837439
# 737                        0  ...     0.140268  0.565847          -0.738906
# 790                        0  ...     0.104258  0.369472          -0.699905
# 823                        0  ...     0.419025  0.775439          -0.844636
#
#     acoustic_vector_1  acoustic_vector_2  acoustic_vector_3  \
# 0            0.386409           0.230160           0.028028
# 45           0.363718           0.310315          -0.042222
# 50           0.375599           0.252660          -0.049007
# 327          0.317562           0.289141          -0.038920
# 353          0.331280           0.210478           0.084740
# 475          0.283297           0.387589           0.279636
# 537          0.321976           0.237488           0.003480
# 540          0.359740           0.293674           0.115302
# 541          0.308700           0.230126           0.066493
# 601          0.316101           0.251329          -0.041532
# 610          0.284808           0.249904          -0.080877
# 621          0.386749           0.348130           0.237089
# 623          0.270084           0.259297           0.089380
# 650          0.317665           0.326257           0.103337
# 712          0.424720           0.342543          -0.023328
# 720          0.428640           0.333781           0.005816
# 736          0.368295           0.271468           0.024429
# 737          0.337211           0.417896           0.099998
# 790          0.307918           0.229517          -0.037115
# 823          0.399668           0.303160           0.032852
#
#      acoustic_vector_4  acoustic_vector_5  acoustic_vector_6  \
# 0            -0.333373           0.015452          -0.353590
# 45           -0.383164           0.066357          -0.365308
# 50           -0.299745           0.063341          -0.486689
# 327          -0.393358           0.092719          -0.364418
# 353          -0.333287          -0.025706          -0.510350
# 475          -0.280334           0.117993           0.106159
# 537          -0.315287           0.032431          -0.464694
# 540          -0.274987           0.043193          -0.444351
# 541          -0.242549           0.025370          -0.403210
# 601          -0.252359           0.059971          -0.313696
# 610          -0.337629           0.116421          -0.337717
# 621          -0.283027           0.023691          -0.254449
# 623          -0.324667           0.030543          -0.431700
# 650          -0.287205           0.031015          -0.448952
# 712          -0.315267           0.107823          -0.384532
# 720          -0.396930           0.048073          -0.344478
# 736          -0.292806           0.032801          -0.485078
# 737          -0.437304           0.187556          -0.031751
# 790          -0.318094           0.045434          -0.417897
# 823          -0.309105           0.048137          -0.410277
#
#      acoustic_vector_7
# 0             0.205826
# 45            0.157920
# 50            0.181604
# 327           0.285603
# 353           0.182315
# 475           0.311233
# 537           0.200836
# 540           0.211909
# 541           0.159350
# 601           0.126421
# 610           0.247187
# 621           0.266956
# 623           0.233430
# 650           0.202570
# 712           0.181089
# 720           0.151020
# 736           0.183784
# 737           0.259453
# 790           0.199561
# 823           0.217713
#
# [20 rows x 54 columns]

# %%
def cal_dist(x):
    from scipy.spatial.distance import cdist
    Y_euc = cdist(x, x, 'euclidean')
    Y_cos = cdist(x, x, 'cosine')
    Y_man = cdist(x, x, 'cityblock')
    # The 1st track of each session should have unreasonably far distance
    euc_dist = [0]
    cos_dist = [0]
    man_dist = [0]
    for n in range(1,len(x)):
        euc_dist.append(Y_euc[n,n-1])
        cos_dist.append(Y_cos[n,n-1])
        man_dist.append(Y_man[n,n-1])
    return euc_dist, cos_dist, man_dist

# %%
# calculate the distance/similarity within each session
## probably the acoustic features have to be scaled before combining the data!!!
from sklearn.preprocessing import StandardScaler

# as the last 20% of the rows of each session will be used as the testing dataset, they should not be fitted by the scaler
train_perc = 0.8

# sel_col_names = ['skip_label','acousticness','beat_strength','danceability',
#                         'dyn_range_mean', 'energy', 'flatness','instrumentalness', 'liveness', 
#                         'loudness', 'mechanism', 'organism','speechiness','valence',
#                         'acoustic_vector_0','acoustic_vector_1', 'acoustic_vector_2', 'acoustic_vector_3',
#                         'acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6','acoustic_vector_7']
sel_col_names = ['acousticness','beat_strength','danceability',
                        'dyn_range_mean', 'energy', 'flatness','instrumentalness', 'liveness', 
                        'loudness', 'mechanism', 'organism','speechiness','valence',
                        'acoustic_vector_0','acoustic_vector_1', 'acoustic_vector_2', 'acoustic_vector_3',
                        'acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6','acoustic_vector_7']

start_time = time.time()

for s_id in session_id:
    temp_data = []
    temp_mat = []
    temp_data = df.loc[df['session_id'] == s_id, sel_col_names]
#     temp_mat = temp_data.drop(columns = ['skip_label']).copy()
    temp_mat = temp_data.copy()
    scaler = StandardScaler()
    scaler.fit(temp_mat[0:round(len(temp_mat)*train_perc)])
    temp_mat_scaled = scaler.transform(temp_mat)
#     temp_mat_scaled_skip0 = temp_mat_scaled[temp_data['skip_label']==0]
#     temp_mat_scaled_skip1 = temp_mat_scaled[temp_data['skip_label']==1]
#     temp_mat_scaled_skipR = temp_mat_scaled[temp_data['skip_label']>1]
    
    
    euc_dist_all, cos_dist_all, man_dist_all = cal_dist(temp_mat_scaled)
    df.loc[temp_data.index, 'euc_dist_all'] = euc_dist_all
    df.loc[temp_data.index, 'cos_dist_all'] = cos_dist_all
    df.loc[temp_data.index, 'man_dist_all'] = man_dist_all
    
#     euc_dist_skip0, cos_dist_skip0, man_dist_skip0 = cal_dist(temp_mat_scaled_skip0)
#     loc_index0 = temp_data.index[temp_data['skip_label']==0].tolist()
#     df.loc[loc_index0, 'euc_dist_skip0'] = euc_dist_skip0
#     df.loc[loc_index0, 'cos_dist_skip0'] = cos_dist_skip0
#     df.loc[loc_index0, 'man_dist_skip0'] = man_dist_skip0
    
#     euc_dist_skip1, cos_dist_skip1, man_dist_skip1 = cal_dist(temp_mat_scaled_skip1)
#     loc_index1 = temp_data.index[temp_data['skip_label']==1].tolist()
#     df.loc[loc_index1, 'euc_dist_skip1'] = euc_dist_skip1
#     df.loc[loc_index1, 'cos_dist_skip1'] = cos_dist_skip1
#     df.loc[loc_index1, 'man_dist_skip1'] = man_dist_skip1
    
#     euc_dist_skipR, cos_dist_skipR, man_dist_skipR = cal_dist(temp_mat_scaled_skipR)
#     loc_indexR = temp_data.index[temp_data['skip_label']>1].tolist()
#     df.loc[loc_indexR, 'euc_dist_skipR'] = euc_dist_skipR
#     df.loc[loc_indexR, 'cos_dist_skipR'] = cos_dist_skipR
#     df.loc[loc_indexR, 'man_dist_skipR'] = man_dist_skipR

print('***It takes ',(time.time() - start_time)/60, ' minutes.***')
# Out:
# ***It takes  1.7423949201901754  minutes.***

# %%
log_df_dummy2 = df.drop(columns = ['track_id','acousticness','beat_strength','danceability',
                                     'dyn_range_mean', 'energy', 'flatness','instrumentalness', 'liveness', 
                                     'loudness', 'mechanism', 'organism','speechiness','valence',
                                     'acoustic_vector_0','acoustic_vector_1', 'acoustic_vector_2', 'acoustic_vector_3',
                                     'acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6','acoustic_vector_7'])
log_df_dummy2['session_id_skip_2_False'] = log_df_dummy2['session_id_skip_2_False'].astype('category')
log_df_dummy2['session_id_skip_2_True'] = log_df_dummy2['session_id_skip_2_True'].astype('category')

# %%
# log_df_dummy2 = df.drop(columns = ['skip_label','track_id','acousticness','beat_strength','danceability',
#                                      'dyn_range_mean', 'energy', 'flatness','instrumentalness', 'liveness', 
#                                      'loudness', 'mechanism', 'organism','speechiness','valence',
#                                      'acoustic_vector_0','acoustic_vector_1', 'acoustic_vector_2', 'acoustic_vector_3',
#                                      'acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6','acoustic_vector_7'])
# log_df_dummy2['session_id_skip_label'] = log_df_dummy2['session_id_skip_label'].astype('category')
# log_df_dummy2['session_id_skip_1_False'] = log_df_dummy2['session_id_skip_1_False'].astype('category')
# log_df_dummy2['session_id_skip_1_True'] = log_df_dummy2['session_id_skip_1_True'].astype('category')
# log_df_dummy2['session_id_not_skipped_True'] = log_df_dummy2['session_id_not_skipped_True'].astype('category')
# log_df_dummy2['session_id_not_skipped_False'] = log_df_dummy2['session_id_not_skipped_False'].astype('category')

# %% [markdown]
# # **Use featuretool to do automatic feature engineering**

# %%
#First, initializing an EntitySet with a name
es = ft.EntitySet(id="spotify_data")

# %%
from woodwork.logical_types import Categorical, PostalCode

es = es.add_dataframe(
    dataframe_name="tf",
    dataframe=tf_df_dummy,
    index="track_id",
)

es
# Out:
# Entityset: spotify_data
#   DataFrames:
#     tf [Rows: 50704, Columns: 46]
#   Relationships:
#     No relationships

# %%
es['tf'].ww.schema
# Out:
#                        Logical Type Semantic Tag(s)
# Column
# track_id                    Unknown       ['index']
# duration                     Double     ['numeric']
# release_year                Integer     ['numeric']
# us_popularity_estimate       Double     ['numeric']
# acousticness                 Double     ['numeric']
# beat_strength                Double     ['numeric']
# bounciness                   Double     ['numeric']
# danceability                 Double     ['numeric']
# dyn_range_mean               Double     ['numeric']
# energy                       Double     ['numeric']
# flatness                     Double     ['numeric']
# instrumentalness             Double     ['numeric']
# liveness                     Double     ['numeric']
# loudness                     Double     ['numeric']
# mechanism                    Double     ['numeric']
# organism                     Double     ['numeric']
# speechiness                  Double     ['numeric']
# tempo                        Double     ['numeric']
# valence                      Double     ['numeric']
# acoustic_vector_0            Double     ['numeric']
# acoustic_vector_1            Double     ['numeric']
# acoustic_vector_2            Double     ['numeric']
# acoustic_vector_3            Double     ['numeric']
# acoustic_vector_4            Double     ['numeric']
# acoustic_vector_5            Double     ['numeric']
# acoustic_vector_6            Double     ['numeric']
# acoustic_vector_7            Double     ['numeric']
# key_0                       Integer     ['numeric']
# key_1                       Integer     ['numeric']
# key_2                       Integer     ['numeric']
# key_3                       Integer     ['numeric']
# key_4                       Integer     ['numeric']
# key_5                       Integer     ['numeric']
# key_6                       Integer     ['numeric']
# key_7                       Integer     ['numeric']
# key_8                       Integer     ['numeric']
# key_9                       Integer     ['numeric']
# key_10                      Integer     ['numeric']
# key_11                      Integer     ['numeric']
# time_signature_0            Integer     ['numeric']
# time_signature_1            Integer     ['numeric']
# time_signature_3            Integer     ['numeric']
# time_signature_4            Integer     ['numeric']
# time_signature_5            Integer     ['numeric']
# mode_major                  Integer     ['numeric']
# mode_minor                  Integer     ['numeric']

# %%
# add dataframe
# the 'session_position' contains order information within each session

es = es.add_dataframe(
    dataframe_name="log", dataframe=log_df_dummy2, make_index = True, index="event_id", time_index="session_position",
)

es
# Out:
# Entityset: spotify_data
#   DataFrames:
#     tf [Rows: 50704, Columns: 46]
#     log [Rows: 167880, Columns: 36]
#   Relationships:
#     No relationships

# %%
es['log'].ww.schema
# Out:
#                                            Logical Type  \
# Column
# event_id                                        Integer
# session_id                                  Categorical
# session_position                                Integer
# track_id_clean                                  Unknown
# skip_1                                          Boolean
# skip_2                                          Boolean
# skip_3                                          Boolean
# not_skipped                                     Boolean
# context_switch                                  Integer
# no_pause_before_play                            Integer
# short_pause_before_play                         Integer
# long_pause_before_play                          Integer
# hist_user_behavior_is_shuffle                   Boolean
# hour_of_day                                     Integer
# date                                           Datetime
# premium                                         Boolean
# hist_user_behavior_reason_start_appload         Integer
# hist_user_behavior_reason_start_backbtn         Integer
# hist_user_behavior_reason_start_clickrow        Integer
# hist_user_behavior_reason_start_endplay         Integer
# hist_user_behavior_reason_start_fwdbtn          Integer
# hist_user_behavior_reason_start_playbtn         Integer
# hist_user_behavior_reason_start_remote          Integer
# hist_user_behavior_reason_start_trackdone       Integer
# hist_user_behavior_reason_start_trackerror      Integer
# context_type_catalog                            Integer
# context_type_charts                             Integer
# context_type_editorial_playlist                 Integer
# context_type_personalized_playlist              Integer
# context_type_radio                              Integer
# context_type_user_collection                    Integer
# session_id_skip_2_False                     Categorical
# session_id_skip_2_True                      Categorical
# euc_dist_all                                     Double
# cos_dist_all                                     Double
# man_dist_all                                     Double
#
#                                                       Semantic Tag(s)
# Column
# event_id                                                    ['index']
# session_id                                               ['category']
# session_position                            ['numeric', 'time_index']
# track_id_clean                                                     []
# skip_1                                                             []
# skip_2                                                             []
# skip_3                                                             []
# not_skipped                                                        []
# context_switch                                            ['numeric']
# no_pause_before_play                                      ['numeric']
# short_pause_before_play                                   ['numeric']
# long_pause_before_play                                    ['numeric']
# hist_user_behavior_is_shuffle                                      []
# hour_of_day                                               ['numeric']
# date                                                               []
# premium                                                            []
# hist_user_behavior_reason_start_appload                   ['numeric']
# hist_user_behavior_reason_start_backbtn                   ['numeric']
# hist_user_behavior_reason_start_clickrow                  ['numeric']
# hist_user_behavior_reason_start_endplay                   ['numeric']
# hist_user_behavior_reason_start_fwdbtn                    ['numeric']
# hist_user_behavior_reason_start_playbtn                   ['numeric']
# hist_user_behavior_reason_start_remote                    ['numeric']
# hist_user_behavior_reason_start_trackdone                 ['numeric']
# hist_user_behavior_reason_start_trackerror                ['numeric']
# context_type_catalog                                      ['numeric']
# context_type_charts                                       ['numeric']
# context_type_editorial_playlist                           ['numeric']
# context_type_personalized_playlist                        ['numeric']
# context_type_radio                                        ['numeric']
# context_type_user_collection                              ['numeric']
# session_id_skip_2_False                                  ['category']
# session_id_skip_2_True                                   ['category']
# euc_dist_all                                              ['numeric']
# cos_dist_all                                              ['numeric']
# man_dist_all                                              ['numeric']

# %%
# When two DataFrames have a one-to-many relationship, we call the “one” DataFrame, the “parent DataFrame”. A relationship between a parent and child is defined like this:
# (parent_dataframe, parent_column, child_dataframe, child_column)
es = es.add_relationship("tf", "track_id", "log", "track_id_clean")
es
# Out:
# Entityset: spotify_data
#   DataFrames:
#     tf [Rows: 50704, Columns: 46]
#     log [Rows: 167880, Columns: 36]
#   Relationships:
#     log.track_id_clean -> tf.track_id

# %%
# turn on "features_only = True" to experiment with the function without computing the feature_matrix

# primi_parameters = {
#     "include_groupby_columns":{"log": ["session_id","session_id_skip_1_False","session_id_skip_1_True","session_id_not_skipped_True","session_id_not_skipped_False"]},
#     "ignore_groupby_dataframes": ["tf"],
#     "ignore_columns": {"log":["context_type_catalog","context_type_charts","context_type_editorial_playlist","context_type_personalized_playlist","context_type_radio","context_type_user_collection","hour_of_day","date"]}
#                    }


primi_parameters = {
    "include_groupby_columns":{"log": ["session_id","session_id_skip_2_False","session_id_skip_2_True"]},
    "ignore_groupby_dataframes": ["tf"],
    "ignore_columns": {"log":["context_type_catalog","context_type_charts","context_type_editorial_playlist","context_type_personalized_playlist","context_type_radio","context_type_user_collection","hour_of_day","date","session_position"]}
                   }
primi_parameters
# Out:
# {'include_groupby_columns': {'log': ['session_id',
#    'session_id_skip_2_False',
#    'session_id_skip_2_True']},
#  'ignore_groupby_dataframes': ['tf'],
#  'ignore_columns': {'log': ['context_type_catalog',
#    'context_type_charts',
#    'context_type_editorial_playlist',
#    'context_type_personalized_playlist',
#    'context_type_radio',
#    'context_type_user_collection',
#    'hour_of_day',
#    'date',
#    'session_position']}}

# %%
# a few categorical acoustic features do not need to be included into the featuretools

primi_parameters_ignoreCategoricalAcoustic = primi_parameters.copy()

key_cols = [col for col in tf_df_dummy.columns if 'key_' in col]
time_cols = [col for col in tf_df_dummy.columns if 'time_signature_' in col]

primi_parameters_ignoreCategoricalAcoustic['ignore_columns']['tf'] = key_cols+time_cols
primi_parameters_ignoreCategoricalAcoustic
# Out:
# {'include_groupby_columns': {'log': ['session_id',
#    'session_id_skip_2_False',
#    'session_id_skip_2_True']},
#  'ignore_groupby_dataframes': ['tf'],
#  'ignore_columns': {'log': ['context_type_catalog',
#    'context_type_charts',
#    'context_type_editorial_playlist',
#    'context_type_personalized_playlist',
#    'context_type_radio',
#    'context_type_user_collection',
#    'hour_of_day',
#    'date',
#    'session_position'],
#   'tf': ['key_0',
#    'key_1',
#    'key_2',
#    'key_3',
#    'key_4',
#    'key_5',
#    'key_6',
#    'key_7',
#    'key_8',
#    'key_9',
#    'key_10',
#    'key_11',
#    'time_signature_0',
#    'time_signature_1',
#    'time_signature_3',
#    'time_signature_4',
#    'time_signature_5']}}

# %%
feature_defs_test = ft.dfs(entityset=es,
                        target_dataframe_name="log",
                        groupby_trans_primitives=["Diff","CumSum", "CumMean", "CumMin", "CumMax"],
                        agg_primitives=[],
                        trans_primitives=[],
                        primitive_options={"diff": primi_parameters,
                                           "cum_sum": primi_parameters,
                                           "cum_mean": primi_parameters,
                                           "cum_min": primi_parameters_ignoreCategoricalAcoustic,
                                           "cum_max": primi_parameters_ignoreCategoricalAcoustic
                                          },
                        features_only = True,
                        n_jobs=-1)


feature_defs_test
# Out:
# [<Feature: session_id>,
#  <Feature: session_position>,
#  <Feature: skip_1>,
#  <Feature: skip_2>,
#  <Feature: skip_3>,
#  <Feature: not_skipped>,
#  <Feature: context_switch>,
#  <Feature: no_pause_before_play>,
#  <Feature: short_pause_before_play>,
#  <Feature: long_pause_before_play>,
#  <Feature: hist_user_behavior_is_shuffle>,
#  <Feature: hour_of_day>,
#  <Feature: premium>,
#  <Feature: hist_user_behavior_reason_start_appload>,
#  <Feature: hist_user_behavior_reason_start_backbtn>,
#  <Feature: hist_user_behavior_reason_start_clickrow>,
#  <Feature: hist_user_behavior_reason_start_endplay>,
#  <Feature: hist_user_behavior_reason_start_fwdbtn>,
#  <Feature: hist_user_behavior_reason_start_playbtn>,
#  <Feature: hist_user_behavior_reason_start_remote>,
#  <Feature: hist_user_behavior_reason_start_trackdone>,
#  <Feature: hist_user_behavior_reason_start_trackerror>,
#  <Feature: context_type_catalog>,
#  <Feature: context_type_charts>,
#  <Feature: context_type_editorial_playlist>,
#  <Feature: context_type_personalized_playlist>,
#  <Feature: context_type_radio>,
#  <Feature: context_type_user_collection>,
#  <Feature: session_id_skip_2_False>,
#  <Feature: session_id_skip_2_True>,
#  <Feature: euc_dist_all>,
#  <Feature: cos_dist_all>,
#  <Feature: man_dist_all>,
#  <Feature: CUM_MAX(context_switch) by session_id>,
#  <Feature: CUM_MAX(context_switch) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(context_switch) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(cos_dist_all) by session_id>,
#  <Feature: CUM_MAX(cos_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(cos_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(euc_dist_all) by session_id>,
#  <Feature: CUM_MAX(euc_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(euc_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_appload) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_appload) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_appload) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_backbtn) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_backbtn) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_backbtn) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_clickrow) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_clickrow) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_clickrow) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_endplay) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_endplay) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_endplay) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_fwdbtn) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_playbtn) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_playbtn) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_playbtn) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_remote) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_remote) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_remote) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_trackdone) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_trackdone) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_trackdone) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_trackerror) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_trackerror) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_trackerror) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(long_pause_before_play) by session_id>,
#  <Feature: CUM_MAX(long_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(long_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(man_dist_all) by session_id>,
#  <Feature: CUM_MAX(man_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(man_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(no_pause_before_play) by session_id>,
#  <Feature: CUM_MAX(no_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(no_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(short_pause_before_play) by session_id>,
#  <Feature: CUM_MAX(short_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(short_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(context_switch) by session_id>,
#  <Feature: CUM_MEAN(context_switch) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(context_switch) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(cos_dist_all) by session_id>,
#  <Feature: CUM_MEAN(cos_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(cos_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(euc_dist_all) by session_id>,
#  <Feature: CUM_MEAN(euc_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(euc_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_appload) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_appload) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_appload) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_backbtn) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_backbtn) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_backbtn) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_clickrow) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_clickrow) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_clickrow) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_endplay) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_endplay) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_endplay) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_fwdbtn) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_playbtn) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_playbtn) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_playbtn) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_remote) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_remote) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_remote) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_trackdone) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_trackdone) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_trackdone) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_trackerror) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_trackerror) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_trackerror) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(long_pause_before_play) by session_id>,
#  <Feature: CUM_MEAN(long_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(long_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(man_dist_all) by session_id>,
#  <Feature: CUM_MEAN(man_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(man_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(no_pause_before_play) by session_id>,
#  <Feature: CUM_MEAN(no_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(no_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(short_pause_before_play) by session_id>,
#  <Feature: CUM_MEAN(short_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(short_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(context_switch) by session_id>,
#  <Feature: CUM_MIN(context_switch) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(context_switch) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(cos_dist_all) by session_id>,
#  <Feature: CUM_MIN(cos_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(cos_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(euc_dist_all) by session_id>,
#  <Feature: CUM_MIN(euc_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(euc_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_appload) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_appload) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_appload) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_backbtn) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_backbtn) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_backbtn) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_clickrow) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_clickrow) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_clickrow) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_endplay) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_endplay) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_endplay) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_fwdbtn) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_playbtn) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_playbtn) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_playbtn) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_remote) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_remote) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_remote) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_trackdone) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_trackdone) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_trackdone) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_trackerror) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_trackerror) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_trackerror) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(long_pause_before_play) by session_id>,
#  <Feature: CUM_MIN(long_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(long_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(man_dist_all) by session_id>,
#  <Feature: CUM_MIN(man_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(man_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(no_pause_before_play) by session_id>,
#  <Feature: CUM_MIN(no_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(no_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(short_pause_before_play) by session_id>,
#  <Feature: CUM_MIN(short_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(short_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(context_switch) by session_id>,
#  <Feature: CUM_SUM(context_switch) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(context_switch) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(cos_dist_all) by session_id>,
#  <Feature: CUM_SUM(cos_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(cos_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(euc_dist_all) by session_id>,
#  <Feature: CUM_SUM(euc_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(euc_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_appload) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_appload) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_appload) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_backbtn) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_backbtn) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_backbtn) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_clickrow) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_clickrow) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_clickrow) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_endplay) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_endplay) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_endplay) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_fwdbtn) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_playbtn) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_playbtn) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_playbtn) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_remote) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_remote) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_remote) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_trackdone) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_trackdone) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_trackdone) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_trackerror) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_trackerror) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_trackerror) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(long_pause_before_play) by session_id>,
#  <Feature: CUM_SUM(long_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(long_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(man_dist_all) by session_id>,
#  <Feature: CUM_SUM(man_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(man_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(no_pause_before_play) by session_id>,
#  <Feature: CUM_SUM(no_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(no_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(short_pause_before_play) by session_id>,
#  <Feature: CUM_SUM(short_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(short_pause_before_play) by session_id_skip_2_True>,
#  <Feature: DIFF(context_switch) by session_id>,
#  <Feature: DIFF(context_switch) by session_id_skip_2_False>,
#  <Feature: DIFF(context_switch) by session_id_skip_2_True>,
#  <Feature: DIFF(cos_dist_all) by session_id>,
#  <Feature: DIFF(cos_dist_all) by session_id_skip_2_False>,
#  <Feature: DIFF(cos_dist_all) by session_id_skip_2_True>,
#  <Feature: DIFF(euc_dist_all) by session_id>,
#  <Feature: DIFF(euc_dist_all) by session_id_skip_2_False>,
#  <Feature: DIFF(euc_dist_all) by session_id_skip_2_True>,
#  <Feature: DIFF(hist_user_behavior_reason_start_appload) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_appload) by session_id_skip_2_False>,
#  <Feature: DIFF(hist_user_behavior_reason_start_appload) by session_id_skip_2_True>,
#  <Feature: DIFF(hist_user_behavior_reason_start_backbtn) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_backbtn) by session_id_skip_2_False>,
#  <Feature: DIFF(hist_user_behavior_reason_start_backbtn) by session_id_skip_2_True>,
#  <Feature: DIFF(hist_user_behavior_reason_start_clickrow) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_clickrow) by session_id_skip_2_False>,
#  <Feature: DIFF(hist_user_behavior_reason_start_clickrow) by session_id_skip_2_True>,
#  <Feature: DIFF(hist_user_behavior_reason_start_endplay) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_endplay) by session_id_skip_2_False>,
#  <Feature: DIFF(hist_user_behavior_reason_start_endplay) by session_id_skip_2_True>,
#  <Feature: DIFF(hist_user_behavior_reason_start_fwdbtn) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_2_False>,
#  <Feature: DIFF(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_2_True>,
#  <Feature: DIFF(hist_user_behavior_reason_start_playbtn) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_playbtn) by session_id_skip_2_False>,
#  <Feature: DIFF(hist_user_behavior_reason_start_playbtn) by session_id_skip_2_True>,
#  <Feature: DIFF(hist_user_behavior_reason_start_remote) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_remote) by session_id_skip_2_False>,
#  <Feature: DIFF(hist_user_behavior_reason_start_remote) by session_id_skip_2_True>,
#  <Feature: DIFF(hist_user_behavior_reason_start_trackdone) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_trackdone) by session_id_skip_2_False>,
#  <Feature: DIFF(hist_user_behavior_reason_start_trackdone) by session_id_skip_2_True>,
#  <Feature: DIFF(hist_user_behavior_reason_start_trackerror) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_trackerror) by session_id_skip_2_False>,
#  <Feature: DIFF(hist_user_behavior_reason_start_trackerror) by session_id_skip_2_True>,
#  <Feature: DIFF(long_pause_before_play) by session_id>,
#  <Feature: DIFF(long_pause_before_play) by session_id_skip_2_False>,
#  <Feature: DIFF(long_pause_before_play) by session_id_skip_2_True>,
#  <Feature: DIFF(man_dist_all) by session_id>,
#  <Feature: DIFF(man_dist_all) by session_id_skip_2_False>,
#  <Feature: DIFF(man_dist_all) by session_id_skip_2_True>,
#  <Feature: DIFF(no_pause_before_play) by session_id>,
#  <Feature: DIFF(no_pause_before_play) by session_id_skip_2_False>,
#  <Feature: DIFF(no_pause_before_play) by session_id_skip_2_True>,
#  <Feature: DIFF(short_pause_before_play) by session_id>,
#  <Feature: DIFF(short_pause_before_play) by session_id_skip_2_False>,
#  <Feature: DIFF(short_pause_before_play) by session_id_skip_2_True>,
#  <Feature: tf.duration>,
#  <Feature: tf.release_year>,
#  <Feature: tf.us_popularity_estimate>,
#  <Feature: tf.acousticness>,
#  <Feature: tf.beat_strength>,
#  <Feature: tf.bounciness>,
#  <Feature: tf.danceability>,
#  <Feature: tf.dyn_range_mean>,
#  <Feature: tf.energy>,
#  <Feature: tf.flatness>,
#  <Feature: tf.instrumentalness>,
#  <Feature: tf.liveness>,
#  <Feature: tf.loudness>,
#  <Feature: tf.mechanism>,
#  <Feature: tf.organism>,
#  <Feature: tf.speechiness>,
#  <Feature: tf.tempo>,
#  <Feature: tf.valence>,
#  <Feature: tf.acoustic_vector_0>,
#  <Feature: tf.acoustic_vector_1>,
#  <Feature: tf.acoustic_vector_2>,
#  <Feature: tf.acoustic_vector_3>,
#  <Feature: tf.acoustic_vector_4>,
#  <Feature: tf.acoustic_vector_5>,
#  <Feature: tf.acoustic_vector_6>,
#  <Feature: tf.acoustic_vector_7>,
#  <Feature: tf.key_0>,
#  <Feature: tf.key_1>,
#  <Feature: tf.key_2>,
#  <Feature: tf.key_3>,
#  <Feature: tf.key_4>,
#  <Feature: tf.key_5>,
#  <Feature: tf.key_6>,
#  <Feature: tf.key_7>,
#  <Feature: tf.key_8>,
#  <Feature: tf.key_9>,
#  <Feature: tf.key_10>,
#  <Feature: tf.key_11>,
#  <Feature: tf.time_signature_0>,
#  <Feature: tf.time_signature_1>,
#  <Feature: tf.time_signature_3>,
#  <Feature: tf.time_signature_4>,
#  <Feature: tf.time_signature_5>,
#  <Feature: tf.mode_major>,
#  <Feature: tf.mode_minor>,
#  <Feature: CUM_MAX(tf.acoustic_vector_0) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_0) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.acoustic_vector_0) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.acoustic_vector_1) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_1) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.acoustic_vector_1) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.acoustic_vector_2) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_2) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.acoustic_vector_2) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.acoustic_vector_3) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_3) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.acoustic_vector_3) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.acoustic_vector_4) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_4) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.acoustic_vector_4) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.acoustic_vector_5) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_5) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.acoustic_vector_5) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.acoustic_vector_6) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_6) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.acoustic_vector_6) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.acoustic_vector_7) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_7) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.acoustic_vector_7) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.acousticness) by session_id>,
#  <Feature: CUM_MAX(tf.acousticness) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.acousticness) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.beat_strength) by session_id>,
#  <Feature: CUM_MAX(tf.beat_strength) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.beat_strength) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.bounciness) by session_id>,
#  <Feature: CUM_MAX(tf.bounciness) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.bounciness) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.danceability) by session_id>,
#  <Feature: CUM_MAX(tf.danceability) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.danceability) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.duration) by session_id>,
#  <Feature: CUM_MAX(tf.duration) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.duration) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.dyn_range_mean) by session_id>,
#  <Feature: CUM_MAX(tf.dyn_range_mean) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.dyn_range_mean) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.energy) by session_id>,
#  <Feature: CUM_MAX(tf.energy) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.energy) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.flatness) by session_id>,
#  <Feature: CUM_MAX(tf.flatness) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.flatness) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.instrumentalness) by session_id>,
#  <Feature: CUM_MAX(tf.instrumentalness) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.instrumentalness) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.liveness) by session_id>,
#  <Feature: CUM_MAX(tf.liveness) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.liveness) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.loudness) by session_id>,
#  <Feature: CUM_MAX(tf.loudness) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.loudness) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.mechanism) by session_id>,
#  <Feature: CUM_MAX(tf.mechanism) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.mechanism) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.mode_major) by session_id>,
#  <Feature: CUM_MAX(tf.mode_major) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.mode_major) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.mode_minor) by session_id>,
#  <Feature: CUM_MAX(tf.mode_minor) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.mode_minor) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.organism) by session_id>,
#  <Feature: CUM_MAX(tf.organism) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.organism) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.release_year) by session_id>,
#  <Feature: CUM_MAX(tf.release_year) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.release_year) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.speechiness) by session_id>,
#  <Feature: CUM_MAX(tf.speechiness) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.speechiness) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.tempo) by session_id>,
#  <Feature: CUM_MAX(tf.tempo) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.tempo) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.us_popularity_estimate) by session_id>,
#  <Feature: CUM_MAX(tf.us_popularity_estimate) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.us_popularity_estimate) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.valence) by session_id>,
#  <Feature: CUM_MAX(tf.valence) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.valence) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_0) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_0) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_0) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_1) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_1) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_1) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_2) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_2) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_2) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_3) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_3) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_3) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_4) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_4) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_4) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_5) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_5) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_5) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_6) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_6) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_6) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_7) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_7) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_7) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.acousticness) by session_id>,
#  <Feature: CUM_MEAN(tf.acousticness) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.acousticness) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.beat_strength) by session_id>,
#  <Feature: CUM_MEAN(tf.beat_strength) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.beat_strength) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.bounciness) by session_id>,
#  <Feature: CUM_MEAN(tf.bounciness) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.bounciness) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.danceability) by session_id>,
#  <Feature: CUM_MEAN(tf.danceability) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.danceability) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.duration) by session_id>,
#  <Feature: CUM_MEAN(tf.duration) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.duration) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.dyn_range_mean) by session_id>,
#  <Feature: CUM_MEAN(tf.dyn_range_mean) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.dyn_range_mean) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.energy) by session_id>,
#  <Feature: CUM_MEAN(tf.energy) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.energy) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.flatness) by session_id>,
#  <Feature: CUM_MEAN(tf.flatness) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.flatness) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.instrumentalness) by session_id>,
#  <Feature: CUM_MEAN(tf.instrumentalness) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.instrumentalness) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.liveness) by session_id>,
#  <Feature: CUM_MEAN(tf.liveness) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.liveness) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.loudness) by session_id>,
#  <Feature: CUM_MEAN(tf.loudness) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.loudness) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.mechanism) by session_id>,
#  <Feature: CUM_MEAN(tf.mechanism) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.mechanism) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.mode_major) by session_id>,
#  <Feature: CUM_MEAN(tf.mode_major) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.mode_major) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.mode_minor) by session_id>,
#  <Feature: CUM_MEAN(tf.mode_minor) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.mode_minor) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.organism) by session_id>,
#  <Feature: CUM_MEAN(tf.organism) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.organism) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.release_year) by session_id>,
#  <Feature: CUM_MEAN(tf.release_year) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.release_year) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.speechiness) by session_id>,
#  <Feature: CUM_MEAN(tf.speechiness) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.speechiness) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.tempo) by session_id>,
#  <Feature: CUM_MEAN(tf.tempo) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.tempo) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.us_popularity_estimate) by session_id>,
#  <Feature: CUM_MEAN(tf.us_popularity_estimate) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.us_popularity_estimate) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.valence) by session_id>,
#  <Feature: CUM_MEAN(tf.valence) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.valence) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.acoustic_vector_0) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_0) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.acoustic_vector_0) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.acoustic_vector_1) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_1) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.acoustic_vector_1) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.acoustic_vector_2) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_2) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.acoustic_vector_2) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.acoustic_vector_3) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_3) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.acoustic_vector_3) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.acoustic_vector_4) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_4) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.acoustic_vector_4) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.acoustic_vector_5) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_5) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.acoustic_vector_5) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.acoustic_vector_6) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_6) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.acoustic_vector_6) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.acoustic_vector_7) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_7) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.acoustic_vector_7) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.acousticness) by session_id>,
#  <Feature: CUM_MIN(tf.acousticness) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.acousticness) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.beat_strength) by session_id>,
#  <Feature: CUM_MIN(tf.beat_strength) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.beat_strength) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.bounciness) by session_id>,
#  <Feature: CUM_MIN(tf.bounciness) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.bounciness) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.danceability) by session_id>,
#  <Feature: CUM_MIN(tf.danceability) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.danceability) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.duration) by session_id>,
#  <Feature: CUM_MIN(tf.duration) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.duration) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.dyn_range_mean) by session_id>,
#  <Feature: CUM_MIN(tf.dyn_range_mean) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.dyn_range_mean) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.energy) by session_id>,
#  <Feature: CUM_MIN(tf.energy) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.energy) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.flatness) by session_id>,
#  <Feature: CUM_MIN(tf.flatness) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.flatness) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.instrumentalness) by session_id>,
#  <Feature: CUM_MIN(tf.instrumentalness) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.instrumentalness) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.liveness) by session_id>,
#  <Feature: CUM_MIN(tf.liveness) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.liveness) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.loudness) by session_id>,
#  <Feature: CUM_MIN(tf.loudness) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.loudness) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.mechanism) by session_id>,
#  <Feature: CUM_MIN(tf.mechanism) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.mechanism) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.mode_major) by session_id>,
#  <Feature: CUM_MIN(tf.mode_major) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.mode_major) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.mode_minor) by session_id>,
#  <Feature: CUM_MIN(tf.mode_minor) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.mode_minor) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.organism) by session_id>,
#  <Feature: CUM_MIN(tf.organism) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.organism) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.release_year) by session_id>,
#  <Feature: CUM_MIN(tf.release_year) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.release_year) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.speechiness) by session_id>,
#  <Feature: CUM_MIN(tf.speechiness) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.speechiness) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.tempo) by session_id>,
#  <Feature: CUM_MIN(tf.tempo) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.tempo) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.us_popularity_estimate) by session_id>,
#  <Feature: CUM_MIN(tf.us_popularity_estimate) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.us_popularity_estimate) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.valence) by session_id>,
#  <Feature: CUM_MIN(tf.valence) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.valence) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.acoustic_vector_0) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_0) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.acoustic_vector_0) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.acoustic_vector_1) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_1) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.acoustic_vector_1) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.acoustic_vector_2) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_2) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.acoustic_vector_2) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.acoustic_vector_3) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_3) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.acoustic_vector_3) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.acoustic_vector_4) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_4) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.acoustic_vector_4) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.acoustic_vector_5) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_5) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.acoustic_vector_5) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.acoustic_vector_6) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_6) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.acoustic_vector_6) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.acoustic_vector_7) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_7) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.acoustic_vector_7) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.acousticness) by session_id>,
#  <Feature: CUM_SUM(tf.acousticness) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.acousticness) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.beat_strength) by session_id>,
#  <Feature: CUM_SUM(tf.beat_strength) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.beat_strength) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.bounciness) by session_id>,
#  <Feature: CUM_SUM(tf.bounciness) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.bounciness) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.danceability) by session_id>,
#  <Feature: CUM_SUM(tf.danceability) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.danceability) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.duration) by session_id>,
#  <Feature: CUM_SUM(tf.duration) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.duration) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.dyn_range_mean) by session_id>,
#  <Feature: CUM_SUM(tf.dyn_range_mean) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.dyn_range_mean) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.energy) by session_id>,
#  <Feature: CUM_SUM(tf.energy) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.energy) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.flatness) by session_id>,
#  <Feature: CUM_SUM(tf.flatness) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.flatness) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.instrumentalness) by session_id>,
#  <Feature: CUM_SUM(tf.instrumentalness) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.instrumentalness) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.liveness) by session_id>,
#  <Feature: CUM_SUM(tf.liveness) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.liveness) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.loudness) by session_id>,
#  <Feature: CUM_SUM(tf.loudness) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.loudness) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.mechanism) by session_id>,
#  <Feature: CUM_SUM(tf.mechanism) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.mechanism) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.mode_major) by session_id>,
#  <Feature: CUM_SUM(tf.mode_major) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.mode_major) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.mode_minor) by session_id>,
#  <Feature: CUM_SUM(tf.mode_minor) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.mode_minor) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.organism) by session_id>,
#  <Feature: CUM_SUM(tf.organism) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.organism) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.release_year) by session_id>,
#  <Feature: CUM_SUM(tf.release_year) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.release_year) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.speechiness) by session_id>,
#  <Feature: CUM_SUM(tf.speechiness) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.speechiness) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.tempo) by session_id>,
#  <Feature: CUM_SUM(tf.tempo) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.tempo) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.us_popularity_estimate) by session_id>,
#  <Feature: CUM_SUM(tf.us_popularity_estimate) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.us_popularity_estimate) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.valence) by session_id>,
#  <Feature: CUM_SUM(tf.valence) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.valence) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.acoustic_vector_0) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_0) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.acoustic_vector_0) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.acoustic_vector_1) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_1) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.acoustic_vector_1) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.acoustic_vector_2) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_2) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.acoustic_vector_2) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.acoustic_vector_3) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_3) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.acoustic_vector_3) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.acoustic_vector_4) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_4) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.acoustic_vector_4) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.acoustic_vector_5) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_5) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.acoustic_vector_5) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.acoustic_vector_6) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_6) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.acoustic_vector_6) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.acoustic_vector_7) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_7) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.acoustic_vector_7) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.acousticness) by session_id>,
#  <Feature: DIFF(tf.acousticness) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.acousticness) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.beat_strength) by session_id>,
#  <Feature: DIFF(tf.beat_strength) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.beat_strength) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.bounciness) by session_id>,
#  <Feature: DIFF(tf.bounciness) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.bounciness) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.danceability) by session_id>,
#  <Feature: DIFF(tf.danceability) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.danceability) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.duration) by session_id>,
#  <Feature: DIFF(tf.duration) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.duration) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.dyn_range_mean) by session_id>,
#  <Feature: DIFF(tf.dyn_range_mean) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.dyn_range_mean) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.energy) by session_id>,
#  <Feature: DIFF(tf.energy) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.energy) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.flatness) by session_id>,
#  <Feature: DIFF(tf.flatness) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.flatness) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.instrumentalness) by session_id>,
#  <Feature: DIFF(tf.instrumentalness) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.instrumentalness) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.liveness) by session_id>,
#  <Feature: DIFF(tf.liveness) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.liveness) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.loudness) by session_id>,
#  <Feature: DIFF(tf.loudness) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.loudness) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.mechanism) by session_id>,
#  <Feature: DIFF(tf.mechanism) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.mechanism) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.mode_major) by session_id>,
#  <Feature: DIFF(tf.mode_major) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.mode_major) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.mode_minor) by session_id>,
#  <Feature: DIFF(tf.mode_minor) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.mode_minor) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.organism) by session_id>,
#  <Feature: DIFF(tf.organism) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.organism) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.release_year) by session_id>,
#  <Feature: DIFF(tf.release_year) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.release_year) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.speechiness) by session_id>,
#  <Feature: DIFF(tf.speechiness) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.speechiness) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.tempo) by session_id>,
#  <Feature: DIFF(tf.tempo) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.tempo) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.us_popularity_estimate) by session_id>,
#  <Feature: DIFF(tf.us_popularity_estimate) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.us_popularity_estimate) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.valence) by session_id>,
#  <Feature: DIFF(tf.valence) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.valence) by session_id_skip_2_True>]

# %%
len(feature_defs_test)
# Out:
# 738

# %%
import warnings
def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
#warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# %%
# check this for specifying groupby: https://featuretools.alteryx.com/en/stable/guides/specifying_primitive_options.html
# The 'session_id' was specified as GroupBy option as we care what happend in each session.
# The tf (track inforamtion) dataframe does not contain any order or session information, so it does not be be specified as GroupBy option.

#warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
# warnings.simplefilter("ignore")


start_time = time.time()

feature_matrix, feature_defs = ft.dfs(entityset=es,
                        target_dataframe_name="log",
                        groupby_trans_primitives=["Diff","CumSum", "CumMean", "CumMin", "CumMax"],
                        agg_primitives=[],
                        trans_primitives=[],
                        primitive_options={"diff": primi_parameters,
                                           "cum_sum": primi_parameters,
                                           "cum_mean": primi_parameters,
                                           "cum_min": primi_parameters_ignoreCategoricalAcoustic,
                                           "cum_max": primi_parameters_ignoreCategoricalAcoustic
                                          },
                        features_only = False,
                        n_jobs=5) # 8 cores will be very slow...

print('***It takes ',(time.time() - start_time)/60, ' minutes.***')

# save feature matrix
feature_matrix.to_csv('../data/processed/feature_matrix_skip2_TF.csv')
# Out:
# EntitySet scattered to 5 workers in 7 seconds
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# ...
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# /Users/andrewchang/opt/anaconda3/envs/Springboard_DS_2022/lib/python3.8/site-packages/featuretools/computational_backends/feature_set_calculator.py:921: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[name] = f.default_value
# ***It takes  37.16111546754837  minutes.***

# %%
feature_matrix
# Out:
#                                       session_id  session_position  skip_1  \
# event_id
# 0         0_00006f66-33e5-4de7-a324-2d18e439fc1e                 1   False
# 20        0_0000a72b-09ac-412f-b452-9b9e79bded8f                 1   False
# 40        0_00010fc5-b79e-4cdf-bc4c-f140d0f99a3a                 1   False
# 60        0_00016a3d-9076-4f67-918f-f29e3ce160dc                 1    True
# 80        0_00018b58-deb8-4f98-ac5e-d7e01b346130                 1   False
# ...                                          ...               ...     ...
# 167773    0_0eab7430-d291-4d57-9c92-ac7cb682f2c6                20   False
# 167807    0_0eac164c-f209-4590-8608-a56e67658952                20   False
# 167827    0_0eacbee7-9868-48a0-9ab0-f86069329f50                20    True
# 167847    0_0ead11fc-f32c-4eb4-8fc1-15b51432a404                20    True
# 167879    0_0eaeef5d-25e9-4429-bd55-af15d3604c9f                20   False
#
#           skip_2  skip_3  not_skipped  context_switch  no_pause_before_play  \
# event_id
# 0          False   False         True               0                     0
# 20          True    True        False               0                     0
# 40         False    True        False               0                     0
# 60          True    True        False               0                     0
# 80         False    True        False               0                     0
# ...          ...     ...          ...             ...                   ...
# 167773     False   False         True               0                     1
# 167807     False    True        False               0                     1
# 167827      True    True        False               0                     1
# 167847      True    True        False               0                     0
# 167879     False   False         True               0                     1
#
#           short_pause_before_play  long_pause_before_play  ...  \
# event_id                                                   ...
# 0                               0                       0  ...
# 20                              0                       0  ...
# 40                              0                       0  ...
# 60                              0                       0  ...
# 80                              0                       0  ...
# ...                           ...                     ...  ...
# 167773                          0                       0  ...
# 167807                          0                       0  ...
# 167827                          0                       0  ...
# 167847                          1                       1  ...
# 167879                          0                       0  ...
#
#           DIFF(tf.speechiness) by session_id_skip_2_True  \
# event_id
# 0                                                    NaN
# 20                                                   NaN
# 40                                              0.460207
# 60                                                   NaN
# 80                                             -0.499567
# ...                                                  ...
# 167773                                          0.613955
# 167807                                         -0.851562
# 167827                                         -0.105432
# 167847                                          0.130020
# 167879                                          0.022904
#
#           DIFF(tf.tempo) by session_id  \
# event_id
# 0                                  NaN
# 20                                 NaN
# 40                                 NaN
# 60                                 NaN
# 80                                 NaN
# ...                                ...
# 167773                       15.776001
# 167807                       14.338005
# 167827                       15.980011
# 167847                       -1.011002
# 167879                       13.552994
#
#           DIFF(tf.tempo) by session_id_skip_2_False  \
# event_id
# 0                                               NaN
# 20                                              NaN
# 40                                              NaN
# 60                                        40.448997
# 80                                              NaN
# ...                                             ...
# 167773                                    15.776001
# 167807                                    14.338005
# 167827                                    43.247002
# 167847                                    -0.012009
# 167879                                    13.552994
#
#           DIFF(tf.tempo) by session_id_skip_2_True  \
# event_id
# 0                                              NaN
# 20                                             NaN
# 40                                      -14.066994
# 60                                             NaN
# 80                                      -29.920998
# ...                                            ...
# 167773                                   -7.440002
# 167807                                   12.658005
# 167827                                   15.980011
# 167847                                   -1.011002
# 167879                                  -24.003006
#
#           DIFF(tf.us_popularity_estimate) by session_id  \
# event_id
# 0                                                   NaN
# 20                                                  NaN
# 40                                                  NaN
# 60                                                  NaN
# 80                                                  NaN
# ...                                                 ...
# 167773                                        -0.017276
# 167807                                        -0.191419
# 167827                                         0.117369
# 167847                                        -0.205259
# 167879                                        -0.004188
#
#           DIFF(tf.us_popularity_estimate) by session_id_skip_2_False  \
# event_id
# 0                                                       NaN
# 20                                                      NaN
# 40                                                      NaN
# 60                                                 1.123040
# 80                                                      NaN
# ...                                                     ...
# 167773                                            -0.017276
# 167807                                            -0.191419
# 167827                                             0.047437
# 167847                                            -0.202169
# 167879                                            -0.004188
#
#           DIFF(tf.us_popularity_estimate) by session_id_skip_2_True  \
# event_id
# 0                                                       NaN
# 20                                                      NaN
# 40                                                 0.031839
# 60                                                      NaN
# 80                                                -0.426843
# ...                                                     ...
# 167773                                            -0.045441
# 167807                                            -0.113564
# 167827                                             0.117369
# 167847                                            -0.205259
# 167879                                             0.070546
#
#           DIFF(tf.valence) by session_id  \
# event_id
# 0                                    NaN
# 20                                   NaN
# 40                                   NaN
# 60                                   NaN
# 80                                   NaN
# ...                                  ...
# 167773                         -0.149514
# 167807                         -0.126923
# 167827                          0.339712
# 167847                          0.402161
# 167879                         -0.038645
#
#           DIFF(tf.valence) by session_id_skip_2_False  \
# event_id
# 0                                                 NaN
# 20                                                NaN
# 40                                                NaN
# 60                                           0.412382
# 80                                                NaN
# ...                                               ...
# 167773                                      -0.149514
# 167807                                      -0.126923
# 167827                                       0.296191
# 167847                                       0.171030
# 167879                                      -0.038645
#
#           DIFF(tf.valence) by session_id_skip_2_True
# event_id
# 0                                                NaN
# 20                                               NaN
# 40                                          0.409766
# 60                                               NaN
# 80                                         -0.333178
# ...                                              ...
# 167773                                      0.021873
# 167807                                     -0.053299
# 167827                                      0.339712
# 167847                                      0.402161
# 167879                                      0.411960
#
# [167880 rows x 738 columns]

# %%
feature_defs
# Out:
# [<Feature: session_id>,
#  <Feature: session_position>,
#  <Feature: skip_1>,
#  <Feature: skip_2>,
#  <Feature: skip_3>,
#  <Feature: not_skipped>,
#  <Feature: context_switch>,
#  <Feature: no_pause_before_play>,
#  <Feature: short_pause_before_play>,
#  <Feature: long_pause_before_play>,
#  <Feature: hist_user_behavior_is_shuffle>,
#  <Feature: hour_of_day>,
#  <Feature: premium>,
#  <Feature: hist_user_behavior_reason_start_appload>,
#  <Feature: hist_user_behavior_reason_start_backbtn>,
#  <Feature: hist_user_behavior_reason_start_clickrow>,
#  <Feature: hist_user_behavior_reason_start_endplay>,
#  <Feature: hist_user_behavior_reason_start_fwdbtn>,
#  <Feature: hist_user_behavior_reason_start_playbtn>,
#  <Feature: hist_user_behavior_reason_start_remote>,
#  <Feature: hist_user_behavior_reason_start_trackdone>,
#  <Feature: hist_user_behavior_reason_start_trackerror>,
#  <Feature: context_type_catalog>,
#  <Feature: context_type_charts>,
#  <Feature: context_type_editorial_playlist>,
#  <Feature: context_type_personalized_playlist>,
#  <Feature: context_type_radio>,
#  <Feature: context_type_user_collection>,
#  <Feature: session_id_skip_2_False>,
#  <Feature: session_id_skip_2_True>,
#  <Feature: euc_dist_all>,
#  <Feature: cos_dist_all>,
#  <Feature: man_dist_all>,
#  <Feature: CUM_MAX(context_switch) by session_id>,
#  <Feature: CUM_MAX(context_switch) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(context_switch) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(cos_dist_all) by session_id>,
#  <Feature: CUM_MAX(cos_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(cos_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(euc_dist_all) by session_id>,
#  <Feature: CUM_MAX(euc_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(euc_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_appload) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_appload) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_appload) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_backbtn) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_backbtn) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_backbtn) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_clickrow) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_clickrow) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_clickrow) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_endplay) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_endplay) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_endplay) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_fwdbtn) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_playbtn) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_playbtn) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_playbtn) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_remote) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_remote) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_remote) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_trackdone) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_trackdone) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_trackdone) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_trackerror) by session_id>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_trackerror) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(hist_user_behavior_reason_start_trackerror) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(long_pause_before_play) by session_id>,
#  <Feature: CUM_MAX(long_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(long_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(man_dist_all) by session_id>,
#  <Feature: CUM_MAX(man_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(man_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(no_pause_before_play) by session_id>,
#  <Feature: CUM_MAX(no_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(no_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(short_pause_before_play) by session_id>,
#  <Feature: CUM_MAX(short_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(short_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(context_switch) by session_id>,
#  <Feature: CUM_MEAN(context_switch) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(context_switch) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(cos_dist_all) by session_id>,
#  <Feature: CUM_MEAN(cos_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(cos_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(euc_dist_all) by session_id>,
#  <Feature: CUM_MEAN(euc_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(euc_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_appload) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_appload) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_appload) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_backbtn) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_backbtn) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_backbtn) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_clickrow) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_clickrow) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_clickrow) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_endplay) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_endplay) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_endplay) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_fwdbtn) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_playbtn) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_playbtn) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_playbtn) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_remote) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_remote) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_remote) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_trackdone) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_trackdone) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_trackdone) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_trackerror) by session_id>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_trackerror) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(hist_user_behavior_reason_start_trackerror) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(long_pause_before_play) by session_id>,
#  <Feature: CUM_MEAN(long_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(long_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(man_dist_all) by session_id>,
#  <Feature: CUM_MEAN(man_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(man_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(no_pause_before_play) by session_id>,
#  <Feature: CUM_MEAN(no_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(no_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(short_pause_before_play) by session_id>,
#  <Feature: CUM_MEAN(short_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(short_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(context_switch) by session_id>,
#  <Feature: CUM_MIN(context_switch) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(context_switch) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(cos_dist_all) by session_id>,
#  <Feature: CUM_MIN(cos_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(cos_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(euc_dist_all) by session_id>,
#  <Feature: CUM_MIN(euc_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(euc_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_appload) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_appload) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_appload) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_backbtn) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_backbtn) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_backbtn) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_clickrow) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_clickrow) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_clickrow) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_endplay) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_endplay) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_endplay) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_fwdbtn) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_playbtn) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_playbtn) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_playbtn) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_remote) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_remote) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_remote) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_trackdone) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_trackdone) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_trackdone) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_trackerror) by session_id>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_trackerror) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(hist_user_behavior_reason_start_trackerror) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(long_pause_before_play) by session_id>,
#  <Feature: CUM_MIN(long_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(long_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(man_dist_all) by session_id>,
#  <Feature: CUM_MIN(man_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(man_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(no_pause_before_play) by session_id>,
#  <Feature: CUM_MIN(no_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(no_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(short_pause_before_play) by session_id>,
#  <Feature: CUM_MIN(short_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(short_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(context_switch) by session_id>,
#  <Feature: CUM_SUM(context_switch) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(context_switch) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(cos_dist_all) by session_id>,
#  <Feature: CUM_SUM(cos_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(cos_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(euc_dist_all) by session_id>,
#  <Feature: CUM_SUM(euc_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(euc_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_appload) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_appload) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_appload) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_backbtn) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_backbtn) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_backbtn) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_clickrow) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_clickrow) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_clickrow) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_endplay) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_endplay) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_endplay) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_fwdbtn) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_playbtn) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_playbtn) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_playbtn) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_remote) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_remote) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_remote) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_trackdone) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_trackdone) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_trackdone) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_trackerror) by session_id>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_trackerror) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(hist_user_behavior_reason_start_trackerror) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(long_pause_before_play) by session_id>,
#  <Feature: CUM_SUM(long_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(long_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(man_dist_all) by session_id>,
#  <Feature: CUM_SUM(man_dist_all) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(man_dist_all) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(no_pause_before_play) by session_id>,
#  <Feature: CUM_SUM(no_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(no_pause_before_play) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(short_pause_before_play) by session_id>,
#  <Feature: CUM_SUM(short_pause_before_play) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(short_pause_before_play) by session_id_skip_2_True>,
#  <Feature: DIFF(context_switch) by session_id>,
#  <Feature: DIFF(context_switch) by session_id_skip_2_False>,
#  <Feature: DIFF(context_switch) by session_id_skip_2_True>,
#  <Feature: DIFF(cos_dist_all) by session_id>,
#  <Feature: DIFF(cos_dist_all) by session_id_skip_2_False>,
#  <Feature: DIFF(cos_dist_all) by session_id_skip_2_True>,
#  <Feature: DIFF(euc_dist_all) by session_id>,
#  <Feature: DIFF(euc_dist_all) by session_id_skip_2_False>,
#  <Feature: DIFF(euc_dist_all) by session_id_skip_2_True>,
#  <Feature: DIFF(hist_user_behavior_reason_start_appload) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_appload) by session_id_skip_2_False>,
#  <Feature: DIFF(hist_user_behavior_reason_start_appload) by session_id_skip_2_True>,
#  <Feature: DIFF(hist_user_behavior_reason_start_backbtn) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_backbtn) by session_id_skip_2_False>,
#  <Feature: DIFF(hist_user_behavior_reason_start_backbtn) by session_id_skip_2_True>,
#  <Feature: DIFF(hist_user_behavior_reason_start_clickrow) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_clickrow) by session_id_skip_2_False>,
#  <Feature: DIFF(hist_user_behavior_reason_start_clickrow) by session_id_skip_2_True>,
#  <Feature: DIFF(hist_user_behavior_reason_start_endplay) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_endplay) by session_id_skip_2_False>,
#  <Feature: DIFF(hist_user_behavior_reason_start_endplay) by session_id_skip_2_True>,
#  <Feature: DIFF(hist_user_behavior_reason_start_fwdbtn) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_2_False>,
#  <Feature: DIFF(hist_user_behavior_reason_start_fwdbtn) by session_id_skip_2_True>,
#  <Feature: DIFF(hist_user_behavior_reason_start_playbtn) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_playbtn) by session_id_skip_2_False>,
#  <Feature: DIFF(hist_user_behavior_reason_start_playbtn) by session_id_skip_2_True>,
#  <Feature: DIFF(hist_user_behavior_reason_start_remote) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_remote) by session_id_skip_2_False>,
#  <Feature: DIFF(hist_user_behavior_reason_start_remote) by session_id_skip_2_True>,
#  <Feature: DIFF(hist_user_behavior_reason_start_trackdone) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_trackdone) by session_id_skip_2_False>,
#  <Feature: DIFF(hist_user_behavior_reason_start_trackdone) by session_id_skip_2_True>,
#  <Feature: DIFF(hist_user_behavior_reason_start_trackerror) by session_id>,
#  <Feature: DIFF(hist_user_behavior_reason_start_trackerror) by session_id_skip_2_False>,
#  <Feature: DIFF(hist_user_behavior_reason_start_trackerror) by session_id_skip_2_True>,
#  <Feature: DIFF(long_pause_before_play) by session_id>,
#  <Feature: DIFF(long_pause_before_play) by session_id_skip_2_False>,
#  <Feature: DIFF(long_pause_before_play) by session_id_skip_2_True>,
#  <Feature: DIFF(man_dist_all) by session_id>,
#  <Feature: DIFF(man_dist_all) by session_id_skip_2_False>,
#  <Feature: DIFF(man_dist_all) by session_id_skip_2_True>,
#  <Feature: DIFF(no_pause_before_play) by session_id>,
#  <Feature: DIFF(no_pause_before_play) by session_id_skip_2_False>,
#  <Feature: DIFF(no_pause_before_play) by session_id_skip_2_True>,
#  <Feature: DIFF(short_pause_before_play) by session_id>,
#  <Feature: DIFF(short_pause_before_play) by session_id_skip_2_False>,
#  <Feature: DIFF(short_pause_before_play) by session_id_skip_2_True>,
#  <Feature: tf.duration>,
#  <Feature: tf.release_year>,
#  <Feature: tf.us_popularity_estimate>,
#  <Feature: tf.acousticness>,
#  <Feature: tf.beat_strength>,
#  <Feature: tf.bounciness>,
#  <Feature: tf.danceability>,
#  <Feature: tf.dyn_range_mean>,
#  <Feature: tf.energy>,
#  <Feature: tf.flatness>,
#  <Feature: tf.instrumentalness>,
#  <Feature: tf.liveness>,
#  <Feature: tf.loudness>,
#  <Feature: tf.mechanism>,
#  <Feature: tf.organism>,
#  <Feature: tf.speechiness>,
#  <Feature: tf.tempo>,
#  <Feature: tf.valence>,
#  <Feature: tf.acoustic_vector_0>,
#  <Feature: tf.acoustic_vector_1>,
#  <Feature: tf.acoustic_vector_2>,
#  <Feature: tf.acoustic_vector_3>,
#  <Feature: tf.acoustic_vector_4>,
#  <Feature: tf.acoustic_vector_5>,
#  <Feature: tf.acoustic_vector_6>,
#  <Feature: tf.acoustic_vector_7>,
#  <Feature: tf.key_0>,
#  <Feature: tf.key_1>,
#  <Feature: tf.key_2>,
#  <Feature: tf.key_3>,
#  <Feature: tf.key_4>,
#  <Feature: tf.key_5>,
#  <Feature: tf.key_6>,
#  <Feature: tf.key_7>,
#  <Feature: tf.key_8>,
#  <Feature: tf.key_9>,
#  <Feature: tf.key_10>,
#  <Feature: tf.key_11>,
#  <Feature: tf.time_signature_0>,
#  <Feature: tf.time_signature_1>,
#  <Feature: tf.time_signature_3>,
#  <Feature: tf.time_signature_4>,
#  <Feature: tf.time_signature_5>,
#  <Feature: tf.mode_major>,
#  <Feature: tf.mode_minor>,
#  <Feature: CUM_MAX(tf.acoustic_vector_0) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_0) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.acoustic_vector_0) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.acoustic_vector_1) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_1) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.acoustic_vector_1) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.acoustic_vector_2) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_2) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.acoustic_vector_2) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.acoustic_vector_3) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_3) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.acoustic_vector_3) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.acoustic_vector_4) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_4) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.acoustic_vector_4) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.acoustic_vector_5) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_5) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.acoustic_vector_5) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.acoustic_vector_6) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_6) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.acoustic_vector_6) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.acoustic_vector_7) by session_id>,
#  <Feature: CUM_MAX(tf.acoustic_vector_7) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.acoustic_vector_7) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.acousticness) by session_id>,
#  <Feature: CUM_MAX(tf.acousticness) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.acousticness) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.beat_strength) by session_id>,
#  <Feature: CUM_MAX(tf.beat_strength) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.beat_strength) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.bounciness) by session_id>,
#  <Feature: CUM_MAX(tf.bounciness) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.bounciness) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.danceability) by session_id>,
#  <Feature: CUM_MAX(tf.danceability) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.danceability) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.duration) by session_id>,
#  <Feature: CUM_MAX(tf.duration) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.duration) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.dyn_range_mean) by session_id>,
#  <Feature: CUM_MAX(tf.dyn_range_mean) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.dyn_range_mean) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.energy) by session_id>,
#  <Feature: CUM_MAX(tf.energy) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.energy) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.flatness) by session_id>,
#  <Feature: CUM_MAX(tf.flatness) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.flatness) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.instrumentalness) by session_id>,
#  <Feature: CUM_MAX(tf.instrumentalness) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.instrumentalness) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.liveness) by session_id>,
#  <Feature: CUM_MAX(tf.liveness) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.liveness) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.loudness) by session_id>,
#  <Feature: CUM_MAX(tf.loudness) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.loudness) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.mechanism) by session_id>,
#  <Feature: CUM_MAX(tf.mechanism) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.mechanism) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.mode_major) by session_id>,
#  <Feature: CUM_MAX(tf.mode_major) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.mode_major) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.mode_minor) by session_id>,
#  <Feature: CUM_MAX(tf.mode_minor) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.mode_minor) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.organism) by session_id>,
#  <Feature: CUM_MAX(tf.organism) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.organism) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.release_year) by session_id>,
#  <Feature: CUM_MAX(tf.release_year) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.release_year) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.speechiness) by session_id>,
#  <Feature: CUM_MAX(tf.speechiness) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.speechiness) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.tempo) by session_id>,
#  <Feature: CUM_MAX(tf.tempo) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.tempo) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.us_popularity_estimate) by session_id>,
#  <Feature: CUM_MAX(tf.us_popularity_estimate) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.us_popularity_estimate) by session_id_skip_2_True>,
#  <Feature: CUM_MAX(tf.valence) by session_id>,
#  <Feature: CUM_MAX(tf.valence) by session_id_skip_2_False>,
#  <Feature: CUM_MAX(tf.valence) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_0) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_0) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_0) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_1) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_1) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_1) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_2) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_2) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_2) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_3) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_3) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_3) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_4) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_4) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_4) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_5) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_5) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_5) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_6) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_6) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_6) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_7) by session_id>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_7) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.acoustic_vector_7) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.acousticness) by session_id>,
#  <Feature: CUM_MEAN(tf.acousticness) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.acousticness) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.beat_strength) by session_id>,
#  <Feature: CUM_MEAN(tf.beat_strength) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.beat_strength) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.bounciness) by session_id>,
#  <Feature: CUM_MEAN(tf.bounciness) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.bounciness) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.danceability) by session_id>,
#  <Feature: CUM_MEAN(tf.danceability) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.danceability) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.duration) by session_id>,
#  <Feature: CUM_MEAN(tf.duration) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.duration) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.dyn_range_mean) by session_id>,
#  <Feature: CUM_MEAN(tf.dyn_range_mean) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.dyn_range_mean) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.energy) by session_id>,
#  <Feature: CUM_MEAN(tf.energy) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.energy) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.flatness) by session_id>,
#  <Feature: CUM_MEAN(tf.flatness) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.flatness) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.instrumentalness) by session_id>,
#  <Feature: CUM_MEAN(tf.instrumentalness) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.instrumentalness) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.liveness) by session_id>,
#  <Feature: CUM_MEAN(tf.liveness) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.liveness) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.loudness) by session_id>,
#  <Feature: CUM_MEAN(tf.loudness) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.loudness) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.mechanism) by session_id>,
#  <Feature: CUM_MEAN(tf.mechanism) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.mechanism) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.mode_major) by session_id>,
#  <Feature: CUM_MEAN(tf.mode_major) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.mode_major) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.mode_minor) by session_id>,
#  <Feature: CUM_MEAN(tf.mode_minor) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.mode_minor) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.organism) by session_id>,
#  <Feature: CUM_MEAN(tf.organism) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.organism) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.release_year) by session_id>,
#  <Feature: CUM_MEAN(tf.release_year) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.release_year) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.speechiness) by session_id>,
#  <Feature: CUM_MEAN(tf.speechiness) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.speechiness) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.tempo) by session_id>,
#  <Feature: CUM_MEAN(tf.tempo) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.tempo) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.us_popularity_estimate) by session_id>,
#  <Feature: CUM_MEAN(tf.us_popularity_estimate) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.us_popularity_estimate) by session_id_skip_2_True>,
#  <Feature: CUM_MEAN(tf.valence) by session_id>,
#  <Feature: CUM_MEAN(tf.valence) by session_id_skip_2_False>,
#  <Feature: CUM_MEAN(tf.valence) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.acoustic_vector_0) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_0) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.acoustic_vector_0) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.acoustic_vector_1) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_1) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.acoustic_vector_1) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.acoustic_vector_2) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_2) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.acoustic_vector_2) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.acoustic_vector_3) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_3) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.acoustic_vector_3) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.acoustic_vector_4) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_4) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.acoustic_vector_4) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.acoustic_vector_5) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_5) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.acoustic_vector_5) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.acoustic_vector_6) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_6) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.acoustic_vector_6) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.acoustic_vector_7) by session_id>,
#  <Feature: CUM_MIN(tf.acoustic_vector_7) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.acoustic_vector_7) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.acousticness) by session_id>,
#  <Feature: CUM_MIN(tf.acousticness) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.acousticness) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.beat_strength) by session_id>,
#  <Feature: CUM_MIN(tf.beat_strength) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.beat_strength) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.bounciness) by session_id>,
#  <Feature: CUM_MIN(tf.bounciness) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.bounciness) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.danceability) by session_id>,
#  <Feature: CUM_MIN(tf.danceability) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.danceability) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.duration) by session_id>,
#  <Feature: CUM_MIN(tf.duration) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.duration) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.dyn_range_mean) by session_id>,
#  <Feature: CUM_MIN(tf.dyn_range_mean) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.dyn_range_mean) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.energy) by session_id>,
#  <Feature: CUM_MIN(tf.energy) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.energy) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.flatness) by session_id>,
#  <Feature: CUM_MIN(tf.flatness) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.flatness) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.instrumentalness) by session_id>,
#  <Feature: CUM_MIN(tf.instrumentalness) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.instrumentalness) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.liveness) by session_id>,
#  <Feature: CUM_MIN(tf.liveness) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.liveness) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.loudness) by session_id>,
#  <Feature: CUM_MIN(tf.loudness) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.loudness) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.mechanism) by session_id>,
#  <Feature: CUM_MIN(tf.mechanism) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.mechanism) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.mode_major) by session_id>,
#  <Feature: CUM_MIN(tf.mode_major) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.mode_major) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.mode_minor) by session_id>,
#  <Feature: CUM_MIN(tf.mode_minor) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.mode_minor) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.organism) by session_id>,
#  <Feature: CUM_MIN(tf.organism) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.organism) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.release_year) by session_id>,
#  <Feature: CUM_MIN(tf.release_year) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.release_year) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.speechiness) by session_id>,
#  <Feature: CUM_MIN(tf.speechiness) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.speechiness) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.tempo) by session_id>,
#  <Feature: CUM_MIN(tf.tempo) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.tempo) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.us_popularity_estimate) by session_id>,
#  <Feature: CUM_MIN(tf.us_popularity_estimate) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.us_popularity_estimate) by session_id_skip_2_True>,
#  <Feature: CUM_MIN(tf.valence) by session_id>,
#  <Feature: CUM_MIN(tf.valence) by session_id_skip_2_False>,
#  <Feature: CUM_MIN(tf.valence) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.acoustic_vector_0) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_0) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.acoustic_vector_0) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.acoustic_vector_1) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_1) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.acoustic_vector_1) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.acoustic_vector_2) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_2) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.acoustic_vector_2) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.acoustic_vector_3) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_3) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.acoustic_vector_3) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.acoustic_vector_4) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_4) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.acoustic_vector_4) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.acoustic_vector_5) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_5) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.acoustic_vector_5) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.acoustic_vector_6) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_6) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.acoustic_vector_6) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.acoustic_vector_7) by session_id>,
#  <Feature: CUM_SUM(tf.acoustic_vector_7) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.acoustic_vector_7) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.acousticness) by session_id>,
#  <Feature: CUM_SUM(tf.acousticness) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.acousticness) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.beat_strength) by session_id>,
#  <Feature: CUM_SUM(tf.beat_strength) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.beat_strength) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.bounciness) by session_id>,
#  <Feature: CUM_SUM(tf.bounciness) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.bounciness) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.danceability) by session_id>,
#  <Feature: CUM_SUM(tf.danceability) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.danceability) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.duration) by session_id>,
#  <Feature: CUM_SUM(tf.duration) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.duration) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.dyn_range_mean) by session_id>,
#  <Feature: CUM_SUM(tf.dyn_range_mean) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.dyn_range_mean) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.energy) by session_id>,
#  <Feature: CUM_SUM(tf.energy) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.energy) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.flatness) by session_id>,
#  <Feature: CUM_SUM(tf.flatness) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.flatness) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.instrumentalness) by session_id>,
#  <Feature: CUM_SUM(tf.instrumentalness) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.instrumentalness) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.liveness) by session_id>,
#  <Feature: CUM_SUM(tf.liveness) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.liveness) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.loudness) by session_id>,
#  <Feature: CUM_SUM(tf.loudness) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.loudness) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.mechanism) by session_id>,
#  <Feature: CUM_SUM(tf.mechanism) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.mechanism) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.mode_major) by session_id>,
#  <Feature: CUM_SUM(tf.mode_major) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.mode_major) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.mode_minor) by session_id>,
#  <Feature: CUM_SUM(tf.mode_minor) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.mode_minor) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.organism) by session_id>,
#  <Feature: CUM_SUM(tf.organism) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.organism) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.release_year) by session_id>,
#  <Feature: CUM_SUM(tf.release_year) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.release_year) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.speechiness) by session_id>,
#  <Feature: CUM_SUM(tf.speechiness) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.speechiness) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.tempo) by session_id>,
#  <Feature: CUM_SUM(tf.tempo) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.tempo) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.us_popularity_estimate) by session_id>,
#  <Feature: CUM_SUM(tf.us_popularity_estimate) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.us_popularity_estimate) by session_id_skip_2_True>,
#  <Feature: CUM_SUM(tf.valence) by session_id>,
#  <Feature: CUM_SUM(tf.valence) by session_id_skip_2_False>,
#  <Feature: CUM_SUM(tf.valence) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.acoustic_vector_0) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_0) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.acoustic_vector_0) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.acoustic_vector_1) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_1) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.acoustic_vector_1) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.acoustic_vector_2) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_2) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.acoustic_vector_2) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.acoustic_vector_3) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_3) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.acoustic_vector_3) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.acoustic_vector_4) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_4) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.acoustic_vector_4) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.acoustic_vector_5) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_5) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.acoustic_vector_5) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.acoustic_vector_6) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_6) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.acoustic_vector_6) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.acoustic_vector_7) by session_id>,
#  <Feature: DIFF(tf.acoustic_vector_7) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.acoustic_vector_7) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.acousticness) by session_id>,
#  <Feature: DIFF(tf.acousticness) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.acousticness) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.beat_strength) by session_id>,
#  <Feature: DIFF(tf.beat_strength) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.beat_strength) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.bounciness) by session_id>,
#  <Feature: DIFF(tf.bounciness) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.bounciness) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.danceability) by session_id>,
#  <Feature: DIFF(tf.danceability) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.danceability) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.duration) by session_id>,
#  <Feature: DIFF(tf.duration) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.duration) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.dyn_range_mean) by session_id>,
#  <Feature: DIFF(tf.dyn_range_mean) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.dyn_range_mean) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.energy) by session_id>,
#  <Feature: DIFF(tf.energy) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.energy) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.flatness) by session_id>,
#  <Feature: DIFF(tf.flatness) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.flatness) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.instrumentalness) by session_id>,
#  <Feature: DIFF(tf.instrumentalness) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.instrumentalness) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.liveness) by session_id>,
#  <Feature: DIFF(tf.liveness) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.liveness) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.loudness) by session_id>,
#  <Feature: DIFF(tf.loudness) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.loudness) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.mechanism) by session_id>,
#  <Feature: DIFF(tf.mechanism) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.mechanism) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.mode_major) by session_id>,
#  <Feature: DIFF(tf.mode_major) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.mode_major) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.mode_minor) by session_id>,
#  <Feature: DIFF(tf.mode_minor) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.mode_minor) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.organism) by session_id>,
#  <Feature: DIFF(tf.organism) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.organism) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.release_year) by session_id>,
#  <Feature: DIFF(tf.release_year) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.release_year) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.speechiness) by session_id>,
#  <Feature: DIFF(tf.speechiness) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.speechiness) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.tempo) by session_id>,
#  <Feature: DIFF(tf.tempo) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.tempo) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.us_popularity_estimate) by session_id>,
#  <Feature: DIFF(tf.us_popularity_estimate) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.us_popularity_estimate) by session_id_skip_2_True>,
#  <Feature: DIFF(tf.valence) by session_id>,
#  <Feature: DIFF(tf.valence) by session_id_skip_2_False>,
#  <Feature: DIFF(tf.valence) by session_id_skip_2_True>]

# %%
print(feature_defs[350])
ft.describe_feature(feature_defs[350])
# Out:
# <Feature: CUM_MAX(tf.bounciness) by session_id_skip_2_True>
# 'The cumulative maximum of the "bounciness" for the instance of "tf" associated with this instance of "log" for each "session_id_skip_2_True".'
