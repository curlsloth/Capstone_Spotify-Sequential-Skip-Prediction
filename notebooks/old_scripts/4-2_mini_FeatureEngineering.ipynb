# %% [markdown]
# # Check the results of Featuretools

# %%
import numpy as np
import pandas as pd
import featuretools as ft
import time
# %matplotlib inline

# %%
# load the feature matrix to check whether it was properly saved.

feature_matrix2 = pd.read_csv('../data/processed/feature_matrix_skip2_TF.csv')
feature_matrix2.sort_values(by = ['session_id','session_position'],inplace=True)
feature_matrix2.head().T
# Out:
#                                                                                      0      \
# event_id                                                                                 0
# session_id                                          0_00006f66-33e5-4de7-a324-2d18e439fc1e
# session_position                                                                         1
# skip_1                                                                               False
# skip_2                                                                               False
# ...                                                                                    ...
# DIFF(tf.us_popularity_estimate) by session_id_s...                                     NaN
# DIFF(tf.us_popularity_estimate) by session_id_s...                                     NaN
# DIFF(tf.valence) by session_id                                                         NaN
# ...

# %%
#pd.set_option('display.max_rows', 1000)
pd.DataFrame(feature_matrix2.isna().sum())
#pd.set_option('display.max_rows', 60)
# Out:
#                                                         0
# event_id                                                0
# session_id                                              0
# session_position                                        0
# skip_1                                                  0
# skip_2                                                  0
# ...                                                   ...
# DIFF(tf.us_popularity_estimate) by session_id_s...  10001
# DIFF(tf.us_popularity_estimate) by session_id_s...  10001
# DIFF(tf.valence) by session_id                      10000
# DIFF(tf.valence) by session_id_skip_2_False         10001
# DIFF(tf.valence) by session_id_skip_2_True          10001
#
# [739 rows x 1 columns]

# %%
# inspect the data of a session
a = feature_matrix2[feature_matrix2['session_id'] == '0_00006f66-33e5-4de7-a324-2d18e439fc1e']
# inspect whether the featuretools generated features considered the session and the order information. The answer appears yes.
a[['tf.speechiness','CUM_SUM(tf.speechiness) by session_id','session_id','CUM_SUM(tf.speechiness) by session_id_skip_2_False','session_id_skip_2_False','CUM_SUM(tf.speechiness) by session_id_skip_2_True','session_id_skip_2_True','session_position']]
# Out:
#         tf.speechiness  CUM_SUM(tf.speechiness) by session_id  \
# 0             0.069717                               0.069717
# 10000         0.061158                               0.130874
# 20000         0.045354                               0.176229
# 30000         0.229936                               0.406164
# 40000         0.240980                               0.647144
# 50000         0.133586                               0.780730
# 60000         0.409848                               1.190578
# 70000         0.103687                               1.294266
# 80000         0.049853                               1.344119
# 90000         0.154609                               1.498729
# 100000        0.027932                               1.526660
# 109181        0.414651                               1.941311
# 117610        0.364139                               2.305451
# 125393        0.256456                               2.561906
# ...

# %%
cols_skip_2_True = [col for col in feature_matrix2.columns if 'by session_id_skip_2_True' in col]
cols_skip_2_False = [col for col in feature_matrix2.columns if 'by session_id_skip_2_False' in col]

# %%
feature_matrix2.loc[feature_matrix2['session_id_skip_2_True'].isna(),cols_skip_2_True] = np.nan
feature_matrix2.loc[feature_matrix2['session_id_skip_2_False'].isna(),cols_skip_2_False] = np.nan
b = feature_matrix2[feature_matrix2['session_id'] == '0_00006f66-33e5-4de7-a324-2d18e439fc1e']
b[['tf.speechiness','CUM_SUM(tf.speechiness) by session_id','session_id','CUM_SUM(tf.speechiness) by session_id_skip_2_False','session_id_skip_2_False','CUM_SUM(tf.speechiness) by session_id_skip_2_True','session_id_skip_2_True','session_position']]
# Out:
#         tf.speechiness  CUM_SUM(tf.speechiness) by session_id  \
# 0             0.069717                               0.069717
# 10000         0.061158                               0.130874
# 20000         0.045354                               0.176229
# 30000         0.229936                               0.406164
# 40000         0.240980                               0.647144
# 50000         0.133586                               0.780730
# 60000         0.409848                               1.190578
# 70000         0.103687                               1.294266
# 80000         0.049853                               1.344119
# 90000         0.154609                               1.498729
# 100000        0.027932                               1.526660
# 109181        0.414651                               1.941311
# 117610        0.364139                               2.305451
# 125393        0.256456                               2.561906
# ...

# %%
# shift the rows down by 1 within each session because it reflects the history (no_skip) up to the previous row
# without shifting, the information of no_skip will leak into the features!!
start_time = time.time()
feature_matrix2[cols_skip_2_True+cols_skip_2_False] = feature_matrix2.groupby(['session_id'])[cols_skip_2_True+cols_skip_2_False].shift(periods=1, axis=0, fill_value=0)
print('***It takes ',(time.time() - start_time)/60, ' mins.***')
# Out:
# ***It takes  2.6390278895696  mins.***

# %%
start_time = time.time()

feature_matrix2 = feature_matrix2.groupby(['session_id'], sort = False).apply(lambda x: x.ffill())

#feature_matrix2.groupby(['session_id']).fillna(method='ffill', axis = 0, inplace=True)
print('***It takes ',(time.time() - start_time)/60, ' mins.***')
# Out:
# /var/folders/fw/slnm06yn15lgwlcg_7jpt3t00000gn/T/ipykernel_53822/1174794535.py:3: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   feature_matrix2 = feature_matrix2.groupby(['session_id'], sort = False).apply(lambda x: x.ffill())
# ***It takes  0.2248967965443929  mins.***

# %%
# check the data again after shifting the rows
b = feature_matrix2[feature_matrix2['session_id'] == '0_00006f66-33e5-4de7-a324-2d18e439fc1e']
# inspect whether the featuretools generated features considered the session and the order information. The answer appears yes.
b[['tf.speechiness','CUM_SUM(tf.speechiness) by session_id','session_id','CUM_SUM(tf.speechiness) by session_id_skip_2_False','session_id_skip_2_False','CUM_SUM(tf.speechiness) by session_id_skip_2_True','session_id_skip_2_True','session_position']]
# Out:
#         tf.speechiness  CUM_SUM(tf.speechiness) by session_id  \
# 0             0.069717                               0.069717
# 10000         0.061158                               0.130874
# 20000         0.045354                               0.176229
# 30000         0.229936                               0.406164
# 40000         0.240980                               0.647144
# 50000         0.133586                               0.780730
# 60000         0.409848                               1.190578
# 70000         0.103687                               1.294266
# 80000         0.049853                               1.344119
# 90000         0.154609                               1.498729
# 100000        0.027932                               1.526660
# 109181        0.414651                               1.941311
# 117610        0.364139                               2.305451
# 125393        0.256456                               2.561906
# ...

# %%
feature_matrix2.to_csv('../data/processed/feature_matrix_skip2_TF_processed.csv')

# %% [markdown]
# # Scale standardization & training/testing data split will be performed at the model fitting stage.
