# %%
import pandas as pd
import numpy as np
import tarfile
import io
import glob
import dask.dataframe as dd

# import xgboost as xgb
# from xgboost import XGBClassifier
from bayes_opt import BayesianOptimization
from bayes_opt.logger import JSONLogger
from bayes_opt.event import Events

import lightgbm as lgb
import warnings

# %%
bst170 = lgb.Booster(model_file='../models/SVD/LightGBM_BayesOpt_dec12/LightGBM_incremental_training_dec15/boost170.txt')
bst160 = lgb.Booster(model_file='../models/SVD/LightGBM_BayesOpt_dec12/LightGBM_incremental_training_dec15/boost160.txt')
bst150 = lgb.Booster(model_file='../models/SVD/LightGBM_BayesOpt_dec12/LightGBM_incremental_training_dec15/boost150.txt')

# %%
aa = bst170.trees_to_dataframe()

# %%
bst160.current_iteration()
# Out:
# 9829

# %%
bst150.current_iteration()
# Out:
# 9750

# %%
bst160.
# Out:
# <bound method Booster.get_split_value_histogram of <lightgbm.basic.Booster object at 0x7fb1098055e0>>

# %%
aa
# Out:
#         tree_index  node_depth node_index left_child right_child parent_index  \
# 0                0           1       0-S0       0-S2        0-S1         None
# 1                0           2       0-S2       0-S3        0-S7         0-S0
# 2                0           3       0-S3      0-S19        0-S5         0-S2
# 3                0           4      0-S19       0-L0       0-L20         0-S3
# 4                0           5       0-L0       None        None        0-S19
# ...            ...         ...        ...        ...         ...          ...
# 913778        9827           3    9827-L1       None        None      9827-S1
# 913779        9827           3    9827-L2       None        None      9827-S1
# 913780        9828           1    9828-S0    9828-L0     9828-L1         None
# 913781        9828           2    9828-L0       None        None      9828-S0
# 913782        9828           2    9828-L1       None        None      9828-S0
#
# ...
